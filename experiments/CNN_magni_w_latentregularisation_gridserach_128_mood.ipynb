# %%
# Importing necessary libraries
# TODO:clean this
import pandas as pd
import numpy as np
import os
pd.options.mode.chained_assignment = None 
import pickle
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import ParameterGrid
from sklearn.metrics import precision_score, recall_score, f1_score
import cv2
import keras
from tensorflow import keras
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, Activation
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorboard.plugins.hparams import api as hp

# %%
#df for 128 embeddings
df = pd.read_pickle('/home/mendu/Thesis/data/magnatagatune/saved_df_data/df_w_mood_128embeddings.pkl')

# %%
df
# Out:
#       clip_id                                           mp3_path     tags  \
# 0          11  american_bach_soloists-j_s__bach_solo_cantatas...    quiet
# 1          21         lvx_nova-lvx_nova-01-contimune-233-262.mp3     fast
# 2          23         lvx_nova-lvx_nova-01-contimune-291-320.mp3     fast
# 3          39  american_bach_soloists-heinrich_schutz__musica...     slow
# 4          51  american_bach_soloists-heinrich_schutz__musica...    quiet
# ...       ...                                                ...      ...
# 5992    58800  magnaloops-world_loops_1-43-osabhanschristian5...     slow
# 5993    58815  jacob_heringman-blame_not_my_lute-45-tantarra_...     soft
# 5994    58880  magnaloops-world_loops_2-54-osdmichaelmasley64...  ambient
# 5995    58907  jacob_heringman-blame_not_my_lute-57-lost_is_m...     slow
# 5996    58915  jacob_heringman-blame_not_my_lute-58-a_toy_for...     slow
#
#                                       caption_embedding
# 0     [0.0, 0.069062, 0.0, 0.0, 0.10199389, 0.017180...
# 1     [0.0, 0.08048035, 0.0, 0.0, 0.0926192, 0.00765...
# 2     [0.0, 0.058119245, 0.0, 0.011021233, 0.0871724...
# 3     [0.0, 0.06326667, 0.0, 0.0, 0.098317504, 0.023...
# 4     [0.0, 0.057540625, 0.0, 0.0044447742, 0.093889...
# ...                                                 ...
# 5992  [0.0, 0.06094677, 0.0, 0.00035023037, 0.094731...
# 5993  [0.0, 0.05936481, 0.0, 0.0057750293, 0.0870878...
# 5994  [0.0, 0.05700565, 0.0, 0.0, 0.11397909, 0.0155...
# 5995  [0.0, 0.058866613, 0.0, 0.0037290733, 0.081891...
# 5996  [0.0, 0.06539015, 0.0, 0.0036312016, 0.0834513...
#
# [5997 rows x 4 columns]

# %% [markdown]
# ## Training the model

# %%
def add_gauss_noise(image, mean = 0, var = 10):
    '''function to add gaussian noise to an image'''
    sigma = var ** 0.5

    #creating a noise image with gaussian distribution
    gaussian = np.random.normal(mean, sigma, (image.shape[0], image.shape[1]))

    #creating a zeroes image
    noisy_image = np.zeros(image.shape, np.float32)

    #adding the noise to the original image
    noisy_image = image + gaussian

    #normalising the image
    cv2.normalize(noisy_image, noisy_image, 0, 255, cv2.NORM_MINMAX, dtype=-1)

    #changing type
    noisy_image = noisy_image.astype(np.uint8)

    return noisy_image

# %%
# #loading the cropped .npy files in a tensor

# #the folder path to where the mel-specs are stored
# folder_path_mel = '/home/mendu/Thesis/data/magnatagatune/mel-specs'

# #The ordered list of all the filenames in the filtered_df
# audio_names_list = df.mp3_path.to_list()

# %%
data = []
i = 0

for filename in audio_names_list: #iterates over the filtered_df audio names
    filename_npy = str(filename[:-4]) + '.npy'
    file_path = os.path.join(folder_path_mel, filename_npy) #creates a folder path for the mel_specs 
    img = np.load(file_path)
    data.append(add_gauss_noise(img))

    # To ensure that the files are getting loaded in the correct order
    if i < 10 :
        print(filename)
    i = i+1

data = np.array(data)
# Out:
# american_bach_soloists-j_s__bach_solo_cantatas-01-bwv54__i_aria-291-320.mp3
# lvx_nova-lvx_nova-01-contimune-233-262.mp3
# lvx_nova-lvx_nova-01-contimune-291-320.mp3
# american_bach_soloists-heinrich_schutz__musicalische_exequien-01-musicalische_exequien_swv_279_teil_i_concert_in_form_einer_teutschen_begrabnismissa-0-29.mp3
# american_bach_soloists-heinrich_schutz__musicalische_exequien-01-musicalische_exequien_swv_279_teil_i_concert_in_form_einer_teutschen_begrabnismissa-349-378.mp3
# american_bach_soloists-heinrich_schutz__musicalische_exequien-01-musicalische_exequien_swv_279_teil_i_concert_in_form_einer_teutschen_begrabnismissa-784-813.mp3
# ralph_meulenbroeks-gambomania-01-my_mistress_hath_a_pritty_thing_tobias_hume-59-88.mp3
# ralph_meulenbroeks-gambomania-01-my_mistress_hath_a_pritty_thing_tobias_hume-117-146.mp3
# ralph_meulenbroeks-gambomania-01-my_mistress_hath_a_pritty_thing_tobias_hume-175-204.mp3
# philharmonia_baroque_orchestra-jake_heggie__to_hell_and_back-01-overture-88-117.mp3

# %%
# data = np.load('/home/mendu/Thesis/data/magnatagatune/saved_df_data/data_array.npy')

# %%
# Caption Embeddings
embeddings = df['caption_embedding']

# %%
#normalize data
data = data.astype('float32')/255.0

data.shape
# Out:
# (5997, 128, 1255)

# %%
# Reshape data to include the channel dimension
data = data.reshape((-1, 128, 1255, 1))

# Split into training (0.8) and remaining set (0.2)
X_train_spec, X_rem_spec, X_train_embed, X_rem_embed, y_train, y_rem = train_test_split(data, embeddings, pd.get_dummies(df['tags']), test_size=0.2, random_state=42)

# Split the remaining set into validation (0.1) and test (0.1)
X_val_spec, X_test_spec, X_val_embed, X_test_embed, y_val, y_test = train_test_split(X_rem_spec, X_rem_embed, y_rem, test_size=0.5, random_state=42)

# %%
# Now, convert this array of arrays into a proper 2D NumPy array
X_train_embed_array = np.stack(X_train_embed, axis=0)

# Check the new shape to ensure it's (450, 64)
print("Shape after conversion:", X_train_embed_array.shape)

# Convert the 2D NumPy array to a TensorFlow tensor
X_train_embed_tensor = tf.convert_to_tensor(X_train_embed_array, dtype=tf.float32)

# Check the shape of the resulting tensor
print("Tensor shape:", X_train_embed_tensor.shape)
# Out:
# Shape after conversion: (4797, 128)
# Tensor shape: (4797, 128)
# 2024-08-10 20:22:58.005360: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
# Convert the 1D array of arrays into a proper 2D NumPy array
X_val_embed_array = np.stack(X_val_embed, axis=0)
X_test_embed_array = np.stack(X_test_embed, axis=0)

# Check the new shape to ensure it's in the correct format
print("Shape after conversion:", X_val_embed_array.shape)
print("Shape of test after conversion:", X_test_embed_array.shape)

# Convert the 2D NumPy array to a TensorFlow tensor
X_val_embed_tensor = tf.convert_to_tensor(X_val_embed_array, dtype=tf.float32)
X_test_embed_tensor = tf.convert_to_tensor(X_test_embed_array, dtype=tf.float32)

# Check the shape of the resulting tensor
print("Tensor shape:", X_val_embed_tensor.shape)
print("Tensor shape of test:", X_test_embed_tensor.shape)
# Out:
# Shape after conversion: (600, 128)
# Shape of test after conversion: (600, 128)
# Tensor shape: (600, 128)
# Tensor shape of test: (600, 128)

# %%
# Convert training data to tensors
X_train_spec = tf.convert_to_tensor(X_train_spec, dtype=tf.float32)
y_train = tf.convert_to_tensor(y_train, dtype=tf.float32)

# Convert validation data to tensors
X_val_spec = tf.convert_to_tensor(X_val_spec, dtype=tf.float32)
y_val = tf.convert_to_tensor(y_val, dtype=tf.float32)

# Convert validation data to tensors
X_test_spec = tf.convert_to_tensor(X_test_spec, dtype=tf.float32)
y_test = tf.convert_to_tensor(y_test, dtype=tf.float32)

# %%
# Initialize ImageDataGenerator with necessary augmentations
datagen = ImageDataGenerator(
    width_shift_range=0.2,
    height_shift_range=0.2
)

datagen.fit(X_train_spec)

# %%
# Define num_classes based on the number of unique genres
num_classes = y_train.shape[1]
num_classes
# Out:
# 7

# %%
def create_model(num_classes, l1_reg=0.01, l2_reg=0.1, alpha=0.0):
    class ModelSubClassing(keras.Model):
        def __init__(self, num_classes, l1_reg=0.01, l2_reg=0.1, alpha = 0):
            super().__init__()
            
            # Define L1 and L2 regularizer
            self.l1_l2_regularizer = regularizers.l1_l2(l1=l1_reg, l2=l2_reg)
            # self.l2_regularizer = regularizers.l2(l2_reg)
            
            # Define alpha the loss regulator
            self.alpha = alpha
            
            # number of classes
            self.num_classes = num_classes
            
            # Initialize layers as None
            self.conv1 = None
            self.max1 = None
            self.bn1 = None
            self.conv2 = None
            self.bn2 = None
            self.max2 = None
            self.drop1 = None
            self.conv3 = None
            self.bn3 = None
            self.max3 = None
            self.drop2 = None
            self.flatten = None
            self.dense128 = None
            self.dense128_relu = None
            self.dense128_sig = None
            self.dense128_do = None
            self.dense64 = None
            self.dense64_act = None
            self.dense_out = None
            
            self.loss_tracker = keras.metrics.Mean(name="loss")
            self.accuracy = keras.metrics.CategoricalAccuracy(name="accuracy")
            self.precision = Precision(name="precision")
            self.recall = Recall(name="recall")
            self.f1_score = keras.metrics.Mean(name="f1_score")

        def build(self, input_shape):
            # Create layers
            self.conv1 = Conv2D(32, 3, activation="relu", kernel_regularizer=self.l1_l2_regularizer)
            self.max1  = MaxPooling2D(3)
            self.bn1   = BatchNormalization(momentum=0.9)

            self.conv2 = Conv2D(64, 3, activation="relu", kernel_regularizer=self.l1_l2_regularizer)
            self.bn2   = BatchNormalization(momentum=0.9)
            self.max2  = MaxPooling2D(3)
            self.drop1 = Dropout(0.3)

            self.conv3 = Conv2D(128, 3, activation="relu", kernel_regularizer=self.l1_l2_regularizer)
            self.bn3   = BatchNormalization(momentum=0.9)
            self.max3  = MaxPooling2D(3)
            self.drop2 = Dropout(0.3)

            self.flatten = Flatten()
            self.dense128 = Dense(128)
            self.dense128_act_relu = Activation('relu')
            self.dense128_act_sig = Activation('sigmoid')
            self.dense128_do = Dropout(0.3)
            self.dense64 = Dense(64)
            self.dense64_act = Activation('relu')
            self.dense_out = Dense(self.num_classes, activation="softmax")
            
            super().build(input_shape)

        def call(self, inputs, training=None):
            # Unpack the inputs
            mel_spectrogram = inputs[0]

            # Forward pass: block 1
            x = self.conv1(mel_spectrogram)
            x = self.max1(x)
            x = self.bn1(x, training=training)

            # Forward pass: block 2
            x = self.conv2(x)
            x = self.bn2(x, training=training)
            x = self.max2(x)
            x = self.drop1(x, training=training)

            # Forward pass: block 3
            x = self.conv3(x)
            x = self.bn3(x, training=training)
            x = self.max3(x)
            x = self.drop2(x, training=training)

            # Flatten and dense layers
            x = self.flatten(x)
            x_dense128 = self.dense128(x)
            x_dense128_act_sig = self.dense128_act_sig(x_dense128)
            x_dense128_act_relu = self.dense128_act_relu(x_dense128)
            x_dense128_act = self.dense128_do(x_dense128_act_relu, training=training)
            
            # dense layer 64
            x_dense64 = self.dense64(x_dense128_act)
            x_dense64_act_relu = self.dense64_act(x_dense64)
            y_hat = self.dense_out(x_dense64_act_relu)
            
            return y_hat, x_dense128_act_sig


        def train_step(self, data):
            # Unpack the data
            (mel_spectrogram, caption_embedding), y = data

            with tf.GradientTape() as tape: 
            #here we get the gradients of the trainable weights with this loss
                y_pred, x_dense = self((mel_spectrogram, caption_embedding), training=True)  # Forward pass
                # Compute the standard loss value
                loss = self.compiled_loss(y, y_pred)
                custom_loss = self.custom_loss(caption_embedding, x_dense)
                total_loss = (1 - self.alpha) * loss + self.alpha * custom_loss

            # Compute gradients
            gradients = tape.gradient(total_loss, self.trainable_variables)

            # Update weights
            self.optimizer.apply_gradients(zip(gradients, self.trainable_variables))

            # Update the loss metric and any additional metrics
            self.loss_tracker.update_state(total_loss) 
            self.accuracy.update_state(y, y_pred)
            self.precision.update_state(y, y_pred)
            self.recall.update_state(y, y_pred)
            
            # Calculate F1 score
            f1 = 2 * ((self.precision.result() * self.recall.result()) / (self.precision.result() + self.recall.result() + tf.keras.backend.epsilon()))
            self.f1_score.update_state(f1)

            return {
                "loss": self.loss_tracker.result(),
                "accuracy": self.accuracy.result(),
                "ce_loss": loss,
                "embedding_loss": custom_loss,
                "total loss": total_loss,
                "alpha": self.alpha,
                "precision": self.precision.result(),
                "recall": self.recall.result(),
                "f1_score": self.f1_score.result(),
            }
            
        def test_step(self, data):
            # Unpack the data
            (mel_spectrogram, caption_embedding), y = data

            
            y_pred, x_dense = self((mel_spectrogram, caption_embedding), training=False)  # Forward pass
            # Compute the standard loss value
            loss = self.compiled_loss(y, y_pred)
            custom_loss = self.custom_loss(caption_embedding, x_dense)
            total_loss = (1 - self.alpha) * loss + self.alpha * custom_loss

            # Update the loss metric and any additional metrics
            self.loss_tracker.update_state(total_loss)
            self.accuracy.update_state(y, y_pred)
            self.precision.update_state(y, y_pred)
            self.recall.update_state(y, y_pred)
            
            # Calculate F1 score
            f1 = 2 * ((self.precision.result() * self.recall.result()) / (self.precision.result() + self.recall.result() + tf.keras.backend.epsilon()))
            self.f1_score.update_state(f1)
            
            return {
                "loss": self.loss_tracker.result(),
                "accuracy": self.accuracy.result(),
                "ce_loss": loss,
                "total loss": total_loss,
                "alpha": self.alpha,
                "precision": self.precision.result(),
                "recall": self.recall.result(),
                "f1_score": self.f1_score.result(), 
            }
            
        # Add a custom loss method in the model
        def custom_loss(self, caption_embedding, x_dense):
            # Compute the Mean Squared Error (MSE) between caption_embedding and x_dense64
            return tf.reduce_mean(tf.square(caption_embedding - x_dense))

        #new
        @property
        def metrics(self):
            # List all metrics to be reset after each epoch
            return [self.loss_tracker, self.accuracy]
        
        
    # Creating the class object

    model = ModelSubClassing(num_classes, l1_reg, l2_reg, alpha)

    # Compile the model
    adam_opt = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=adam_opt, loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# %%
# Define hyperparameters for grid search
param_grid = {
    'alpha': [0, 0.25, 0.5, 0.75, 1]
    # 'l1_reg': [0.01, 0.001],
    # 'l2_reg': [0.1, 0.01, 0.001]
}

only_alpha = False

if ("alpha" in param_grid) & (len(param_grid) == 1):
    only_alpha = True

checkpoint_folder = f"/home/mendu/Thesis/data/saved_models/grid_search_alpha_128_mood"

# Ensure the checkpoint folder exists
os.makedirs(checkpoint_folder, exist_ok=True)

# Define an empty dictionary to store history objects
history_dict = {}
results_dict = {}
models = {}

# Perform grid search
best_accuracy = 0
best_params = None
for params in ParameterGrid(param_grid):
    print(f"Testing params: {params}")
    
    model = create_model(num_classes, **params)
    
    checkpoint_file = f"_{params['alpha']}.keras"
    checkpoint_path = os.path.join(checkpoint_folder, checkpoint_file)
    
    # Initialize the ModelCheckpoint callback
    model_checkpoint = ModelCheckpoint(filepath=checkpoint_path,
                                   monitor='val_accuracy',  # Monitor validation accuracy
                                   save_best_only=True,     # Save only the best model
                                   verbose=0)
    
    rlronp = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=10, verbose=1)
    early_stopper = EarlyStopping(monitor='val_loss', patience=19, verbose=1, restore_best_weights=True)
    history = model.fit(
        (X_train_spec, X_train_embed_tensor),
        y_train,
        epochs= 100,
        batch_size=32,
        validation_data=((X_val_spec, X_val_embed_tensor), y_val),
        callbacks=[early_stopper, rlronp, model_checkpoint]
    )
    
    models[f'model_{params["alpha"]}'] = model
    
    # Save the history keyed by the parameter tuple for later reference
    history_dict[tuple(params.values())] = history.history
    
    # Evaluate manually
    train_loss, train_accuracy = model.evaluate((X_train_spec, X_train_embed_tensor), y_train, verbose=0)
    val_loss, val_accuracy = model.evaluate((X_val_spec, X_val_embed_tensor), y_val, verbose=0)
    test_loss, test_accuracy = model.evaluate((X_test_spec, X_test_embed_tensor), y_test, verbose=0)
    
    results_dict[tuple(params.values())] = {
    'train_accuracy': train_accuracy,
    'train_loss': train_loss,
    'val_accuracy': val_accuracy,
    'val_loss': val_loss,
    'test_accuracy': test_accuracy,
    'test_loss': test_loss
    }
    
    print(f"Test accuracy: {test_accuracy}, Training accuracy: {train_accuracy}, Validation accuracy: {val_accuracy} for params: {params}")
    
    if val_accuracy > best_accuracy:
        best_accuracy = val_accuracy
        best_params = params
        
    

print(f"Best params: {best_params} with validation accuracy: {best_accuracy}")
# Out:
# Testing params: {'alpha': 0}
# Epoch 1/100
# /home/mendu/miniconda3/envs/myenv/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py:612: UserWarning: `model.compiled_loss()` is deprecated. Instead, use `model.compute_loss(x, y, y_pred, sample_weight)`.
#   warnings.warn(
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 52s 329ms/step - accuracy: 0.3687 - alpha: 0.0000e+00 - ce_loss: 39.1104 - embedding_loss: 0.1048 - f1_score: 0.2581 - loss: 42.2539 - precision: 0.4077 - recall: 0.2238 - total loss: 39.1104 - val_accuracy: 0.5350 - val_loss: 33.1497 - learning_rate: 1.0000e-04
# Epoch 2/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 325ms/step - accuracy: 0.5237 - alpha: 0.0000e+00 - ce_loss: 27.9873 - embedding_loss: 0.0587 - f1_score: 0.3052 - loss: 30.4785 - precision: 0.5364 - recall: 0.2582 - total loss: 27.9873 - val_accuracy: 0.5783 - val_loss: 23.0924 - learning_rate: 1.0000e-04
# Epoch 3/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.5533 - alpha: 0.0000e+00 - ce_loss: 19.2557 - embedding_loss: 0.0520 - f1_score: 0.3319 - loss: 21.1055 - precision: 0.5834 - recall: 0.2898 - total loss: 19.2557 - val_accuracy: 0.5583 - val_loss: 15.6794 - learning_rate: 1.0000e-04
# Epoch 4/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 324ms/step - accuracy: 0.5657 - alpha: 0.0000e+00 - ce_loss: 12.9487 - embedding_loss: 0.0514 - f1_score: 0.3518 - loss: 14.2543 - precision: 0.6067 - recall: 0.3126 - total loss: 12.9487 - val_accuracy: 0.6033 - val_loss: 10.5190 - learning_rate: 1.0000e-04
# Epoch 5/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.5882 - alpha: 0.0000e+00 - ce_loss: 8.8100 - embedding_loss: 0.0517 - f1_score: 0.3684 - loss: 9.6087 - precision: 0.6257 - recall: 0.3349 - total loss: 8.8100 - val_accuracy: 0.5983 - val_loss: 7.2854 - learning_rate: 1.0000e-04
# Epoch 6/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.5976 - alpha: 0.0000e+00 - ce_loss: 6.2404 - embedding_loss: 0.0546 - f1_score: 0.3824 - loss: 6.7245 - precision: 0.6378 - recall: 0.3498 - total loss: 6.2404 - val_accuracy: 0.6450 - val_loss: 5.2678 - learning_rate: 1.0000e-04
# Epoch 7/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.5798 - alpha: 0.0000e+00 - ce_loss: 4.7548 - embedding_loss: 0.0559 - f1_score: 0.3943 - loss: 5.0666 - precision: 0.6468 - recall: 0.3638 - total loss: 4.7548 - val_accuracy: 0.6117 - val_loss: 4.2168 - learning_rate: 1.0000e-04
# Epoch 8/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.5923 - alpha: 0.0000e+00 - ce_loss: 3.8829 - embedding_loss: 0.0593 - f1_score: 0.4047 - loss: 4.0665 - precision: 0.6536 - recall: 0.3757 - total loss: 3.8829 - val_accuracy: 0.6050 - val_loss: 3.5533 - learning_rate: 1.0000e-04
# Epoch 9/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 324ms/step - accuracy: 0.6240 - alpha: 0.0000e+00 - ce_loss: 3.2880 - embedding_loss: 0.0580 - f1_score: 0.4140 - loss: 3.3901 - precision: 0.6599 - recall: 0.3885 - total loss: 3.2880 - val_accuracy: 0.6483 - val_loss: 3.0164 - learning_rate: 1.0000e-04
# Epoch 10/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.6285 - alpha: 0.0000e+00 - ce_loss: 2.8955 - embedding_loss: 0.0601 - f1_score: 0.4225 - loss: 2.9582 - precision: 0.6655 - recall: 0.3984 - total loss: 2.8955 - val_accuracy: 0.6383 - val_loss: 2.7948 - learning_rate: 1.0000e-04
# Epoch 11/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.6351 - alpha: 0.0000e+00 - ce_loss: 2.5838 - embedding_loss: 0.0618 - f1_score: 0.4301 - loss: 2.6370 - precision: 0.6707 - recall: 0.4071 - total loss: 2.5838 - val_accuracy: 0.6267 - val_loss: 2.4559 - learning_rate: 1.0000e-04
# Epoch 12/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 324ms/step - accuracy: 0.6496 - alpha: 0.0000e+00 - ce_loss: 2.3549 - embedding_loss: 0.0641 - f1_score: 0.4372 - loss: 2.3748 - precision: 0.6760 - recall: 0.4166 - total loss: 2.3549 - val_accuracy: 0.6633 - val_loss: 2.2594 - learning_rate: 1.0000e-04
# Epoch 13/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.6554 - alpha: 0.0000e+00 - ce_loss: 2.2023 - embedding_loss: 0.0616 - f1_score: 0.4438 - loss: 2.2097 - precision: 0.6811 - recall: 0.4241 - total loss: 2.2023 - val_accuracy: 0.5883 - val_loss: 2.2030 - learning_rate: 1.0000e-04
# Epoch 14/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.6557 - alpha: 0.0000e+00 - ce_loss: 2.0211 - embedding_loss: 0.0620 - f1_score: 0.4499 - loss: 2.0572 - precision: 0.6849 - recall: 0.4300 - total loss: 2.0211 - val_accuracy: 0.6600 - val_loss: 1.9836 - learning_rate: 1.0000e-04
# Epoch 15/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.6572 - alpha: 0.0000e+00 - ce_loss: 1.9018 - embedding_loss: 0.0675 - f1_score: 0.4555 - loss: 1.9073 - precision: 0.6888 - recall: 0.4373 - total loss: 1.9018 - val_accuracy: 0.6017 - val_loss: 2.0231 - learning_rate: 1.0000e-04
# Epoch 16/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.6504 - alpha: 0.0000e+00 - ce_loss: 1.8061 - embedding_loss: 0.0648 - f1_score: 0.4609 - loss: 1.8256 - precision: 0.6923 - recall: 0.4436 - total loss: 1.8061 - val_accuracy: 0.5167 - val_loss: 2.1949 - learning_rate: 1.0000e-04
# Epoch 17/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.6706 - alpha: 0.0000e+00 - ce_loss: 1.7231 - embedding_loss: 0.0639 - f1_score: 0.4659 - loss: 1.7325 - precision: 0.6941 - recall: 0.4486 - total loss: 1.7231 - val_accuracy: 0.6800 - val_loss: 1.6673 - learning_rate: 1.0000e-04
# Epoch 18/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.6636 - alpha: 0.0000e+00 - ce_loss: 1.6458 - embedding_loss: 0.0674 - f1_score: 0.4706 - loss: 1.6601 - precision: 0.6971 - recall: 0.4544 - total loss: 1.6458 - val_accuracy: 0.6683 - val_loss: 1.6619 - learning_rate: 1.0000e-04
# Epoch 19/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.6808 - alpha: 0.0000e+00 - ce_loss: 1.5917 - embedding_loss: 0.0666 - f1_score: 0.4750 - loss: 1.5963 - precision: 0.7006 - recall: 0.4603 - total loss: 1.5917 - val_accuracy: 0.6733 - val_loss: 1.6041 - learning_rate: 1.0000e-04
# Epoch 20/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.6695 - alpha: 0.0000e+00 - ce_loss: 1.5436 - embedding_loss: 0.0659 - f1_score: 0.4793 - loss: 1.5927 - precision: 0.7031 - recall: 0.4652 - total loss: 1.5436 - val_accuracy: 0.6850 - val_loss: 1.5352 - learning_rate: 1.0000e-04
# Epoch 21/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.6846 - alpha: 0.0000e+00 - ce_loss: 1.4741 - embedding_loss: 0.0679 - f1_score: 0.4833 - loss: 1.4723 - precision: 0.7064 - recall: 0.4706 - total loss: 1.4741 - val_accuracy: 0.6917 - val_loss: 1.5098 - learning_rate: 1.0000e-04
# Epoch 22/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.6756 - alpha: 0.0000e+00 - ce_loss: 1.4611 - embedding_loss: 0.0709 - f1_score: 0.4873 - loss: 1.4730 - precision: 0.7094 - recall: 0.4758 - total loss: 1.4611 - val_accuracy: 0.6733 - val_loss: 1.5243 - learning_rate: 1.0000e-04
# Epoch 23/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.6943 - alpha: 0.0000e+00 - ce_loss: 1.3966 - embedding_loss: 0.0730 - f1_score: 0.4910 - loss: 1.4049 - precision: 0.7123 - recall: 0.4801 - total loss: 1.3966 - val_accuracy: 0.6500 - val_loss: 1.4975 - learning_rate: 1.0000e-04
# Epoch 24/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 324ms/step - accuracy: 0.6921 - alpha: 0.0000e+00 - ce_loss: 1.3766 - embedding_loss: 0.0740 - f1_score: 0.4946 - loss: 1.3757 - precision: 0.7148 - recall: 0.4841 - total loss: 1.3766 - val_accuracy: 0.6250 - val_loss: 1.5611 - learning_rate: 1.0000e-04
# Epoch 25/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 328ms/step - accuracy: 0.6952 - alpha: 0.0000e+00 - ce_loss: 1.3249 - embedding_loss: 0.0767 - f1_score: 0.4981 - loss: 1.3163 - precision: 0.7165 - recall: 0.4880 - total loss: 1.3249 - val_accuracy: 0.6933 - val_loss: 1.3710 - learning_rate: 1.0000e-04
# Epoch 26/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 50s 335ms/step - accuracy: 0.7023 - alpha: 0.0000e+00 - ce_loss: 1.2966 - embedding_loss: 0.0765 - f1_score: 0.5014 - loss: 1.2819 - precision: 0.7191 - recall: 0.4927 - total loss: 1.2966 - val_accuracy: 0.6300 - val_loss: 1.4802 - learning_rate: 1.0000e-04
# Epoch 27/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 328ms/step - accuracy: 0.7151 - alpha: 0.0000e+00 - ce_loss: 1.2632 - embedding_loss: 0.0800 - f1_score: 0.5046 - loss: 1.2429 - precision: 0.7215 - recall: 0.4969 - total loss: 1.2632 - val_accuracy: 0.6983 - val_loss: 1.3816 - learning_rate: 1.0000e-04
# Epoch 28/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.7116 - alpha: 0.0000e+00 - ce_loss: 1.2246 - embedding_loss: 0.0810 - f1_score: 0.5077 - loss: 1.2230 - precision: 0.7237 - recall: 0.5011 - total loss: 1.2246 - val_accuracy: 0.5833 - val_loss: 1.6800 - learning_rate: 1.0000e-04
# Epoch 29/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.7202 - alpha: 0.0000e+00 - ce_loss: 1.2128 - embedding_loss: 0.0819 - f1_score: 0.5108 - loss: 1.2001 - precision: 0.7256 - recall: 0.5049 - total loss: 1.2128 - val_accuracy: 0.4883 - val_loss: 2.3015 - learning_rate: 1.0000e-04
# Epoch 30/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 325ms/step - accuracy: 0.7080 - alpha: 0.0000e+00 - ce_loss: 1.1739 - embedding_loss: 0.0812 - f1_score: 0.5137 - loss: 1.1952 - precision: 0.7266 - recall: 0.5081 - total loss: 1.1739 - val_accuracy: 0.6967 - val_loss: 1.2993 - learning_rate: 1.0000e-04
# Epoch 31/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 324ms/step - accuracy: 0.7296 - alpha: 0.0000e+00 - ce_loss: 1.1534 - embedding_loss: 0.0851 - f1_score: 0.5165 - loss: 1.1410 - precision: 0.7293 - recall: 0.5124 - total loss: 1.1534 - val_accuracy: 0.7183 - val_loss: 1.2609 - learning_rate: 1.0000e-04
# Epoch 32/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 325ms/step - accuracy: 0.7381 - alpha: 0.0000e+00 - ce_loss: 1.1657 - embedding_loss: 0.0855 - f1_score: 0.5193 - loss: 1.1523 - precision: 0.7314 - recall: 0.5164 - total loss: 1.1657 - val_accuracy: 0.7067 - val_loss: 1.2818 - learning_rate: 1.0000e-04
# Epoch 33/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 324ms/step - accuracy: 0.7410 - alpha: 0.0000e+00 - ce_loss: 1.1211 - embedding_loss: 0.0854 - f1_score: 0.5220 - loss: 1.1033 - precision: 0.7338 - recall: 0.5203 - total loss: 1.1211 - val_accuracy: 0.7017 - val_loss: 1.2909 - learning_rate: 1.0000e-04
# Epoch 34/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 324ms/step - accuracy: 0.7515 - alpha: 0.0000e+00 - ce_loss: 1.0900 - embedding_loss: 0.0892 - f1_score: 0.5246 - loss: 1.0566 - precision: 0.7360 - recall: 0.5240 - total loss: 1.0900 - val_accuracy: 0.6550 - val_loss: 1.3893 - learning_rate: 1.0000e-04
# Epoch 35/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.7504 - alpha: 0.0000e+00 - ce_loss: 1.0675 - embedding_loss: 0.0877 - f1_score: 0.5272 - loss: 1.0614 - precision: 0.7380 - recall: 0.5275 - total loss: 1.0675 - val_accuracy: 0.6933 - val_loss: 1.2745 - learning_rate: 1.0000e-04
# Epoch 36/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.7365 - alpha: 0.0000e+00 - ce_loss: 1.0608 - embedding_loss: 0.0888 - f1_score: 0.5298 - loss: 1.0531 - precision: 0.7400 - recall: 0.5310 - total loss: 1.0608 - val_accuracy: 0.6967 - val_loss: 1.2566 - learning_rate: 1.0000e-04
# Epoch 37/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.7558 - alpha: 0.0000e+00 - ce_loss: 1.0225 - embedding_loss: 0.0920 - f1_score: 0.5322 - loss: 1.0113 - precision: 0.7420 - recall: 0.5346 - total loss: 1.0225 - val_accuracy: 0.5917 - val_loss: 1.4783 - learning_rate: 1.0000e-04
# Epoch 38/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 324ms/step - accuracy: 0.7715 - alpha: 0.0000e+00 - ce_loss: 0.9999 - embedding_loss: 0.0907 - f1_score: 0.5347 - loss: 0.9872 - precision: 0.7439 - recall: 0.5382 - total loss: 0.9999 - val_accuracy: 0.7033 - val_loss: 1.2736 - learning_rate: 1.0000e-04
# Epoch 39/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 324ms/step - accuracy: 0.7688 - alpha: 0.0000e+00 - ce_loss: 0.9823 - embedding_loss: 0.0918 - f1_score: 0.5370 - loss: 0.9647 - precision: 0.7461 - recall: 0.5419 - total loss: 0.9823 - val_accuracy: 0.6600 - val_loss: 1.3579 - learning_rate: 1.0000e-04
# Epoch 40/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.7832 - alpha: 0.0000e+00 - ce_loss: 0.9565 - embedding_loss: 0.0942 - f1_score: 0.5394 - loss: 0.9246 - precision: 0.7481 - recall: 0.5455 - total loss: 0.9565 - val_accuracy: 0.7000 - val_loss: 1.2938 - learning_rate: 1.0000e-04
# Epoch 41/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.7727 - alpha: 0.0000e+00 - ce_loss: 0.9479 - embedding_loss: 0.0950 - f1_score: 0.5417 - loss: 0.9505 - precision: 0.7501 - recall: 0.5492 - total loss: 0.9479 - val_accuracy: 0.7050 - val_loss: 1.2418 - learning_rate: 1.0000e-04
# Epoch 42/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.7691 - alpha: 0.0000e+00 - ce_loss: 0.9318 - embedding_loss: 0.0969 - f1_score: 0.5439 - loss: 0.9559 - precision: 0.7520 - recall: 0.5528 - total loss: 0.9318 - val_accuracy: 0.6800 - val_loss: 1.3016 - learning_rate: 1.0000e-04
# Epoch 43/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.7794 - alpha: 0.0000e+00 - ce_loss: 0.9122 - embedding_loss: 0.0984 - f1_score: 0.5462 - loss: 0.9035 - precision: 0.7541 - recall: 0.5565 - total loss: 0.9122 - val_accuracy: 0.6900 - val_loss: 1.3579 - learning_rate: 1.0000e-04
# Epoch 44/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.7922 - alpha: 0.0000e+00 - ce_loss: 0.8804 - embedding_loss: 0.1007 - f1_score: 0.5484 - loss: 0.8901 - precision: 0.7561 - recall: 0.5601 - total loss: 0.8804 - val_accuracy: 0.7000 - val_loss: 1.3264 - learning_rate: 1.0000e-04
# Epoch 45/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.7881 - alpha: 0.0000e+00 - ce_loss: 0.8767 - embedding_loss: 0.1000 - f1_score: 0.5506 - loss: 0.8772 - precision: 0.7581 - recall: 0.5638 - total loss: 0.8767 - val_accuracy: 0.6683 - val_loss: 1.3518 - learning_rate: 1.0000e-04
# Epoch 46/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.8031 - alpha: 0.0000e+00 - ce_loss: 0.8342 - embedding_loss: 0.1047 - f1_score: 0.5527 - loss: 0.8522 - precision: 0.7602 - recall: 0.5674 - total loss: 0.8342 - val_accuracy: 0.6950 - val_loss: 1.3390 - learning_rate: 1.0000e-04
# Epoch 47/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.8078 - alpha: 0.0000e+00 - ce_loss: 0.8237 - embedding_loss: 0.1036 - f1_score: 0.5548 - loss: 0.8158 - precision: 0.7623 - recall: 0.5711 - total loss: 0.8237 - val_accuracy: 0.6950 - val_loss: 1.3002 - learning_rate: 1.0000e-04
# Epoch 48/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.8166 - alpha: 0.0000e+00 - ce_loss: 0.7903 - embedding_loss: 0.1034 - f1_score: 0.5569 - loss: 0.7938 - precision: 0.7645 - recall: 0.5749 - total loss: 0.7903 - val_accuracy: 0.6767 - val_loss: 1.3576 - learning_rate: 1.0000e-04
# Epoch 49/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.8294 - alpha: 0.0000e+00 - ce_loss: 0.7685 - embedding_loss: 0.1082 - f1_score: 0.5590 - loss: 0.7793 - precision: 0.7667 - recall: 0.5787 - total loss: 0.7685 - val_accuracy: 0.6717 - val_loss: 1.4522 - learning_rate: 1.0000e-04
# Epoch 50/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.8288 - alpha: 0.0000e+00 - ce_loss: 0.7515 - embedding_loss: 0.1070 - f1_score: 0.5611 - loss: 0.7429 - precision: 0.7689 - recall: 0.5825 - total loss: 0.7515 - val_accuracy: 0.7000 - val_loss: 1.3481 - learning_rate: 1.0000e-04
# Epoch 51/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.8445 - alpha: 0.0000e+00 - ce_loss: 0.7463 - embedding_loss: 0.1068 - f1_score: 0.5631 - loss: 0.7201 - precision: 0.7711 - recall: 0.5864 - total loss: 0.7463
# Epoch 51: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.8444 - alpha: 0.0000e+00 - ce_loss: 0.7463 - embedding_loss: 0.1068 - f1_score: 0.5631 - loss: 0.7203 - precision: 0.7711 - recall: 0.5864 - total loss: 0.7463 - val_accuracy: 0.6967 - val_loss: 1.3151 - learning_rate: 1.0000e-04
# Epoch 52/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 324ms/step - accuracy: 0.8446 - alpha: 0.0000e+00 - ce_loss: 0.6835 - embedding_loss: 0.1066 - f1_score: 0.5652 - loss: 0.6845 - precision: 0.7733 - recall: 0.5902 - total loss: 0.6835 - val_accuracy: 0.7033 - val_loss: 1.3498 - learning_rate: 5.0000e-05
# Epoch 53/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.8625 - alpha: 0.0000e+00 - ce_loss: 0.6480 - embedding_loss: 0.1115 - f1_score: 0.5672 - loss: 0.6503 - precision: 0.7756 - recall: 0.5941 - total loss: 0.6480 - val_accuracy: 0.6867 - val_loss: 1.4317 - learning_rate: 5.0000e-05
# Epoch 54/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.8691 - alpha: 0.0000e+00 - ce_loss: 0.6272 - embedding_loss: 0.1139 - f1_score: 0.5692 - loss: 0.6242 - precision: 0.7779 - recall: 0.5981 - total loss: 0.6272 - val_accuracy: 0.6883 - val_loss: 1.3794 - learning_rate: 5.0000e-05
# Epoch 55/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.8645 - alpha: 0.0000e+00 - ce_loss: 0.6226 - embedding_loss: 0.1133 - f1_score: 0.5712 - loss: 0.6182 - precision: 0.7802 - recall: 0.6019 - total loss: 0.6226 - val_accuracy: 0.6867 - val_loss: 1.3659 - learning_rate: 5.0000e-05
# Epoch 56/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.8691 - alpha: 0.0000e+00 - ce_loss: 0.6160 - embedding_loss: 0.1150 - f1_score: 0.5732 - loss: 0.6190 - precision: 0.7823 - recall: 0.6056 - total loss: 0.6160 - val_accuracy: 0.6950 - val_loss: 1.4126 - learning_rate: 5.0000e-05
# Epoch 57/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.8659 - alpha: 0.0000e+00 - ce_loss: 0.5977 - embedding_loss: 0.1169 - f1_score: 0.5752 - loss: 0.5989 - precision: 0.7844 - recall: 0.6093 - total loss: 0.5977 - val_accuracy: 0.6767 - val_loss: 1.4307 - learning_rate: 5.0000e-05
# Epoch 58/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.8798 - alpha: 0.0000e+00 - ce_loss: 0.5902 - embedding_loss: 0.1189 - f1_score: 0.5771 - loss: 0.5764 - precision: 0.7866 - recall: 0.6130 - total loss: 0.5902 - val_accuracy: 0.6817 - val_loss: 1.4010 - learning_rate: 5.0000e-05
# Epoch 59/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.8782 - alpha: 0.0000e+00 - ce_loss: 0.5808 - embedding_loss: 0.1174 - f1_score: 0.5790 - loss: 0.5706 - precision: 0.7886 - recall: 0.6165 - total loss: 0.5808 - val_accuracy: 0.6917 - val_loss: 1.4342 - learning_rate: 5.0000e-05
# Epoch 60/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.8757 - alpha: 0.0000e+00 - ce_loss: 0.5826 - embedding_loss: 0.1181 - f1_score: 0.5810 - loss: 0.5811 - precision: 0.7906 - recall: 0.6200 - total loss: 0.5826 - val_accuracy: 0.6950 - val_loss: 1.3373 - learning_rate: 5.0000e-05
# Epoch 60: early stopping
# Restoring model weights from the end of the best epoch: 41.
# Test accuracy: 0.7116666436195374, Training accuracy: 0.8294767737388611, Validation accuracy: 0.7049999833106995 for params: {'alpha': 0}
# Testing params: {'alpha': 0.25}
# Epoch 1/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 52s 329ms/step - accuracy: 0.3875 - alpha: 0.2500 - ce_loss: 38.8068 - embedding_loss: 0.1121 - f1_score: 0.2684 - loss: 31.5605 - precision: 0.4458 - recall: 0.2439 - total loss: 29.1331 - val_accuracy: 0.5817 - val_loss: 24.4643 - learning_rate: 1.0000e-04
# Epoch 2/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.5174 - alpha: 0.2500 - ce_loss: 27.4603 - embedding_loss: 0.0679 - f1_score: 0.3308 - loss: 22.5104 - precision: 0.5729 - recall: 0.2719 - total loss: 20.6122 - val_accuracy: 0.5667 - val_loss: 16.9100 - learning_rate: 1.0000e-04
# Epoch 3/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 324ms/step - accuracy: 0.5145 - alpha: 0.2500 - ce_loss: 18.6687 - embedding_loss: 0.0616 - f1_score: 0.3528 - loss: 15.4231 - precision: 0.6027 - recall: 0.2949 - total loss: 14.0169 - val_accuracy: 0.6017 - val_loss: 11.3466 - learning_rate: 1.0000e-04
# Epoch 4/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 324ms/step - accuracy: 0.5347 - alpha: 0.2500 - ce_loss: 12.4306 - embedding_loss: 0.0573 - f1_score: 0.3684 - loss: 10.3097 - precision: 0.6207 - recall: 0.3124 - total loss: 9.3373 - val_accuracy: 0.6083 - val_loss: 7.4909 - learning_rate: 1.0000e-04
# Epoch 5/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.5856 - alpha: 0.2500 - ce_loss: 8.2762 - embedding_loss: 0.0560 - f1_score: 0.3812 - loss: 6.8260 - precision: 0.6361 - recall: 0.3295 - total loss: 6.2211 - val_accuracy: 0.5950 - val_loss: 5.0797 - learning_rate: 1.0000e-04
# Epoch 6/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.5745 - alpha: 0.2500 - ce_loss: 5.7177 - embedding_loss: 0.0544 - f1_score: 0.3922 - loss: 4.6778 - precision: 0.6460 - recall: 0.3415 - total loss: 4.3018 - val_accuracy: 0.6217 - val_loss: 3.6209 - learning_rate: 1.0000e-04
# Epoch 7/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 324ms/step - accuracy: 0.5846 - alpha: 0.2500 - ce_loss: 4.3010 - embedding_loss: 0.0570 - f1_score: 0.4016 - loss: 3.4268 - precision: 0.6535 - recall: 0.3530 - total loss: 3.2400 - val_accuracy: 0.6550 - val_loss: 2.8487 - learning_rate: 1.0000e-04
# Epoch 8/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.5988 - alpha: 0.2500 - ce_loss: 3.4558 - embedding_loss: 0.0562 - f1_score: 0.4100 - loss: 2.7198 - precision: 0.6605 - recall: 0.3644 - total loss: 2.6059 - val_accuracy: 0.6317 - val_loss: 2.3761 - learning_rate: 1.0000e-04
# Epoch 9/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.6344 - alpha: 0.2500 - ce_loss: 2.9480 - embedding_loss: 0.0593 - f1_score: 0.4177 - loss: 2.2750 - precision: 0.6668 - recall: 0.3758 - total loss: 2.2258 - val_accuracy: 0.6467 - val_loss: 2.0456 - learning_rate: 1.0000e-04
# Epoch 10/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.6204 - alpha: 0.2500 - ce_loss: 2.6126 - embedding_loss: 0.0613 - f1_score: 0.4249 - loss: 2.0297 - precision: 0.6727 - recall: 0.3862 - total loss: 1.9748 - val_accuracy: 0.6433 - val_loss: 1.8558 - learning_rate: 1.0000e-04
# Epoch 11/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.6371 - alpha: 0.2500 - ce_loss: 2.3801 - embedding_loss: 0.0632 - f1_score: 0.4317 - loss: 1.8197 - precision: 0.6785 - recall: 0.3963 - total loss: 1.8009 - val_accuracy: 0.5650 - val_loss: 2.0486 - learning_rate: 1.0000e-04
# Epoch 12/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.6325 - alpha: 0.2500 - ce_loss: 2.1920 - embedding_loss: 0.0632 - f1_score: 0.4380 - loss: 1.6866 - precision: 0.6815 - recall: 0.4037 - total loss: 1.6598 - val_accuracy: 0.6533 - val_loss: 1.6442 - learning_rate: 1.0000e-04
# Epoch 13/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.6409 - alpha: 0.2500 - ce_loss: 2.0274 - embedding_loss: 0.0637 - f1_score: 0.4439 - loss: 1.5536 - precision: 0.6870 - recall: 0.4125 - total loss: 1.5365 - val_accuracy: 0.6450 - val_loss: 1.5820 - learning_rate: 1.0000e-04
# Epoch 14/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.6549 - alpha: 0.2500 - ce_loss: 1.9021 - embedding_loss: 0.0614 - f1_score: 0.4495 - loss: 1.4570 - precision: 0.6912 - recall: 0.4197 - total loss: 1.4420 - val_accuracy: 0.6500 - val_loss: 1.4599 - learning_rate: 1.0000e-04
# Epoch 15/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.6460 - alpha: 0.2500 - ce_loss: 1.8012 - embedding_loss: 0.0623 - f1_score: 0.4548 - loss: 1.4063 - precision: 0.6956 - recall: 0.4272 - total loss: 1.3665 - val_accuracy: 0.6217 - val_loss: 1.4035 - learning_rate: 1.0000e-04
# Epoch 16/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.6648 - alpha: 0.2500 - ce_loss: 1.7356 - embedding_loss: 0.0614 - f1_score: 0.4598 - loss: 1.3260 - precision: 0.6996 - recall: 0.4344 - total loss: 1.3171 - val_accuracy: 0.6783 - val_loss: 1.3226 - learning_rate: 1.0000e-04
# Epoch 17/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.6684 - alpha: 0.2500 - ce_loss: 1.6583 - embedding_loss: 0.0614 - f1_score: 0.4646 - loss: 1.2699 - precision: 0.7027 - recall: 0.4408 - total loss: 1.2591 - val_accuracy: 0.6767 - val_loss: 1.2599 - learning_rate: 1.0000e-04
# Epoch 18/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.6934 - alpha: 0.2500 - ce_loss: 1.5722 - embedding_loss: 0.0656 - f1_score: 0.4692 - loss: 1.1803 - precision: 0.7067 - recall: 0.4471 - total loss: 1.1955 - val_accuracy: 0.6033 - val_loss: 1.5069 - learning_rate: 1.0000e-04
# Epoch 19/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.6624 - alpha: 0.2500 - ce_loss: 1.5433 - embedding_loss: 0.0654 - f1_score: 0.4736 - loss: 1.1891 - precision: 0.7089 - recall: 0.4523 - total loss: 1.1738 - val_accuracy: 0.6550 - val_loss: 1.2799 - learning_rate: 1.0000e-04
# Epoch 20/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.6899 - alpha: 0.2500 - ce_loss: 1.4758 - embedding_loss: 0.0668 - f1_score: 0.4778 - loss: 1.1253 - precision: 0.7121 - recall: 0.4580 - total loss: 1.1236 - val_accuracy: 0.6817 - val_loss: 1.2088 - learning_rate: 1.0000e-04
# Epoch 21/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.7005 - alpha: 0.2500 - ce_loss: 1.4401 - embedding_loss: 0.0692 - f1_score: 0.4818 - loss: 1.0791 - precision: 0.7151 - recall: 0.4641 - total loss: 1.0974 - val_accuracy: 0.5150 - val_loss: 1.5870 - learning_rate: 1.0000e-04
# Epoch 22/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.6900 - alpha: 0.2500 - ce_loss: 1.4042 - embedding_loss: 0.0672 - f1_score: 0.4857 - loss: 1.0630 - precision: 0.7166 - recall: 0.4684 - total loss: 1.0699 - val_accuracy: 0.6200 - val_loss: 1.4316 - learning_rate: 1.0000e-04
# Epoch 23/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.6912 - alpha: 0.2500 - ce_loss: 1.3585 - embedding_loss: 0.0665 - f1_score: 0.4894 - loss: 1.0566 - precision: 0.7188 - recall: 0.4734 - total loss: 1.0355 - val_accuracy: 0.6767 - val_loss: 1.1259 - learning_rate: 1.0000e-04
# Epoch 24/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.6955 - alpha: 0.2500 - ce_loss: 1.3385 - embedding_loss: 0.0673 - f1_score: 0.4930 - loss: 1.0293 - precision: 0.7216 - recall: 0.4788 - total loss: 1.0207 - val_accuracy: 0.6683 - val_loss: 1.1422 - learning_rate: 1.0000e-04
# Epoch 25/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 324ms/step - accuracy: 0.7030 - alpha: 0.2500 - ce_loss: 1.2964 - embedding_loss: 0.0692 - f1_score: 0.4964 - loss: 1.0048 - precision: 0.7243 - recall: 0.4839 - total loss: 0.9896 - val_accuracy: 0.6933 - val_loss: 1.0946 - learning_rate: 1.0000e-04
# Epoch 26/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.7033 - alpha: 0.2500 - ce_loss: 1.2850 - embedding_loss: 0.0675 - f1_score: 0.4998 - loss: 0.9688 - precision: 0.7270 - recall: 0.4890 - total loss: 0.9806 - val_accuracy: 0.6033 - val_loss: 1.2660 - learning_rate: 1.0000e-04
# Epoch 27/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.7143 - alpha: 0.2500 - ce_loss: 1.2408 - embedding_loss: 0.0674 - f1_score: 0.5031 - loss: 0.9529 - precision: 0.7291 - recall: 0.4930 - total loss: 0.9474 - val_accuracy: 0.6800 - val_loss: 1.0384 - learning_rate: 1.0000e-04
# Epoch 28/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.7207 - alpha: 0.2500 - ce_loss: 1.2339 - embedding_loss: 0.0689 - f1_score: 0.5063 - loss: 0.9245 - precision: 0.7316 - recall: 0.4976 - total loss: 0.9426 - val_accuracy: 0.6933 - val_loss: 1.0391 - learning_rate: 1.0000e-04
# Epoch 29/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.7031 - alpha: 0.2500 - ce_loss: 1.2202 - embedding_loss: 0.0706 - f1_score: 0.5094 - loss: 0.9385 - precision: 0.7336 - recall: 0.5018 - total loss: 0.9328 - val_accuracy: 0.6833 - val_loss: 1.0315 - learning_rate: 1.0000e-04
# Epoch 30/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.7343 - alpha: 0.2500 - ce_loss: 1.1839 - embedding_loss: 0.0709 - f1_score: 0.5124 - loss: 0.8873 - precision: 0.7360 - recall: 0.5061 - total loss: 0.9056 - val_accuracy: 0.6500 - val_loss: 1.2019 - learning_rate: 1.0000e-04
# Epoch 31/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.7271 - alpha: 0.2500 - ce_loss: 1.1689 - embedding_loss: 0.0721 - f1_score: 0.5153 - loss: 0.8904 - precision: 0.7378 - recall: 0.5100 - total loss: 0.8947 - val_accuracy: 0.6967 - val_loss: 0.9886 - learning_rate: 1.0000e-04
# Epoch 32/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.7446 - alpha: 0.2500 - ce_loss: 1.1265 - embedding_loss: 0.0742 - f1_score: 0.5181 - loss: 0.8554 - precision: 0.7401 - recall: 0.5142 - total loss: 0.8635 - val_accuracy: 0.7000 - val_loss: 1.0256 - learning_rate: 1.0000e-04
# Epoch 33/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.7420 - alpha: 0.2500 - ce_loss: 1.1187 - embedding_loss: 0.0736 - f1_score: 0.5209 - loss: 0.8465 - precision: 0.7423 - recall: 0.5184 - total loss: 0.8574 - val_accuracy: 0.7050 - val_loss: 1.0291 - learning_rate: 1.0000e-04
# Epoch 34/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.7415 - alpha: 0.2500 - ce_loss: 1.0870 - embedding_loss: 0.0751 - f1_score: 0.5237 - loss: 0.8376 - precision: 0.7442 - recall: 0.5225 - total loss: 0.8340 - val_accuracy: 0.6883 - val_loss: 1.0463 - learning_rate: 1.0000e-04
# Epoch 35/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.7540 - alpha: 0.2500 - ce_loss: 1.0746 - embedding_loss: 0.0758 - f1_score: 0.5263 - loss: 0.8136 - precision: 0.7464 - recall: 0.5268 - total loss: 0.8249 - val_accuracy: 0.6433 - val_loss: 1.0815 - learning_rate: 1.0000e-04
# Epoch 36/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.7665 - alpha: 0.2500 - ce_loss: 1.0685 - embedding_loss: 0.0753 - f1_score: 0.5290 - loss: 0.8057 - precision: 0.7484 - recall: 0.5307 - total loss: 0.8202 - val_accuracy: 0.6783 - val_loss: 1.0758 - learning_rate: 1.0000e-04
# Epoch 37/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.7622 - alpha: 0.2500 - ce_loss: 1.0293 - embedding_loss: 0.0742 - f1_score: 0.5315 - loss: 0.7883 - precision: 0.7505 - recall: 0.5346 - total loss: 0.7905 - val_accuracy: 0.6933 - val_loss: 1.0353 - learning_rate: 1.0000e-04
# Epoch 38/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.7765 - alpha: 0.2500 - ce_loss: 1.0069 - embedding_loss: 0.0769 - f1_score: 0.5341 - loss: 0.7531 - precision: 0.7525 - recall: 0.5388 - total loss: 0.7744 - val_accuracy: 0.6900 - val_loss: 1.0178 - learning_rate: 1.0000e-04
# Epoch 39/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.7654 - alpha: 0.2500 - ce_loss: 0.9783 - embedding_loss: 0.0769 - f1_score: 0.5365 - loss: 0.7566 - precision: 0.7546 - recall: 0.5427 - total loss: 0.7530 - val_accuracy: 0.6967 - val_loss: 1.0203 - learning_rate: 1.0000e-04
# Epoch 40/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.7900 - alpha: 0.2500 - ce_loss: 0.9530 - embedding_loss: 0.0790 - f1_score: 0.5390 - loss: 0.7180 - precision: 0.7568 - recall: 0.5468 - total loss: 0.7345 - val_accuracy: 0.6800 - val_loss: 1.0660 - learning_rate: 1.0000e-04
# Epoch 41/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.7759 - alpha: 0.2500 - ce_loss: 0.9534 - embedding_loss: 0.0782 - f1_score: 0.5414 - loss: 0.7382 - precision: 0.7587 - recall: 0.5505 - total loss: 0.7346
# Epoch 41: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.7759 - alpha: 0.2500 - ce_loss: 0.9534 - embedding_loss: 0.0782 - f1_score: 0.5414 - loss: 0.7382 - precision: 0.7587 - recall: 0.5505 - total loss: 0.7346 - val_accuracy: 0.6767 - val_loss: 1.0384 - learning_rate: 1.0000e-04
# Epoch 42/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.8165 - alpha: 0.2500 - ce_loss: 0.8797 - embedding_loss: 0.0798 - f1_score: 0.5438 - loss: 0.6687 - precision: 0.7609 - recall: 0.5545 - total loss: 0.6797 - val_accuracy: 0.6417 - val_loss: 1.1610 - learning_rate: 5.0000e-05
# Epoch 43/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.8023 - alpha: 0.2500 - ce_loss: 0.8607 - embedding_loss: 0.0805 - f1_score: 0.5461 - loss: 0.6695 - precision: 0.7631 - recall: 0.5584 - total loss: 0.6657 - val_accuracy: 0.6600 - val_loss: 1.1046 - learning_rate: 5.0000e-05
# Epoch 44/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.8132 - alpha: 0.2500 - ce_loss: 0.8296 - embedding_loss: 0.0814 - f1_score: 0.5484 - loss: 0.6471 - precision: 0.7652 - recall: 0.5624 - total loss: 0.6425 - val_accuracy: 0.6900 - val_loss: 0.9868 - learning_rate: 5.0000e-05
# Epoch 45/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.8233 - alpha: 0.2500 - ce_loss: 0.8199 - embedding_loss: 0.0822 - f1_score: 0.5507 - loss: 0.6268 - precision: 0.7676 - recall: 0.5667 - total loss: 0.6354 - val_accuracy: 0.6983 - val_loss: 0.9903 - learning_rate: 5.0000e-05
# Epoch 46/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.8221 - alpha: 0.2500 - ce_loss: 0.8218 - embedding_loss: 0.0809 - f1_score: 0.5530 - loss: 0.6255 - precision: 0.7698 - recall: 0.5706 - total loss: 0.6366 - val_accuracy: 0.6550 - val_loss: 1.1133 - learning_rate: 5.0000e-05
# Epoch 47/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.8215 - alpha: 0.2500 - ce_loss: 0.7923 - embedding_loss: 0.0828 - f1_score: 0.5552 - loss: 0.6135 - precision: 0.7719 - recall: 0.5744 - total loss: 0.6149 - val_accuracy: 0.6800 - val_loss: 1.0329 - learning_rate: 5.0000e-05
# Epoch 48/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.8231 - alpha: 0.2500 - ce_loss: 0.7809 - embedding_loss: 0.0820 - f1_score: 0.5574 - loss: 0.6073 - precision: 0.7741 - recall: 0.5783 - total loss: 0.6062 - val_accuracy: 0.6350 - val_loss: 1.2469 - learning_rate: 5.0000e-05
# Epoch 49/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.8245 - alpha: 0.2500 - ce_loss: 0.7783 - embedding_loss: 0.0824 - f1_score: 0.5596 - loss: 0.6021 - precision: 0.7760 - recall: 0.5820 - total loss: 0.6043 - val_accuracy: 0.6917 - val_loss: 0.9966 - learning_rate: 5.0000e-05
# Epoch 50/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.8329 - alpha: 0.2500 - ce_loss: 0.7629 - embedding_loss: 0.0829 - f1_score: 0.5618 - loss: 0.5927 - precision: 0.7780 - recall: 0.5857 - total loss: 0.5929 - val_accuracy: 0.6867 - val_loss: 1.0459 - learning_rate: 5.0000e-05
# Epoch 51/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.8293 - alpha: 0.2500 - ce_loss: 0.7568 - embedding_loss: 0.0828 - f1_score: 0.5639 - loss: 0.5954 - precision: 0.7800 - recall: 0.5893 - total loss: 0.5883 - val_accuracy: 0.6900 - val_loss: 1.0528 - learning_rate: 5.0000e-05
# Epoch 52/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.8375 - alpha: 0.2500 - ce_loss: 0.7413 - embedding_loss: 0.0840 - f1_score: 0.5661 - loss: 0.5793 - precision: 0.7819 - recall: 0.5928 - total loss: 0.5770 - val_accuracy: 0.6833 - val_loss: 1.0326 - learning_rate: 5.0000e-05
# Epoch 53/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.8391 - alpha: 0.2500 - ce_loss: 0.7381 - embedding_loss: 0.0853 - f1_score: 0.5682 - loss: 0.5735 - precision: 0.7839 - recall: 0.5963 - total loss: 0.5749 - val_accuracy: 0.6950 - val_loss: 1.0355 - learning_rate: 5.0000e-05
# Epoch 54/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.8303 - alpha: 0.2500 - ce_loss: 0.7419 - embedding_loss: 0.0836 - f1_score: 0.5702 - loss: 0.5842 - precision: 0.7857 - recall: 0.5996 - total loss: 0.5773
# Epoch 54: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.8303 - alpha: 0.2500 - ce_loss: 0.7419 - embedding_loss: 0.0836 - f1_score: 0.5702 - loss: 0.5841 - precision: 0.7857 - recall: 0.5996 - total loss: 0.5773 - val_accuracy: 0.6533 - val_loss: 1.1845 - learning_rate: 5.0000e-05
# Epoch 55/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.8535 - alpha: 0.2500 - ce_loss: 0.6963 - embedding_loss: 0.0859 - f1_score: 0.5723 - loss: 0.5460 - precision: 0.7875 - recall: 0.6031 - total loss: 0.5437 - val_accuracy: 0.6850 - val_loss: 1.0342 - learning_rate: 2.5000e-05
# Epoch 56/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.8475 - alpha: 0.2500 - ce_loss: 0.6884 - embedding_loss: 0.0862 - f1_score: 0.5743 - loss: 0.5472 - precision: 0.7894 - recall: 0.6064 - total loss: 0.5378 - val_accuracy: 0.6867 - val_loss: 1.0548 - learning_rate: 2.5000e-05
# Epoch 57/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.8613 - alpha: 0.2500 - ce_loss: 0.6753 - embedding_loss: 0.0863 - f1_score: 0.5763 - loss: 0.5227 - precision: 0.7912 - recall: 0.6098 - total loss: 0.5281 - val_accuracy: 0.6850 - val_loss: 1.0402 - learning_rate: 2.5000e-05
# Epoch 58/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.8634 - alpha: 0.2500 - ce_loss: 0.6654 - embedding_loss: 0.0863 - f1_score: 0.5783 - loss: 0.5150 - precision: 0.7930 - recall: 0.6131 - total loss: 0.5206 - val_accuracy: 0.6850 - val_loss: 1.0704 - learning_rate: 2.5000e-05
# Epoch 59/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.8746 - alpha: 0.2500 - ce_loss: 0.6581 - embedding_loss: 0.0867 - f1_score: 0.5802 - loss: 0.5208 - precision: 0.7948 - recall: 0.6164 - total loss: 0.5152 - val_accuracy: 0.6667 - val_loss: 1.1011 - learning_rate: 2.5000e-05
# Epoch 60/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.8696 - alpha: 0.2500 - ce_loss: 0.6544 - embedding_loss: 0.0869 - f1_score: 0.5822 - loss: 0.5061 - precision: 0.7965 - recall: 0.6196 - total loss: 0.5125 - val_accuracy: 0.6450 - val_loss: 1.1761 - learning_rate: 2.5000e-05
# Epoch 61/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.8599 - alpha: 0.2500 - ce_loss: 0.6517 - embedding_loss: 0.0871 - f1_score: 0.5841 - loss: 0.5078 - precision: 0.7982 - recall: 0.6225 - total loss: 0.5105 - val_accuracy: 0.6600 - val_loss: 1.0844 - learning_rate: 2.5000e-05
# Epoch 62/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.8600 - alpha: 0.2500 - ce_loss: 0.6467 - embedding_loss: 0.0877 - f1_score: 0.5860 - loss: 0.5104 - precision: 0.7998 - recall: 0.6254 - total loss: 0.5069 - val_accuracy: 0.6850 - val_loss: 1.0644 - learning_rate: 2.5000e-05
# Epoch 63/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.8618 - alpha: 0.2500 - ce_loss: 0.6536 - embedding_loss: 0.0874 - f1_score: 0.5879 - loss: 0.5106 - precision: 0.8013 - recall: 0.6283 - total loss: 0.5120 - val_accuracy: 0.6867 - val_loss: 1.0499 - learning_rate: 2.5000e-05
# Epoch 63: early stopping
# Restoring model weights from the end of the best epoch: 44.
# Test accuracy: 0.7116666436195374, Training accuracy: 0.873254120349884, Validation accuracy: 0.6899999976158142 for params: {'alpha': 0.25}
# Testing params: {'alpha': 0.5}
# Epoch 1/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 52s 327ms/step - accuracy: 0.3573 - alpha: 0.5000 - ce_loss: 38.9169 - embedding_loss: 0.0885 - f1_score: 0.2459 - loss: 21.1241 - precision: 0.4125 - recall: 0.2025 - total loss: 19.5027 - val_accuracy: 0.5583 - val_loss: 16.3832 - learning_rate: 1.0000e-04
# Epoch 2/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.5165 - alpha: 0.5000 - ce_loss: 27.4915 - embedding_loss: 0.0536 - f1_score: 0.2918 - loss: 15.0549 - precision: 0.5568 - recall: 0.2475 - total loss: 13.7726 - val_accuracy: 0.5567 - val_loss: 11.3022 - learning_rate: 1.0000e-04
# Epoch 3/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.5429 - alpha: 0.5000 - ce_loss: 18.6940 - embedding_loss: 0.0461 - f1_score: 0.3213 - loss: 10.3004 - precision: 0.5990 - recall: 0.2773 - total loss: 9.3701 - val_accuracy: 0.6133 - val_loss: 7.5697 - learning_rate: 1.0000e-04
# Epoch 4/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.5612 - alpha: 0.5000 - ce_loss: 12.4979 - embedding_loss: 0.0414 - f1_score: 0.3424 - loss: 6.9049 - precision: 0.6219 - recall: 0.3018 - total loss: 6.2696 - val_accuracy: 0.5817 - val_loss: 5.0917 - learning_rate: 1.0000e-04
# Epoch 5/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.5740 - alpha: 0.5000 - ce_loss: 8.4151 - embedding_loss: 0.0410 - f1_score: 0.3589 - loss: 4.6451 - precision: 0.6348 - recall: 0.3187 - total loss: 4.2281 - val_accuracy: 0.6150 - val_loss: 3.4578 - learning_rate: 1.0000e-04
# Epoch 6/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.5802 - alpha: 0.5000 - ce_loss: 5.8887 - embedding_loss: 0.0409 - f1_score: 0.3724 - loss: 3.2116 - precision: 0.6461 - recall: 0.3326 - total loss: 2.9648 - val_accuracy: 0.6217 - val_loss: 2.5000 - learning_rate: 1.0000e-04
# Epoch 7/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.5961 - alpha: 0.5000 - ce_loss: 4.3812 - embedding_loss: 0.0422 - f1_score: 0.3839 - loss: 2.3507 - precision: 0.6561 - recall: 0.3466 - total loss: 2.2117 - val_accuracy: 0.5867 - val_loss: 1.9794 - learning_rate: 1.0000e-04
# Epoch 8/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.6109 - alpha: 0.5000 - ce_loss: 3.5185 - embedding_loss: 0.0427 - f1_score: 0.3942 - loss: 1.8495 - precision: 0.6635 - recall: 0.3600 - total loss: 1.7806 - val_accuracy: 0.6233 - val_loss: 1.6562 - learning_rate: 1.0000e-04
# Epoch 9/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.6199 - alpha: 0.5000 - ce_loss: 2.9934 - embedding_loss: 0.0440 - f1_score: 0.4034 - loss: 1.5668 - precision: 0.6682 - recall: 0.3708 - total loss: 1.5187 - val_accuracy: 0.6500 - val_loss: 1.3730 - learning_rate: 1.0000e-04
# Epoch 10/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.6367 - alpha: 0.5000 - ce_loss: 2.6045 - embedding_loss: 0.0429 - f1_score: 0.4118 - loss: 1.3463 - precision: 0.6756 - recall: 0.3840 - total loss: 1.3237 - val_accuracy: 0.5783 - val_loss: 1.3332 - learning_rate: 1.0000e-04
# Epoch 11/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.6283 - alpha: 0.5000 - ce_loss: 2.3559 - embedding_loss: 0.0426 - f1_score: 0.4198 - loss: 1.2260 - precision: 0.6797 - recall: 0.3939 - total loss: 1.1993 - val_accuracy: 0.6400 - val_loss: 1.1522 - learning_rate: 1.0000e-04
# Epoch 12/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.6428 - alpha: 0.5000 - ce_loss: 2.1639 - embedding_loss: 0.0425 - f1_score: 0.4270 - loss: 1.1120 - precision: 0.6852 - recall: 0.4026 - total loss: 1.1032 - val_accuracy: 0.6900 - val_loss: 1.0495 - learning_rate: 1.0000e-04
# Epoch 13/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.6530 - alpha: 0.5000 - ce_loss: 1.9831 - embedding_loss: 0.0434 - f1_score: 0.4338 - loss: 1.0225 - precision: 0.6903 - recall: 0.4107 - total loss: 1.0132 - val_accuracy: 0.5767 - val_loss: 1.1052 - learning_rate: 1.0000e-04
# Epoch 14/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.6366 - alpha: 0.5000 - ce_loss: 1.8973 - embedding_loss: 0.0428 - f1_score: 0.4401 - loss: 0.9871 - precision: 0.6937 - recall: 0.4176 - total loss: 0.9701 - val_accuracy: 0.6900 - val_loss: 0.9273 - learning_rate: 1.0000e-04
# Epoch 15/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.6478 - alpha: 0.5000 - ce_loss: 1.7968 - embedding_loss: 0.0441 - f1_score: 0.4459 - loss: 0.9325 - precision: 0.6975 - recall: 0.4244 - total loss: 0.9205 - val_accuracy: 0.6650 - val_loss: 0.9185 - learning_rate: 1.0000e-04
# Epoch 16/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.6665 - alpha: 0.5000 - ce_loss: 1.7131 - embedding_loss: 0.0433 - f1_score: 0.4514 - loss: 0.8761 - precision: 0.7010 - recall: 0.4313 - total loss: 0.8782 - val_accuracy: 0.5917 - val_loss: 0.9582 - learning_rate: 1.0000e-04
# Epoch 17/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.6682 - alpha: 0.5000 - ce_loss: 1.6294 - embedding_loss: 0.0449 - f1_score: 0.4566 - loss: 0.8359 - precision: 0.7034 - recall: 0.4375 - total loss: 0.8372 - val_accuracy: 0.6900 - val_loss: 0.8266 - learning_rate: 1.0000e-04
# Epoch 18/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.6712 - alpha: 0.5000 - ce_loss: 1.5801 - embedding_loss: 0.0445 - f1_score: 0.4615 - loss: 0.8226 - precision: 0.7069 - recall: 0.4434 - total loss: 0.8123 - val_accuracy: 0.6917 - val_loss: 0.7971 - learning_rate: 1.0000e-04
# Epoch 19/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.6714 - alpha: 0.5000 - ce_loss: 1.5301 - embedding_loss: 0.0441 - f1_score: 0.4662 - loss: 0.7882 - precision: 0.7098 - recall: 0.4489 - total loss: 0.7871 - val_accuracy: 0.6883 - val_loss: 0.7852 - learning_rate: 1.0000e-04
# Epoch 20/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.6820 - alpha: 0.5000 - ce_loss: 1.4587 - embedding_loss: 0.0451 - f1_score: 0.4706 - loss: 0.7539 - precision: 0.7129 - recall: 0.4547 - total loss: 0.7519 - val_accuracy: 0.6600 - val_loss: 0.7761 - learning_rate: 1.0000e-04
# Epoch 21/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.6758 - alpha: 0.5000 - ce_loss: 1.4361 - embedding_loss: 0.0459 - f1_score: 0.4749 - loss: 0.7444 - precision: 0.7157 - recall: 0.4599 - total loss: 0.7410 - val_accuracy: 0.5383 - val_loss: 1.0114 - learning_rate: 1.0000e-04
# Epoch 22/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.6942 - alpha: 0.5000 - ce_loss: 1.3940 - embedding_loss: 0.0449 - f1_score: 0.4790 - loss: 0.7219 - precision: 0.7171 - recall: 0.4643 - total loss: 0.7194 - val_accuracy: 0.6367 - val_loss: 0.8148 - learning_rate: 1.0000e-04
# Epoch 23/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.6868 - alpha: 0.5000 - ce_loss: 1.3493 - embedding_loss: 0.0452 - f1_score: 0.4828 - loss: 0.7125 - precision: 0.7192 - recall: 0.4687 - total loss: 0.6973 - val_accuracy: 0.6617 - val_loss: 0.7804 - learning_rate: 1.0000e-04
# Epoch 24/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.6959 - alpha: 0.5000 - ce_loss: 1.3250 - embedding_loss: 0.0452 - f1_score: 0.4865 - loss: 0.6832 - precision: 0.7219 - recall: 0.4732 - total loss: 0.6851 - val_accuracy: 0.7050 - val_loss: 0.6932 - learning_rate: 1.0000e-04
# Epoch 25/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.6952 - alpha: 0.5000 - ce_loss: 1.2940 - embedding_loss: 0.0456 - f1_score: 0.4901 - loss: 0.6662 - precision: 0.7245 - recall: 0.4779 - total loss: 0.6698 - val_accuracy: 0.5583 - val_loss: 0.9000 - learning_rate: 1.0000e-04
# Epoch 26/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.6917 - alpha: 0.5000 - ce_loss: 1.2596 - embedding_loss: 0.0465 - f1_score: 0.4935 - loss: 0.6682 - precision: 0.7264 - recall: 0.4819 - total loss: 0.6530 - val_accuracy: 0.6900 - val_loss: 0.6948 - learning_rate: 1.0000e-04
# Epoch 27/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.7093 - alpha: 0.5000 - ce_loss: 1.2553 - embedding_loss: 0.0455 - f1_score: 0.4969 - loss: 0.6491 - precision: 0.7291 - recall: 0.4865 - total loss: 0.6504 - val_accuracy: 0.6550 - val_loss: 0.7212 - learning_rate: 1.0000e-04
# Epoch 28/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.7081 - alpha: 0.5000 - ce_loss: 1.2286 - embedding_loss: 0.0475 - f1_score: 0.5001 - loss: 0.6295 - precision: 0.7312 - recall: 0.4905 - total loss: 0.6381 - val_accuracy: 0.6333 - val_loss: 0.7298 - learning_rate: 1.0000e-04
# Epoch 29/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.7075 - alpha: 0.5000 - ce_loss: 1.2082 - embedding_loss: 0.0459 - f1_score: 0.5032 - loss: 0.6267 - precision: 0.7329 - recall: 0.4943 - total loss: 0.6271 - val_accuracy: 0.6933 - val_loss: 0.6894 - learning_rate: 1.0000e-04
# Epoch 30/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.7291 - alpha: 0.5000 - ce_loss: 1.1745 - embedding_loss: 0.0463 - f1_score: 0.5062 - loss: 0.6038 - precision: 0.7351 - recall: 0.4981 - total loss: 0.6104 - val_accuracy: 0.6683 - val_loss: 0.7109 - learning_rate: 1.0000e-04
# Epoch 31/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.7289 - alpha: 0.5000 - ce_loss: 1.1492 - embedding_loss: 0.0462 - f1_score: 0.5092 - loss: 0.5924 - precision: 0.7371 - recall: 0.5022 - total loss: 0.5977 - val_accuracy: 0.6533 - val_loss: 0.7087 - learning_rate: 1.0000e-04
# Epoch 32/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.7227 - alpha: 0.5000 - ce_loss: 1.1388 - embedding_loss: 0.0467 - f1_score: 0.5120 - loss: 0.5946 - precision: 0.7391 - recall: 0.5059 - total loss: 0.5928 - val_accuracy: 0.6767 - val_loss: 0.6771 - learning_rate: 1.0000e-04
# Epoch 33/100
# ...
# Epoch 58/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.7517 - alpha: 0.7500 - ce_loss: 0.9263 - embedding_loss: 0.0239 - f1_score: 0.5565 - loss: 0.2555 - precision: 0.7806 - recall: 0.5560 - total loss: 0.2495 - val_accuracy: 0.6917 - val_loss: 0.3264 - learning_rate: 5.0000e-05
# Epoch 59/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.7758 - alpha: 0.7500 - ce_loss: 0.8895 - embedding_loss: 0.0242 - f1_score: 0.5581 - loss: 0.2379 - precision: 0.7819 - recall: 0.5585 - total loss: 0.2405 - val_accuracy: 0.6967 - val_loss: 0.3209 - learning_rate: 5.0000e-05
# Epoch 60/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.7844 - alpha: 0.7500 - ce_loss: 0.8864 - embedding_loss: 0.0246 - f1_score: 0.5597 - loss: 0.2329 - precision: 0.7831 - recall: 0.5610 - total loss: 0.2400 - val_accuracy: 0.7033 - val_loss: 0.3193 - learning_rate: 5.0000e-05
# Epoch 61/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.7763 - alpha: 0.7500 - ce_loss: 0.8881 - embedding_loss: 0.0248 - f1_score: 0.5612 - loss: 0.2403 - precision: 0.7842 - recall: 0.5632 - total loss: 0.2406 - val_accuracy: 0.6850 - val_loss: 0.3224 - learning_rate: 5.0000e-05
# Epoch 62/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.7665 - alpha: 0.7500 - ce_loss: 0.8812 - embedding_loss: 0.0243 - f1_score: 0.5628 - loss: 0.2368 - precision: 0.7853 - recall: 0.5654 - total loss: 0.2386 - val_accuracy: 0.6883 - val_loss: 0.3247 - learning_rate: 5.0000e-05
# Epoch 63/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.7732 - alpha: 0.7500 - ce_loss: 0.8681 - embedding_loss: 0.0245 - f1_score: 0.5643 - loss: 0.2336 - precision: 0.7863 - recall: 0.5675 - total loss: 0.2354 - val_accuracy: 0.6350 - val_loss: 0.3591 - learning_rate: 5.0000e-05
# Epoch 64/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.7704 - alpha: 0.7500 - ce_loss: 0.8650 - embedding_loss: 0.0244 - f1_score: 0.5658 - loss: 0.2379 - precision: 0.7872 - recall: 0.5695 - total loss: 0.2346 - val_accuracy: 0.6817 - val_loss: 0.3284 - learning_rate: 5.0000e-05
# Epoch 65/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.7595 - alpha: 0.7500 - ce_loss: 0.8667 - embedding_loss: 0.0243 - f1_score: 0.5673 - loss: 0.2380 - precision: 0.7882 - recall: 0.5716 - total loss: 0.2349 - val_accuracy: 0.6917 - val_loss: 0.3240 - learning_rate: 5.0000e-05
# Epoch 66/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.7696 - alpha: 0.7500 - ce_loss: 0.8603 - embedding_loss: 0.0246 - f1_score: 0.5688 - loss: 0.2356 - precision: 0.7892 - recall: 0.5736 - total loss: 0.2336 - val_accuracy: 0.7017 - val_loss: 0.3207 - learning_rate: 5.0000e-05
# Epoch 67/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.7716 - alpha: 0.7500 - ce_loss: 0.8606 - embedding_loss: 0.0244 - f1_score: 0.5702 - loss: 0.2373 - precision: 0.7902 - recall: 0.5756 - total loss: 0.2335 - val_accuracy: 0.7000 - val_loss: 0.3175 - learning_rate: 5.0000e-05
# Epoch 68/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.7801 - alpha: 0.7500 - ce_loss: 0.8421 - embedding_loss: 0.0246 - f1_score: 0.5717 - loss: 0.2282 - precision: 0.7912 - recall: 0.5776 - total loss: 0.2290 - val_accuracy: 0.6800 - val_loss: 0.3276 - learning_rate: 5.0000e-05
# Epoch 69/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.7896 - alpha: 0.7500 - ce_loss: 0.8446 - embedding_loss: 0.0245 - f1_score: 0.5731 - loss: 0.2241 - precision: 0.7922 - recall: 0.5796 - total loss: 0.2295 - val_accuracy: 0.6383 - val_loss: 0.3572 - learning_rate: 5.0000e-05
# Epoch 70/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.7845 - alpha: 0.7500 - ce_loss: 0.8401 - embedding_loss: 0.0243 - f1_score: 0.5745 - loss: 0.2246 - precision: 0.7931 - recall: 0.5814 - total loss: 0.2282 - val_accuracy: 0.6583 - val_loss: 0.3400 - learning_rate: 5.0000e-05
# Epoch 71/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.7838 - alpha: 0.7500 - ce_loss: 0.8312 - embedding_loss: 0.0245 - f1_score: 0.5759 - loss: 0.2226 - precision: 0.7940 - recall: 0.5833 - total loss: 0.2262 - val_accuracy: 0.6950 - val_loss: 0.3227 - learning_rate: 5.0000e-05
# Epoch 72/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.7823 - alpha: 0.7500 - ce_loss: 0.8354 - embedding_loss: 0.0243 - f1_score: 0.5772 - loss: 0.2262 - precision: 0.7949 - recall: 0.5852 - total loss: 0.2270 - val_accuracy: 0.6850 - val_loss: 0.3290 - learning_rate: 5.0000e-05
# Epoch 73/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.7761 - alpha: 0.7500 - ce_loss: 0.8229 - embedding_loss: 0.0241 - f1_score: 0.5786 - loss: 0.2260 - precision: 0.7958 - recall: 0.5869 - total loss: 0.2238 - val_accuracy: 0.6600 - val_loss: 0.3532 - learning_rate: 5.0000e-05
# Epoch 74/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.7838 - alpha: 0.7500 - ce_loss: 0.8244 - embedding_loss: 0.0241 - f1_score: 0.5799 - loss: 0.2246 - precision: 0.7966 - recall: 0.5886 - total loss: 0.2242 - val_accuracy: 0.7033 - val_loss: 0.3179 - learning_rate: 5.0000e-05
# Epoch 75/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.7891 - alpha: 0.7500 - ce_loss: 0.8123 - embedding_loss: 0.0241 - f1_score: 0.5812 - loss: 0.2201 - precision: 0.7975 - recall: 0.5904 - total loss: 0.2212 - val_accuracy: 0.6900 - val_loss: 0.3262 - learning_rate: 5.0000e-05
# Epoch 76/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.7913 - alpha: 0.7500 - ce_loss: 0.8241 - embedding_loss: 0.0242 - f1_score: 0.5825 - loss: 0.2217 - precision: 0.7984 - recall: 0.5921 - total loss: 0.2242 - val_accuracy: 0.6817 - val_loss: 0.3394 - learning_rate: 5.0000e-05
# Epoch 77/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.7883 - alpha: 0.7500 - ce_loss: 0.8161 - embedding_loss: 0.0244 - f1_score: 0.5838 - loss: 0.2219 - precision: 0.7992 - recall: 0.5937 - total loss: 0.2223
# Epoch 77: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.7883 - alpha: 0.7500 - ce_loss: 0.8161 - embedding_loss: 0.0244 - f1_score: 0.5838 - loss: 0.2219 - precision: 0.7992 - recall: 0.5937 - total loss: 0.2223 - val_accuracy: 0.7017 - val_loss: 0.3242 - learning_rate: 5.0000e-05
# Epoch 78/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.7824 - alpha: 0.7500 - ce_loss: 0.7976 - embedding_loss: 0.0242 - f1_score: 0.5851 - loss: 0.2222 - precision: 0.8000 - recall: 0.5953 - total loss: 0.2176 - val_accuracy: 0.6950 - val_loss: 0.3230 - learning_rate: 2.5000e-05
# Epoch 79/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.7948 - alpha: 0.7500 - ce_loss: 0.7842 - embedding_loss: 0.0247 - f1_score: 0.5863 - loss: 0.2104 - precision: 0.8009 - recall: 0.5970 - total loss: 0.2146 - val_accuracy: 0.6950 - val_loss: 0.3207 - learning_rate: 2.5000e-05
# Epoch 80/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.8014 - alpha: 0.7500 - ce_loss: 0.7624 - embedding_loss: 0.0246 - f1_score: 0.5876 - loss: 0.2065 - precision: 0.8018 - recall: 0.5987 - total loss: 0.2090 - val_accuracy: 0.6917 - val_loss: 0.3239 - learning_rate: 2.5000e-05
# Epoch 81/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.8047 - alpha: 0.7500 - ce_loss: 0.7747 - embedding_loss: 0.0244 - f1_score: 0.5888 - loss: 0.2092 - precision: 0.8026 - recall: 0.6004 - total loss: 0.2120 - val_accuracy: 0.6967 - val_loss: 0.3214 - learning_rate: 2.5000e-05
# Epoch 82/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.8038 - alpha: 0.7500 - ce_loss: 0.7627 - embedding_loss: 0.0244 - f1_score: 0.5900 - loss: 0.2067 - precision: 0.8035 - recall: 0.6020 - total loss: 0.2090 - val_accuracy: 0.7017 - val_loss: 0.3225 - learning_rate: 2.5000e-05
# Epoch 83/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.7992 - alpha: 0.7500 - ce_loss: 0.7651 - embedding_loss: 0.0247 - f1_score: 0.5912 - loss: 0.2088 - precision: 0.8044 - recall: 0.6037 - total loss: 0.2098 - val_accuracy: 0.6983 - val_loss: 0.3202 - learning_rate: 2.5000e-05
# Epoch 84/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.7978 - alpha: 0.7500 - ce_loss: 0.7574 - embedding_loss: 0.0244 - f1_score: 0.5924 - loss: 0.2077 - precision: 0.8052 - recall: 0.6052 - total loss: 0.2076 - val_accuracy: 0.6983 - val_loss: 0.3223 - learning_rate: 2.5000e-05
# Epoch 85/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.7971 - alpha: 0.7500 - ce_loss: 0.7584 - embedding_loss: 0.0244 - f1_score: 0.5936 - loss: 0.2094 - precision: 0.8060 - recall: 0.6068 - total loss: 0.2079 - val_accuracy: 0.6950 - val_loss: 0.3217 - learning_rate: 2.5000e-05
# Epoch 86/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.7928 - alpha: 0.7500 - ce_loss: 0.7595 - embedding_loss: 0.0244 - f1_score: 0.5947 - loss: 0.2099 - precision: 0.8068 - recall: 0.6083 - total loss: 0.2082 - val_accuracy: 0.6917 - val_loss: 0.3201 - learning_rate: 2.5000e-05
# Epoch 86: early stopping
# Restoring model weights from the end of the best epoch: 67.
# Test accuracy: 0.7049999833106995, Training accuracy: 0.8346883654594421, Validation accuracy: 0.699999988079071 for params: {'alpha': 0.75}
# Testing params: {'alpha': 1}
# Epoch 1/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 52s 329ms/step - accuracy: 0.1414 - alpha: 1.0000 - ce_loss: 44.6275 - embedding_loss: 0.0057 - f1_score: 0.0101 - loss: 0.0212 - precision: 0.0543 - recall: 0.0023 - total loss: 0.0057 - val_accuracy: 0.1283 - val_loss: 0.0021 - learning_rate: 1.0000e-04
# Epoch 2/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.1487 - alpha: 1.0000 - ce_loss: 44.5897 - embedding_loss: 0.0019 - f1_score: 0.0027 - loss: 0.0019 - precision: 0.0541 - recall: 2.6452e-04 - total loss: 0.0019 - val_accuracy: 0.1283 - val_loss: 0.0021 - learning_rate: 1.0000e-04
# Epoch 3/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.1416 - alpha: 1.0000 - ce_loss: 44.5895 - embedding_loss: 0.0019 - f1_score: 0.0017 - loss: 0.0019 - precision: 0.0541 - recall: 1.5310e-04 - total loss: 0.0019 - val_accuracy: 0.1283 - val_loss: 0.0022 - learning_rate: 1.0000e-04
# Epoch 4/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.1452 - alpha: 1.0000 - ce_loss: 44.5892 - embedding_loss: 0.0019 - f1_score: 0.0013 - loss: 0.0019 - precision: 0.0541 - recall: 1.0809e-04 - total loss: 0.0019 - val_accuracy: 0.1283 - val_loss: 0.0023 - learning_rate: 1.0000e-04
# Epoch 5/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.1394 - alpha: 1.0000 - ce_loss: 44.5888 - embedding_loss: 0.0019 - f1_score: 0.0010 - loss: 0.0019 - precision: 0.0541 - recall: 8.3599e-05 - total loss: 0.0019 - val_accuracy: 0.1250 - val_loss: 0.0036 - learning_rate: 1.0000e-04
# Epoch 6/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 322ms/step - accuracy: 0.1327 - alpha: 1.0000 - ce_loss: 44.5880 - embedding_loss: 0.0019 - f1_score: 8.7626e-04 - loss: 0.0019 - precision: 0.0541 - recall: 6.8177e-05 - total loss: 0.0019 - val_accuracy: 0.1267 - val_loss: 0.0035 - learning_rate: 1.0000e-04
# Epoch 7/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.1523 - alpha: 1.0000 - ce_loss: 44.5873 - embedding_loss: 0.0019 - f1_score: 7.5935e-04 - loss: 0.0019 - precision: 0.0541 - recall: 5.7566e-05 - total loss: 0.0019 - val_accuracy: 0.1250 - val_loss: 0.0058 - learning_rate: 1.0000e-04
# Epoch 8/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.1478 - alpha: 1.0000 - ce_loss: 44.5873 - embedding_loss: 0.0019 - f1_score: 6.7152e-04 - loss: 0.0019 - precision: 0.0541 - recall: 4.9817e-05 - total loss: 0.0019 - val_accuracy: 0.1233 - val_loss: 0.0102 - learning_rate: 1.0000e-04
# Epoch 9/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.1459 - alpha: 1.0000 - ce_loss: 44.5890 - embedding_loss: 0.0019 - f1_score: 6.0295e-04 - loss: 0.0019 - precision: 0.0541 - recall: 4.3908e-05 - total loss: 0.0019 - val_accuracy: 0.1150 - val_loss: 0.0158 - learning_rate: 1.0000e-04
# Epoch 10/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.1355 - alpha: 1.0000 - ce_loss: 44.5894 - embedding_loss: 0.0019 - f1_score: 5.4782e-04 - loss: 0.0019 - precision: 0.0541 - recall: 3.9253e-05 - total loss: 0.0019 - val_accuracy: 0.1250 - val_loss: 0.0207 - learning_rate: 1.0000e-04
# Epoch 11/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.1450 - alpha: 1.0000 - ce_loss: 44.5964 - embedding_loss: 0.0019 - f1_score: 5.0246e-04 - loss: 0.0019 - precision: 0.0526 - recall: 3.5491e-05 - total loss: 0.0019
# Epoch 11: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 324ms/step - accuracy: 0.1450 - alpha: 1.0000 - ce_loss: 44.5964 - embedding_loss: 0.0019 - f1_score: 5.0246e-04 - loss: 0.0019 - precision: 0.0526 - recall: 3.5491e-05 - total loss: 0.0019 - val_accuracy: 0.1567 - val_loss: 0.0233 - learning_rate: 1.0000e-04
# Epoch 12/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.1461 - alpha: 1.0000 - ce_loss: 44.6022 - embedding_loss: 0.0018 - f1_score: 4.6445e-04 - loss: 0.0019 - precision: 0.0526 - recall: 3.2388e-05 - total loss: 0.0018 - val_accuracy: 0.1517 - val_loss: 0.0335 - learning_rate: 5.0000e-05
# Epoch 13/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.1485 - alpha: 1.0000 - ce_loss: 44.6080 - embedding_loss: 0.0018 - f1_score: 4.3209e-04 - loss: 0.0018 - precision: 0.0526 - recall: 2.9783e-05 - total loss: 0.0018 - val_accuracy: 0.1400 - val_loss: 0.0373 - learning_rate: 5.0000e-05
# Epoch 14/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.1490 - alpha: 1.0000 - ce_loss: 44.6202 - embedding_loss: 0.0017 - f1_score: 4.0420e-04 - loss: 0.0017 - precision: 0.0444 - recall: 2.7567e-05 - total loss: 0.0017 - val_accuracy: 0.1233 - val_loss: 0.0471 - learning_rate: 5.0000e-05
# Epoch 15/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.1516 - alpha: 1.0000 - ce_loss: 44.6334 - embedding_loss: 0.0016 - f1_score: 3.7988e-04 - loss: 0.0017 - precision: 0.0435 - recall: 2.5658e-05 - total loss: 0.0016 - val_accuracy: 0.1250 - val_loss: 0.0694 - learning_rate: 5.0000e-05
# Epoch 16/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.1415 - alpha: 1.0000 - ce_loss: 44.6516 - embedding_loss: 0.0016 - f1_score: 3.5849e-04 - loss: 0.0016 - precision: 0.0435 - recall: 2.3996e-05 - total loss: 0.0016 - val_accuracy: 0.1117 - val_loss: 0.0441 - learning_rate: 5.0000e-05
# Epoch 17/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.1409 - alpha: 1.0000 - ce_loss: 44.6780 - embedding_loss: 0.0015 - f1_score: 3.3951e-04 - loss: 0.0015 - precision: 0.0435 - recall: 2.2536e-05 - total loss: 0.0015 - val_accuracy: 0.1167 - val_loss: 0.0585 - learning_rate: 5.0000e-05
# Epoch 18/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - accuracy: 0.1368 - alpha: 1.0000 - ce_loss: 44.7176 - embedding_loss: 0.0014 - f1_score: 3.2255e-04 - loss: 0.0014 - precision: 0.0435 - recall: 2.1244e-05 - total loss: 0.0014 - val_accuracy: 0.0950 - val_loss: 0.0561 - learning_rate: 5.0000e-05
# Epoch 19/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 324ms/step - accuracy: 0.1385 - alpha: 1.0000 - ce_loss: 44.7761 - embedding_loss: 0.0013 - f1_score: 3.0729e-04 - loss: 0.0013 - precision: 0.0435 - recall: 2.0092e-05 - total loss: 0.0013 - val_accuracy: 0.1200 - val_loss: 0.0343 - learning_rate: 5.0000e-05
# Epoch 20/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 48s 323ms/step - accuracy: 0.1424 - alpha: 1.0000 - ce_loss: 44.8378 - embedding_loss: 0.0012 - f1_score: 2.9350e-04 - loss: 0.0012 - precision: 0.0435 - recall: 1.9058e-05 - total loss: 0.0012 - val_accuracy: 0.1317 - val_loss: 0.0255 - learning_rate: 5.0000e-05
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Test accuracy: 0.125, Training accuracy: 0.14529915153980255, Validation accuracy: 0.12833333015441895 for params: {'alpha': 1}
# Best params: {'alpha': 0} with validation accuracy: 0.7049999833106995

# %%
# Plotting
def plot_history(history_dict):
    num_combinations = len(history_dict)
    fig, axs = plt.subplots(num_combinations, 2, figsize=(15, 5 * num_combinations))
    
    if num_combinations == 1:
        axs = np.expand_dims(axs, axis=0)
    
    for i, (params, history) in enumerate(history_dict.items()):
        # param_str = f"alpha: {params[0]}, l1 = {params[1]}, l2 = {params[2]}"
        if only_alpha:
            param_str = f"alpha: {params[0]}"
        else:
            param_str = f"alpha: {params[0]}, l2 = {params[1]}"
        
        # Plot accuracy
        axs[i, 0].plot(history['accuracy'], label='Training Accuracy')
        axs[i, 0].plot(history['val_accuracy'], label='Validation Accuracy')
        axs[i, 0].set_title(f'Accuracy for {param_str}')
        axs[i, 0].set_xlabel('Epochs')
        axs[i, 0].set_ylabel('Accuracy')
        axs[i, 0].legend()
        
        # Plot loss
        axs[i, 1].plot(history['loss'], label='Training Loss')
        axs[i, 1].plot(history['val_loss'], label='Validation Loss')
        axs[i, 1].set_title(f'Loss for {param_str}')
        axs[i, 1].set_xlabel('Epochs')
        axs[i, 1].set_ylabel('Loss')
        axs[i, 1].legend()
    
    plt.tight_layout()
    plt.show()

# Call the plotting function
plot_history(history_dict)

# %%
for k, v in models.items():
    
    best_model = v
    
    # Get predictions from the best model
    predictions = best_model.predict((X_test_spec, X_test_embed_tensor))
    predicted_class_probabilities = predictions[0]  # This gives you the (1183, 8) array
    predicted_labels = np.argmax(predicted_class_probabilities, axis=1)
    ground_truth = np.argmax(y_test, axis=1)  # Converting one-hot encoded ground truth to class labels

    # Reshape predicted_labels and ground_truth to be 1D arrays
    predicted_labels = np.reshape(predicted_labels, (-1,))
    ground_truth = np.reshape(ground_truth, (-1,))

    # Calculate precision, recall, and F1 score
    test_precision = precision_score(ground_truth, predicted_labels, average='macro')
    test_recall = recall_score(ground_truth, predicted_labels, average='macro')
    test_f1_score = f1_score(ground_truth, predicted_labels, average='macro')

    results_dict[(float(str.split(k,'_')[1]),)]["test_precision"] = test_precision
    results_dict[(float(str.split(k,'_')[1]),)]["test_recall"] = test_recall
    results_dict[(float(str.split(k,'_')[1]),)]["test_f1_score"] = test_f1_score
    
    # Define class labels
    class_labels = ['ambient', 'fast', 'loud', 'quiet', 'slow', 'soft', 'weird']

    # Convert numerical labels to class labels
    predicted_labels = [class_labels[i] for i in predicted_labels]
    ground_truth = [class_labels[i] for i in ground_truth]

    # Create confusion matrix
    conf_matrix = confusion_matrix(ground_truth, predicted_labels, labels=class_labels)

    # Convert confusion matrix to DataFrame for better visualization
    conf_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

    # Plot confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix_df, annot=True, cmap='Blues', fmt='g', cbar=False)
    plt.xlabel('Predicted Class')
    plt.ylabel('Ground Truth')
    plt.title(f'Confusion Matrix for {k}')
    plt.show()
# Out:
#  7/19 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step
# /home/mendu/miniconda3/envs/myenv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step
# /home/mendu/miniconda3/envs/myenv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step
# /home/mendu/miniconda3/envs/myenv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step
# /home/mendu/miniconda3/envs/myenv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
pd.DataFrame(results_dict)
# Out:
#                     0.00      0.25      0.50      0.75      1.00
# train_accuracy  0.829477  0.873254  0.836981  0.834688  0.145299
# train_loss      0.817406  0.539549  0.404087  0.199149  0.002158
# val_accuracy    0.705000  0.690000  0.705000  0.700000  0.128333
# val_loss        1.241780  0.986763  0.644984  0.317500  0.002050
# test_accuracy   0.711667  0.711667  0.695000  0.705000  0.125000
# test_loss       1.273263  0.993993  0.678303  0.325011  0.002037
# test_precision  0.506831  0.534128  0.434452  0.455136  0.017887
# test_recall     0.478724  0.481727  0.439843  0.466827  0.142857
# test_f1_score   0.467831  0.481585  0.432029  0.459550  0.031793

# %%
with open('/home/mendu/Thesis/data/saved_models/grid_search_alpha_128_mood/result_dict.pkl', 'wb') as fp:
    pickle.dump(results_dict, fp)
    
with open('/home/mendu/Thesis/data/saved_models/grid_search_alpha_128_mood/history_dict.pkl', 'wb') as fp:
    pickle.dump(history_dict, fp)

# %%
# Assuming models and other variables are already defined
misclassified_dict = {}

# Iterate over the models and their corresponding parameter values
for model_name, model in models.items():
    # Get model predictions
    y_test_pred = model.predict((X_test_spec, X_test_embed_tensor))
    
    # Check if y_val_pred is a tuple and select the appropriate output
    if isinstance(y_test_pred, tuple):
        y_test_pred = y_test_pred[0]  # Assuming the first element is the logits or probabilities
    
    # Ensure y_val_pred is a 2D array
    if y_test_pred.ndim == 2:
        y_test_pred_labels = np.argmax(y_test_pred, axis=1)
    else:
        raise ValueError(f"Unexpected output shape {y_test_pred.shape} for model {model_name}")

    # Get the true labels
    y_test_true_labels = np.argmax(y_test, axis=1)

    # Find misclassified samples
    misclassified_indices = np.where(y_test_pred_labels != y_test_true_labels)[0]
    wrong_labels = y_test_pred_labels[misclassified_indices]
    correct_labels = y_test_true_labels[misclassified_indices]

    # Create a dataframe
    df_misclassified = pd.DataFrame({
        'Index': misclassified_indices,
        'Wrong Label': wrong_labels,
        'Correct Label': correct_labels
    })

    # Store the dataframe in the dictionary
    misclassified_dict[model_name] = df_misclassified
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step

# %%
model_0 = misclassified_dict['model_0']
model_25= misclassified_dict['model_0.25']
model_5 = misclassified_dict['model_0.5']
model_75 = misclassified_dict['model_0.75']

# %%
# Rename the Wrong Label columns for clarity
model_0 = model_0.rename(columns={'Wrong Label': 'Wrong Label_0'})
model_25 = model_25.rename(columns={'Wrong Label': 'Wrong Label_25'})
model_5 = model_5.rename(columns={'Wrong Label': 'Wrong Label_5'})
model_75 = model_75.rename(columns={'Wrong Label': 'Wrong Label_75'})
# model_1 = model_1.rename(columns={'Wrong Label': 'Wrong Label_1'})

# Merge the dataframes
merged_df = pd.merge(model_0, model_25, on=['Index', 'Correct Label'], how='outer')
merged_df = pd.merge(merged_df, model_5, on=['Index', 'Correct Label'], how='outer')
merged_df = pd.merge(merged_df, model_75, on=['Index', 'Correct Label'], how='outer')
# merged_df = pd.merge(merged_df, model_1, on=['Index', 'Correct Label'], how='outer')

# %%
# Genre mapping
genre_map = {
    0: 'ambient',
    1: 'fast',
    2: 'loud',
    3: 'quiet',
    4: 'slow',
    5: 'soft',
    6: 'weird',
}

# Replace numeric labels with genre names
columns_to_replace = ['Correct Label', 'Wrong Label_0', 'Wrong Label_25', 'Wrong Label_5', 'Wrong Label_75']
for col in columns_to_replace:
    merged_df[col] = merged_df[col].map(genre_map)

# Display the merged dataframe
merged_df
# Out:
#      Index Wrong Label_0 Correct Label Wrong Label_25 Wrong Label_5  \
# 0        8          loud         quiet           slow          fast
# 1       14          slow          fast            NaN           NaN
# 2       15          fast          loud           fast          fast
# 3       16          fast       ambient            NaN          fast
# 4       20          slow         quiet            NaN       ambient
# ..     ...           ...           ...            ...           ...
# 245    587         quiet          fast          quiet         quiet
# 246    589          fast         weird           slow          fast
# 247    590       ambient          slow            NaN       ambient
# 248    592           NaN          slow           fast           NaN
# 249    598          slow          fast           slow          slow
#
#     Wrong Label_75
# 0             fast
# 1             slow
# 2             fast
# 3              NaN
# 4              NaN
# ..             ...
# 245          quiet
# 246           slow
# 247          quiet
# 248            NaN
# 249           slow
#
# [250 rows x 6 columns]

# %%
merged_df.columns
# Out:
# Index(['Index', 'Wrong Label_0', 'Correct Label', 'Wrong Label_25',
#        'Wrong Label_5', 'Wrong Label_75'],
#       dtype='object')

# %%
merged_df = merged_df[['Index', 'Correct Label', 'Wrong Label_0', 'Wrong Label_25',
       'Wrong Label_5', 'Wrong Label_75']]

# %%
merged_df = merged_df.dropna(subset=['Wrong Label_0',  'Wrong Label_25', 'Wrong Label_5', 'Wrong Label_75'])

# %%
merged_df
# Out:
#      Index Correct Label Wrong Label_0 Wrong Label_25 Wrong Label_5  \
# 0        8         quiet          loud           slow          fast
# 2       15          loud          fast           fast          fast
# 6       23         weird          fast           fast          fast
# 7       27       ambient         weird          quiet         quiet
# 8       31         weird          fast           slow          slow
# ..     ...           ...           ...            ...           ...
# 242    583          fast          loud           loud          loud
# 244    585       ambient          fast           fast          fast
# 245    587          fast         quiet          quiet         quiet
# 246    589         weird          fast           slow          fast
# 249    598          fast          slow           slow          slow
#
#     Wrong Label_75
# 0             fast
# 2             fast
# 6             fast
# 7            quiet
# 8             fast
# ..             ...
# 242           loud
# 244           fast
# 245          quiet
# 246           slow
# 249           slow
#
# [116 rows x 6 columns]

# %%
# merged_df = merged_df[['Index', 'Correct Label', 'Wrong Label_0',  'Wrong Label_4', 'Wrong Label_5', 'Wrong Label_6']]

# Initialize a new column with zeros
merged_df['Highest Wrong Label'] = 0

# Iterate over each row to count the number of identical wrong labels
for i, row in merged_df.iterrows():
    wrong_labels = row[['Wrong Label_0',  'Wrong Label_25', 'Wrong Label_5', 'Wrong Label_75']]
    # Drop NaN values before checking uniqueness
    unique_labels = wrong_labels.dropna().value_counts().index.tolist()[0] 
    unique_labels_count = wrong_labels.dropna().value_counts().iloc[0]
    merged_df.at[i, 'Highest Wrong Label'] = unique_labels_count

# %%
merged_df['Highest Wrong Label'].value_counts()
# Out:
# Highest Wrong Label
# 4    83
# 3    22
# 2    11
# Name: count, dtype: int64

# %%
merged_df.to_csv('/home/mendu/Thesis/data/saved_models/grid_search_alpha_128_mood/error_analysis_df.csv')

# %%
# import pickle

# with open('/home/mendu/Thesis/data/magnatagatune/history_dict_gridsearch4.pkl', 'wb') as f:
#     pickle.dump(history_dict, f)

# %%
# early_stopper = EarlyStopping(monitor='val_loss', patience=5, verbose=1, restore_best_weights=True)

# history = model.fit(
#     (X_train_spec, X_train_embed_tensor),
#     y_train,
#     epochs=100,
#     batch_size=32,
#     validation_data=((X_val_spec, X_val_embed_tensor), y_val),
#     callbacks = [early_stopper]
# )

# %%
# # First, let's gather the maximum epoch number reached among all histories
# max_epoch = max([len(history['accuracy']) for history in history_dict.values()])

# # Now, for plotting purposes, let's create four separate figures
# fig_acc, ax_acc = plt.subplots()
# fig_val_acc, ax_val_acc = plt.subplots()
# fig_loss, ax_loss = plt.subplots()
# fig_val_loss, ax_val_loss = plt.subplots()

# # Now we loop through each combination's history and plot it appropriately
# for parameter_combination, history in history_dict.items():
#     num_epochs = len(history['accuracy'])
#     epochs = range(1, num_epochs + 1)

#     # Parameters string for legend label
#     params_label = f'l1_reg={parameter_combination[0]}_l2_reg={parameter_combination[1]}'

#     # Training accuracy for this combination
#     ax_acc.plot(epochs, history['accuracy'], label=params_label)

#     # Validation accuracy for this combination
#     ax_val_acc.plot(epochs, history['val_accuracy'], label=params_label)
    
#     # Training loss for this combination
#     ax_loss.plot(epochs, history['loss'], label=params_label)
    
#     # Validation loss for this combination
#     ax_val_loss.plot(epochs, history['val_loss'], label=params_label)

# # After plotting all combinations on separate figures, let's show the plots with legends
# ax_acc.set_title('Training Accuracy for all combinations')
# ax_acc.set_xlabel('Epoch')
# ax_acc.set_ylabel('Accuracy')
# ax_acc.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# ax_val_acc.set_title('Validation Accuracy for all combinations')
# ax_val_acc.set_xlabel('Epoch')
# ax_val_acc.set_ylabel('Accuracy')
# ax_val_acc.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# ax_loss.set_title('Training Loss for all combinations')
# ax_loss.set_xlabel('Epoch')
# ax_loss.set_ylabel('Loss')
# ax_loss.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# ax_val_loss.set_title('Validation Loss for all combinations')
# ax_val_loss.set_xlabel('Epoch')
# ax_val_loss.set_ylabel('Loss')
# ax_val_loss.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# fig_acc.show()
# fig_val_acc.show()
# fig_loss.show()
# fig_val_loss.show()

# %%
# # Plot a graph for training and validation loss
# plt.figure(figsize=(10, 5)) # Optionally specify the figure size
# plt.plot(history.history['loss'], label='Training Loss')
# plt.plot(history.history['val_loss'], label='Validation Loss')
# plt.title('Training and Validation Loss')
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# # Plot a graph for training and validation accuracy
# plt.figure(figsize=(10, 5)) # Optionally specify the figure size
# plt.plot(history.history['accuracy'], label='Training Accuracy')
# plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
# plt.title('Training and Validation Accuracy')
# plt.xlabel('Epoche')
# plt.ylabel('Accuracy')
# plt.legend()
# plt.show()

# %%
# from sklearn.metrics import confusion_matrix
# import seaborn as sns

# # Get predictions
# predictions = model.predict((X_val_spec, X_val_embed_tensor))
# predicted_labels = np.argmax(predictions[0], axis=1)  # Converting probabilities to class labels
# ground_truth = np.argmax(y_val, axis=1)  # Converting one-hot encoded ground truth to class labels

# # Reshape predicted_labels and ground_truth to be 1D arrays
# predicted_labels = np.reshape(predicted_labels, (-1,))
# ground_truth = np.reshape(ground_truth, (-1,))

# # Define class labels
# class_labels = ['classical', 'country', 'electronic', 'indian',
#                 'new age', 'opera', 'pop', 'rock']

# predicted_labels = [class_labels[i] for i in predicted_labels]
# ground_truth = [class_labels[i] for i in ground_truth]

# # Create a table with prediction and ground truth
# comparison_table = pd.DataFrame({'Predicted': predicted_labels, 'Ground Truth': ground_truth})
# # Get unique class labels
# unique_labels = sorted(comparison_table['Ground Truth'].unique())

# # Create confusion matrix
# conf_matrix = confusion_matrix(comparison_table['Ground Truth'], comparison_table['Predicted'], labels=unique_labels)

# # Convert confusion matrix to DataFrame for better visualization
# conf_matrix_df = pd.DataFrame(conf_matrix, index=unique_labels, columns=unique_labels)

# # Plot confusion matrix
# plt.figure(figsize=(8, 6))
# sns.heatmap(conf_matrix_df, annot=True, cmap='Blues', fmt='g', cbar=False)
# plt.xlabel('Predicted Class')
# plt.ylabel('Ground Truth')
# plt.title('Confusion Matrix')
# plt.show()

# %%
# # First, let's gather the maximum epoch number reached among all histories
# max_epoch = max([len(history['accuracy']) for history in history_dict.values()])

# # Now, for plotting purposes, let's create four separate figures
# fig_acc, ax_acc = plt.subplots()
# fig_val_acc, ax_val_acc = plt.subplots()
# fig_loss, ax_loss = plt.subplots()
# fig_val_loss, ax_val_loss = plt.subplots()

# # Now we loop through each combination's history and plot it appropriately
# for parameter_combination, history in history_dict.items():
#     num_epochs = len(history['accuracy'])
#     epochs = range(1, num_epochs + 1)

#     # Parameters string for legend label
#     params_label = f'l1_reg={parameter_combination[0]}_l2_reg={parameter_combination[1]}'

#     # Training accuracy for this combination
#     ax_acc.plot(epochs, history['accuracy'], label=params_label)

#     # Validation accuracy for this combination
#     ax_val_acc.plot(epochs, history['val_accuracy'], label=params_label)
    
#     # Training loss for this combination
#     ax_loss.plot(epochs, history['loss'], label=params_label)
    
#     # Validation loss for this combination
#     ax_val_loss.plot(epochs, history['val_loss'], label=params_label)

# # After plotting all combinations on separate figures, let's show the plots with legends
# ax_acc.set_title('Training Accuracy for all combinations')
# ax_acc.set_xlabel('Epoch')
# ax_acc.set_ylabel('Accuracy')
# ax_acc.legend()

# ax_val_acc.set_title('Validation Accuracy for all combinations')
# ax_val_acc.set_xlabel('Epoch')
# ax_val_acc.set_ylabel('Accuracy')
# ax_val_acc.legend()

# ax_loss.set_title('Training Loss for all combinations')
# ax_loss.set_xlabel('Epoch')
# ax_loss.set_ylabel('Loss')
# ax_loss.legend()

# ax_val_loss.set_title('Validation Loss for all combinations')
# ax_val_loss.set_xlabel('Epoch')
# ax_val_loss.set_ylabel('Loss')
# ax_val_loss.legend()

# fig_acc.show()
# fig_val_acc.show()
# fig_loss.show()
# fig_val_loss.show()

# %%
'''For inidivially printing the train_acc, val_acc, train_loss, val_loss'''
# # Define number of subplots needed
# num_combinations = len(history_dict)
# rows = cols = int(num_combinations ** 0.5)
# cols = rows if rows * rows == num_combinations else rows + 1

# # If the square root of combinations does not give an integer grid, slightly increase the number of columns
# if rows * cols < num_combinations:
#     cols += 1

# # Create subplots for each metric
# fig_size = (20,7)
# fig_acc, axes_acc = plt.subplots(rows, cols, figsize=fig_size, sharex=True, sharey=True)
# fig_val_acc, axes_val_acc = plt.subplots(rows, cols, figsize=fig_size, sharex=True, sharey=True)
# fig_loss, axes_loss = plt.subplots(rows, cols, figsize=fig_size, sharex=True, sharey=True)
# fig_val_loss, axes_val_loss = plt.subplots(rows, cols, figsize=fig_size, sharex=True, sharey=True)

# # Flatten the axes array for easy iteration
# axes_acc_flat = axes_acc.flatten()
# axes_val_acc_flat = axes_val_acc.flatten()
# axes_loss_flat = axes_loss.flatten()
# axes_val_loss_flat = axes_val_loss.flatten()

# # Loop through each combination's history and plot it in a dedicated subplot
# for idx, (parameter_combination, history) in enumerate(history_dict.items()):
#     num_epochs = len(history['accuracy'])
#     epochs = range(1, num_epochs + 1)

#     # Parameters string for legend label
#     # params_label = f"alpha={parameter_combination[0]}, l1 = {parameter_combination[1]}, l2 = {parameter_combination[2]}"
#     params_label = f"alpha={parameter_combination[0]}"
#     # params_label = f"alpha={parameter_combination[0]}, l2 = {parameter_combination[1]}"
    
#     # Plot Training accuracy for this combination
#     axes_acc_flat[idx].plot(epochs, history['accuracy'], label=params_label)
#     axes_acc_flat[idx].set_title(params_label)
#     axes_acc_flat[idx].set_xlabel('Epoch')
#     axes_acc_flat[idx].set_ylabel('Accuracy')

#     # Plot Validation accuracy for this combination
#     axes_val_acc_flat[idx].plot(epochs, history['val_accuracy'], label=params_label)
#     axes_val_acc_flat[idx].set_title(params_label)
#     axes_val_acc_flat[idx].set_xlabel('Epoch')
#     axes_val_acc_flat[idx].set_ylabel('Val Accuracy')

#     # Plot Training loss for this combination
#     axes_loss_flat[idx].plot(epochs, history['loss'], label=params_label)
#     axes_loss_flat[idx].set_title(params_label)
#     axes_loss_flat[idx].set_xlabel('Epoch')
#     axes_loss_flat[idx].set_ylabel('Loss')

#     # Plot Validation loss for this combination
#     axes_val_loss_flat[idx].plot(epochs, history['val_loss'], label=params_label)
#     axes_val_loss_flat[idx].set_title(params_label)
#     axes_val_loss_flat[idx].set_xlabel('Epoch')
#     axes_val_loss_flat[idx].set_ylabel('Val Loss')

# # After adding all the plots to the subplots, adjust the layout and add the legend outside the last axis in each figure
# for axes, fig in [(axes_acc_flat, fig_acc), 
#                   (axes_val_acc_flat, fig_val_acc), 
#                   (axes_loss_flat, fig_loss), 
#                   (axes_val_loss_flat, fig_val_loss)]:
#     # Put a legend to the right of the last subplot
#     axes[-1].legend(loc='center left', bbox_to_anchor=(1, 0.5))

#     # Hide any unused axes if the number of combinations isn't a perfect square
#     for ax in axes[num_combinations:]:
#         ax.set_visible(False)

#     fig.tight_layout()
#     fig.subplots_adjust(right=0.85)  # Adjust subplot params so the legend outside fits
#     fig.show()
# Out:
# 'For inidivially printing the train_acc, val_acc, train_loss, val_loss'
