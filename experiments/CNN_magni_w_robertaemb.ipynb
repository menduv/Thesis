# %% [markdown]
# ## CNN with latentregularisation using distilRoberta embeddings
# This notebook is to conduct a grid search on with the distilRoBerta embeddings with alpha = [0, 0.25, 0.5, 0.75, 1]

# %%
# importing necessary libraries
from sentence_transformers import SentenceTransformer, models
import pandas as pd
import numpy as np
import os
pd.options.mode.chained_assignment = None 
import pickle
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import ParameterGrid
from sklearn.metrics import precision_score, recall_score, f1_score
import cv2
import keras
from tensorflow import keras
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, Activation
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from scipy.special import expit
# Out:
# 2024-08-11 09:18:08.150553: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-08-11 09:18:08.191127: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-11 09:18:08.912264: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
#df with 768 distilroberta embeddings
df = pd.read_pickle('/home/mendu/Thesis/data/magnatagatune/saved_df_data/df_w_robertaemb.pkl')

# %%
checkpoint_folder = f"/home/mendu/Thesis/data/saved_models/grid_search_alpha_roberta"

# %%
df
# Out:
#                                                   mp3_path        tags  \
# clip_id
# 2        american_bach_soloists-j_s__bach_solo_cantatas...       opera
# 6        american_bach_soloists-j_s__bach_solo_cantatas...       opera
# 10       american_bach_soloists-j_s__bach_solo_cantatas...       opera
# 11       american_bach_soloists-j_s__bach_solo_cantatas...       opera
# 14                lvx_nova-lvx_nova-01-contimune-30-59.mp3  electronic
# ...                                                    ...         ...
# 58896    jacob_heringman-blame_not_my_lute-56-la_bressa...   classical
# 58897    jacob_heringman-blame_not_my_lute-56-la_bressa...   classical
# 58898    jacob_heringman-blame_not_my_lute-56-la_bressa...   classical
# 58907    jacob_heringman-blame_not_my_lute-57-lost_is_m...   classical
# 58915    jacob_heringman-blame_not_my_lute-58-a_toy_for...   classical
#
#                                            caption_writing  \
# clip_id
# 2        Experience the majestic beauty of classical mu...
# 6        Experience the rich sound of classical eleganc...
# 10       This powerful classic opera piece showcases th...
# 11       This atmospheric and introspective song blends...
# 14       This upbeat dance track features a pulsing tec...
# ...                                                    ...
# 58896    This classical guitar solo piece features intr...
# 58897    This beautiful classical piece features a haun...
# 58898    This classical piece features beautiful melodi...
# 58907    This beautiful classical piece features a gent...
# 58915    This beautiful classical guitar melody is slow...
#
#                                          caption_embedding
# clip_id
# 2        [0.5080656, 0.5543384, 0.5286751, 0.4642, 0.57...
# 6        [0.5029524, 0.5553035, 0.5221314, 0.46020785, ...
# 10       [0.5025382, 0.5408516, 0.5334432, 0.4520641, 0...
# 11       [0.50476646, 0.5650928, 0.52276534, 0.493968, ...
# 14       [0.52656597, 0.5425188, 0.5277765, 0.5096747, ...
# ...                                                    ...
# 58896    [0.49805862, 0.55350935, 0.5117885, 0.491859, ...
# 58897    [0.5031797, 0.5562754, 0.51029664, 0.4921467, ...
# 58898    [0.50356936, 0.5640039, 0.5067394, 0.49358532,...
# 58907    [0.49854168, 0.563801, 0.5132744, 0.50910074, ...
# 58915    [0.50969565, 0.5637866, 0.5108695, 0.50700986,...
#
# [11826 rows x 4 columns]

# %% [markdown]
# ## Training the model

# %%
def add_gauss_noise(image, mean = 0, var = 10):
    '''function to add gaussian noise to an image'''
    sigma = var ** 0.5

    #creating a noise image with gaussian distribution
    gaussian = np.random.normal(mean, sigma, (image.shape[0], image.shape[1]))

    #creating a zeroes image
    noisy_image = np.zeros(image.shape, np.float32)

    #adding the noise to the original image
    noisy_image = image + gaussian

    #normalising the image
    cv2.normalize(noisy_image, noisy_image, 0, 255, cv2.NORM_MINMAX, dtype=-1)

    #changing type
    noisy_image = noisy_image.astype(np.uint8)

    return noisy_image

# %%
#loading the cropped .npy files in a tensor

#the folder path to where the mel-specs are stored
folder_path_mel = '/home/mendu/Thesis/data/magnatagatune/mel-specs'

#The ordered list of all the filenames in the filtered_df
audio_names_list = df.mp3_path.to_list()

# %%
# data = []
# i = 0

# for filename in audio_names_list: #iterates over the filtered_df audio names
#     filename_npy = str(filename[:-4]) + '.npy'
#     file_path = os.path.join(folder_path_mel, filename_npy) #creates a folder path for the mel_specs 
#     img = np.load(file_path)
#     data.append(add_gauss_noise(img))

#     # To ensure that the files are getting loaded in the correct order
#     if i < 10 :
#         print(filename)
#     i = i+1

# data = np.array(data)

# %%
data = np.load('/home/mendu/Thesis/data/magnatagatune/saved_df_data/data_array.npy')

# %%
# Caption Embeddings
embeddings = df['caption_embedding']

# %%
#normalize data
data = data.astype('float32')/255.0

data.shape
# Out:
# (11826, 128, 1255)

# %%
# Reshape data to include the channel dimension
data = data.reshape((-1, 128, 1255, 1))

# Split into training (0.8) and remaining set (0.2)
X_train_spec, X_rem_spec, X_train_embed, X_rem_embed, y_train, y_rem = train_test_split(data, embeddings, pd.get_dummies(df['tags']), test_size=0.2, random_state=42)

# Split the remaining set into validation (0.1) and test (0.1)
X_val_spec, X_test_spec, X_val_embed, X_test_embed, y_val, y_test = train_test_split(X_rem_spec, X_rem_embed, y_rem, test_size=0.5, random_state=42)

# %%
# Now, convert this array of arrays into a proper 2D NumPy array
X_train_embed_array = np.stack(X_train_embed, axis=0)

# Check the new shape to ensure it's (450, 64)
print("Shape after conversion:", X_train_embed_array.shape)

# Convert the 2D NumPy array to a TensorFlow tensor
X_train_embed_tensor = tf.convert_to_tensor(X_train_embed_array, dtype=tf.float32)

# Check the shape of the resulting tensor
print("Tensor shape:", X_train_embed_tensor.shape)
# Out:
# Shape after conversion: (9460, 768)
# Tensor shape: (9460, 768)
# 2024-08-11 09:18:14.582604: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
# Convert the 1D array of arrays into a proper 2D NumPy array
X_val_embed_array = np.stack(X_val_embed, axis=0)
X_test_embed_array = np.stack(X_test_embed, axis=0)

# Check the new shape to ensure it's in the correct format
print("Shape after conversion:", X_val_embed_array.shape)
print("Shape of test after conversion:", X_test_embed_array.shape)

# Convert the 2D NumPy array to a TensorFlow tensor
X_val_embed_tensor = tf.convert_to_tensor(X_val_embed_array, dtype=tf.float32)
X_test_embed_tensor = tf.convert_to_tensor(X_test_embed_array, dtype=tf.float32)

# Check the shape of the resulting tensor
print("Tensor shape:", X_val_embed_tensor.shape)
print("Tensor shape of test:", X_test_embed_tensor.shape)
# Out:
# Shape after conversion: (1183, 768)
# Shape of test after conversion: (1183, 768)
# Tensor shape: (1183, 768)
# Tensor shape of test: (1183, 768)

# %%
# Convert training data to tensors
X_train_spec = tf.convert_to_tensor(X_train_spec, dtype=tf.float32)
y_train = tf.convert_to_tensor(y_train, dtype=tf.float32)

# Convert validation data to tensors
X_val_spec = tf.convert_to_tensor(X_val_spec, dtype=tf.float32)
y_val = tf.convert_to_tensor(y_val, dtype=tf.float32)

# Convert validation data to tensors
X_test_spec = tf.convert_to_tensor(X_test_spec, dtype=tf.float32)
y_test = tf.convert_to_tensor(y_test, dtype=tf.float32)

# %%
# Initialize ImageDataGenerator with necessary augmentations
datagen = ImageDataGenerator(
    width_shift_range=0.2,
    height_shift_range=0.2
)

datagen.fit(X_train_spec)

# %%
# Define num_classes based on the number of unique genres
num_classes = y_train.shape[1]
num_classes
# Out:
# 8

# %%
def create_model(num_classes, l1_reg=0.01, l2_reg=0.1, alpha=0.0):
    class ModelSubClassing(keras.Model):
        def __init__(self, num_classes, l1_reg=0.01, l2_reg=0.1, alpha = 0):
            super().__init__()
            
            # Define L1 and L2 regularizer
            self.l1_l2_regularizer = regularizers.l1_l2(l1=l1_reg, l2=l2_reg)
            # self.l2_regularizer = regularizers.l2(l2_reg)
            
            # Define alpha the loss regulator
            self.alpha = alpha
            
            # number of classes
            self.num_classes = num_classes
            
            # Initialize layers as None
            self.conv1 = None
            self.max1 = None
            self.bn1 = None
            self.conv2 = None
            self.bn2 = None
            self.max2 = None
            self.drop1 = None
            self.conv3 = None
            self.bn3 = None
            self.max3 = None
            self.drop2 = None
            self.flatten = None
            self.dense768 = None
            self.dense768_act_relu = None
            self.dense768_act_sig = None
            self.dense768_do = None
            # self.dense128 = None
            # self.dense128_relu = None
            # self.dense128_do = None
            self.dense64 = None
            self.dense64_act = None
            self.dense_out = None
            
            self.loss_tracker = keras.metrics.Mean(name="loss")
            self.accuracy = keras.metrics.CategoricalAccuracy(name="accuracy")
            self.precision = Precision(name="precision")
            self.recall = Recall(name="recall")
            self.f1_score = keras.metrics.Mean(name="f1_score")

        def build(self, input_shape):
            # Create layers
            self.conv1 = Conv2D(32, 3, activation="relu", kernel_regularizer=self.l1_l2_regularizer)
            self.max1  = MaxPooling2D(3)
            self.bn1   = BatchNormalization(momentum=0.9)

            self.conv2 = Conv2D(64, 3, activation="relu", kernel_regularizer=self.l1_l2_regularizer)
            self.bn2   = BatchNormalization(momentum=0.9)
            self.max2  = MaxPooling2D(3)
            self.drop1 = Dropout(0.3)

            self.conv3 = Conv2D(128, 3, activation="relu", kernel_regularizer=self.l1_l2_regularizer)
            self.bn3   = BatchNormalization(momentum=0.9)
            self.max3  = MaxPooling2D(3)
            self.drop2 = Dropout(0.3)

            self.flatten = Flatten()
            self.dense768 = Dense(768)
            self.dense768_act_relu = Activation('relu')
            self.dense768_act_sig = Activation('sigmoid')
            self.dense768_do = Dropout(0.3)
            # self.dense128 = Dense(128)
            # self.dense128_act_relu = Activation('relu')
            # self.dense128_do = Dropout(0.3)
            self.dense64 = Dense(64)
            self.dense64_act = Activation('relu')
            self.dense_out = Dense(self.num_classes, activation="softmax")
            
            super().build(input_shape)

        def call(self, inputs, training=None):
            # Unpack the inputs
            mel_spectrogram = inputs[0]

            # Forward pass: block 1
            x = self.conv1(mel_spectrogram)
            x = self.max1(x)
            x = self.bn1(x, training=training)

            # Forward pass: block 2
            x = self.conv2(x)
            x = self.bn2(x, training=training)
            x = self.max2(x)
            x = self.drop1(x, training=training)

            # Forward pass: block 3
            x = self.conv3(x)
            x = self.bn3(x, training=training)
            x = self.max3(x)
            x = self.drop2(x, training=training)

            # Flatten and dense layers
            x = self.flatten(x)
            x_dense768 = self.dense768(x)
            x_dense768_act_sig = self.dense768_act_sig(x_dense768)
            x_dense768_act_relu = self.dense768_act_relu(x_dense768)
            x_dense768_act = self.dense768_do(x_dense768_act_relu, training=training)
            
            # x_dense128 = self.dense128(x_dense768_act)
            # x_dense128_act_relu = self.dense128_act_relu(x_dense128)
            # x_dense128_act = self.dense128_do(x_dense128_act_relu, training=training)
            
            # dense layer 64
            x_dense64 = self.dense64(x_dense768_act)
            x_dense64_act_relu = self.dense64_act(x_dense64)
            y_hat = self.dense_out(x_dense64_act_relu)
            
            return y_hat, x_dense768_act_sig


        def train_step(self, data):
            # Unpack the data
            (mel_spectrogram, caption_embedding), y = data

            with tf.GradientTape() as tape: 
            #here we get the gradients of the trainable weights with this loss
                y_pred, x_dense = self((mel_spectrogram, caption_embedding), training=True)  # Forward pass
                # Compute the standard loss value
                loss = self.compiled_loss(y, y_pred)
                custom_loss = self.custom_loss(caption_embedding, x_dense)
                total_loss = (1 - self.alpha) * loss + self.alpha * custom_loss

            # Compute gradients
            gradients = tape.gradient(total_loss, self.trainable_variables)

            # Update weights
            self.optimizer.apply_gradients(zip(gradients, self.trainable_variables))

            # Update the loss metric and any additional metrics
            self.loss_tracker.update_state(total_loss) 
            self.accuracy.update_state(y, y_pred)
            self.precision.update_state(y, y_pred)
            self.recall.update_state(y, y_pred)
            
            # Calculate F1 score
            f1 = 2 * ((self.precision.result() * self.recall.result()) / (self.precision.result() + self.recall.result() + tf.keras.backend.epsilon()))
            self.f1_score.update_state(f1)

            return {
                "loss": self.loss_tracker.result(),
                "accuracy": self.accuracy.result(),
                "ce_loss": loss,
                "embedding_loss": custom_loss,
                "total loss": total_loss,
                "alpha": self.alpha,
                "precision": self.precision.result(),
                "recall": self.recall.result(),
                "f1_score": self.f1_score.result(),
            }
            
        def test_step(self, data):
            # Unpack the data
            (mel_spectrogram, caption_embedding), y = data

            
            y_pred, x_dense = self((mel_spectrogram, caption_embedding), training=False)  # Forward pass
            # Compute the standard loss value
            loss = self.compiled_loss(y, y_pred)
            custom_loss = self.custom_loss(caption_embedding, x_dense)
            total_loss = (1 - self.alpha) * loss + self.alpha * custom_loss

            # Update the loss metric and any additional metrics
            self.loss_tracker.update_state(total_loss)
            self.accuracy.update_state(y, y_pred)
            self.precision.update_state(y, y_pred)
            self.recall.update_state(y, y_pred)
            
            # Calculate F1 score
            f1 = 2 * ((self.precision.result() * self.recall.result()) / (self.precision.result() + self.recall.result() + tf.keras.backend.epsilon()))
            self.f1_score.update_state(f1)
            
            return {
                "loss": self.loss_tracker.result(),
                "accuracy": self.accuracy.result(),
                "ce_loss": loss,
                "total loss": total_loss,
                "alpha": self.alpha,
                "precision": self.precision.result(),
                "recall": self.recall.result(),
                "f1_score": self.f1_score.result(), 
            }
            
        # Add a custom loss method in the model
        def custom_loss(self, caption_embedding, x_dense):
            # Compute the Mean Squared Error (MSE) between caption_embedding and x_dense64
            return tf.reduce_mean(tf.square(caption_embedding - x_dense))

        #new
        @property
        def metrics(self):
            # List all metrics to be reset after each epoch
            return [self.loss_tracker, self.accuracy]
        
        
    # Creating the class object

    model = ModelSubClassing(num_classes, l1_reg, l2_reg, alpha)

    # Compile the model
    adam_opt = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=adam_opt, loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# %%
# Define hyperparameters for grid search
param_grid = {
    'alpha': [0, 0.25, 0.5, 0.75, 1]
    # 'l1_reg': [0.01, 0.001],
    # 'l2_reg': [0.1, 0.01, 0.001]
}

only_alpha = False

if ("alpha" in param_grid) & (len(param_grid) == 1):
    only_alpha = True

# Ensure the checkpoint folder exists
os.makedirs(checkpoint_folder, exist_ok=True)

# Define an empty dictionary to store history objects
history_dict = {}
results_dict = {}
models = {}

# Perform grid search
best_accuracy = 0
best_params = None
for params in ParameterGrid(param_grid):
    print(f"Testing params: {params}")
    
    model = create_model(num_classes, **params)
    
    checkpoint_file = f"_{params['alpha']}.keras"
    checkpoint_path = os.path.join(checkpoint_folder, checkpoint_file)
    
    # Initialize the ModelCheckpoint callback
    model_checkpoint = ModelCheckpoint(filepath=checkpoint_path,
                                   monitor='val_accuracy',  # Monitor validation accuracy
                                   save_best_only=True,     # Save only the best model
                                   verbose=0)
    
    rlronp = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=10, verbose=1)
    early_stopper = EarlyStopping(monitor='val_loss', patience=19, verbose=1, restore_best_weights=True)
    history = model.fit(
        (X_train_spec, X_train_embed_tensor),
        y_train,
        epochs= 100,
        batch_size=32,
        validation_data=((X_val_spec, X_val_embed_tensor), y_val),
        callbacks=[early_stopper, rlronp, model_checkpoint]
    )
    
    models[f'model_{params["alpha"]}'] = model
    
    # Save the history keyed by the parameter tuple for later reference
    history_dict[tuple(params.values())] = history.history
    
    # Evaluate manually
    train_loss, train_accuracy = model.evaluate((X_train_spec, X_train_embed_tensor), y_train, verbose=0)
    val_loss, val_accuracy = model.evaluate((X_val_spec, X_val_embed_tensor), y_val, verbose=0)
    test_loss, test_accuracy = model.evaluate((X_test_spec, X_test_embed_tensor), y_test, verbose=0)
    
    results_dict[tuple(params.values())] = {
    'train_accuracy': train_accuracy,
    'train_loss': train_loss,
    'val_accuracy': val_accuracy,
    'val_loss': val_loss,
    'test_accuracy': test_accuracy,
    'test_loss': test_loss
    }
    
    print(f"Test accuracy: {test_accuracy}, Training accuracy: {train_accuracy}, Validation accuracy: {val_accuracy} for params: {params}")
    
    if val_accuracy > best_accuracy:
        best_accuracy = val_accuracy
        best_params = params
        
    

print(f"Best params: {best_params} with validation accuracy: {best_accuracy}")
# Out:
# Testing params: {'alpha': 0}
# Epoch 1/100
# /home/mendu/miniconda3/envs/myenv/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py:612: UserWarning: `model.compiled_loss()` is deprecated. Instead, use `model.compute_loss(x, y, y_pred, sample_weight)`.
#   warnings.warn(
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 106s 349ms/step - accuracy: 0.4471 - alpha: 0.0000e+00 - ce_loss: 33.0976 - embedding_loss: 0.2199 - f1_score: 0.3188 - loss: 39.0275 - precision: 0.5520 - recall: 0.2811 - total loss: 33.0976 - val_accuracy: 0.5799 - val_loss: 22.2730 - learning_rate: 1.0000e-04
# Epoch 2/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 103s 347ms/step - accuracy: 0.6064 - alpha: 0.0000e+00 - ce_loss: 15.2629 - embedding_loss: 0.2258 - f1_score: 0.4040 - loss: 18.4432 - precision: 0.6826 - recall: 0.3655 - total loss: 15.2629 - val_accuracy: 0.6500 - val_loss: 9.8998 - learning_rate: 1.0000e-04
# Epoch 3/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 103s 348ms/step - accuracy: 0.6809 - alpha: 0.0000e+00 - ce_loss: 7.0485 - embedding_loss: 0.2262 - f1_score: 0.4472 - loss: 8.3056 - precision: 0.7165 - recall: 0.4350 - total loss: 7.0485 - val_accuracy: 0.6830 - val_loss: 5.0437 - learning_rate: 1.0000e-04
# Epoch 4/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 103s 348ms/step - accuracy: 0.7167 - alpha: 0.0000e+00 - ce_loss: 4.0462 - embedding_loss: 0.2224 - f1_score: 0.4821 - loss: 4.4847 - precision: 0.7437 - recall: 0.4876 - total loss: 4.0462 - val_accuracy: 0.7346 - val_loss: 3.3370 - learning_rate: 1.0000e-04
# Epoch 5/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 103s 348ms/step - accuracy: 0.7368 - alpha: 0.0000e+00 - ce_loss: 2.9429 - embedding_loss: 0.2213 - f1_score: 0.5103 - loss: 3.1200 - precision: 0.7637 - recall: 0.5261 - total loss: 2.9429 - val_accuracy: 0.7337 - val_loss: 2.6603 - learning_rate: 1.0000e-04
# Epoch 6/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 346ms/step - accuracy: 0.7617 - alpha: 0.0000e+00 - ce_loss: 2.3699 - embedding_loss: 0.2212 - f1_score: 0.5332 - loss: 2.4743 - precision: 0.7779 - recall: 0.5517 - total loss: 2.3699 - val_accuracy: 0.6441 - val_loss: 2.6341 - learning_rate: 1.0000e-04
# Epoch 7/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 103s 347ms/step - accuracy: 0.7631 - alpha: 0.0000e+00 - ce_loss: 2.0427 - embedding_loss: 0.2216 - f1_score: 0.5520 - loss: 2.1055 - precision: 0.7863 - recall: 0.5717 - total loss: 2.0427 - val_accuracy: 0.7498 - val_loss: 1.9642 - learning_rate: 1.0000e-04
# Epoch 8/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 103s 348ms/step - accuracy: 0.7787 - alpha: 0.0000e+00 - ce_loss: 1.8112 - embedding_loss: 0.2202 - f1_score: 0.5679 - loss: 1.8525 - precision: 0.7952 - recall: 0.5900 - total loss: 1.8112 - val_accuracy: 0.7811 - val_loss: 1.7272 - learning_rate: 1.0000e-04
# Epoch 9/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.7965 - alpha: 0.0000e+00 - ce_loss: 1.6320 - embedding_loss: 0.2193 - f1_score: 0.5817 - loss: 1.6439 - precision: 0.8032 - recall: 0.6061 - total loss: 1.6320 - val_accuracy: 0.7329 - val_loss: 1.7849 - learning_rate: 1.0000e-04
# Epoch 10/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 346ms/step - accuracy: 0.8037 - alpha: 0.0000e+00 - ce_loss: 1.4859 - embedding_loss: 0.2186 - f1_score: 0.5938 - loss: 1.5113 - precision: 0.8091 - recall: 0.6191 - total loss: 1.4859 - val_accuracy: 0.8090 - val_loss: 1.4463 - learning_rate: 1.0000e-04
# Epoch 11/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.8174 - alpha: 0.0000e+00 - ce_loss: 1.3573 - embedding_loss: 0.2167 - f1_score: 0.6046 - loss: 1.3838 - precision: 0.8158 - recall: 0.6320 - total loss: 1.3573 - val_accuracy: 0.7904 - val_loss: 1.3804 - learning_rate: 1.0000e-04
# Epoch 12/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 346ms/step - accuracy: 0.8286 - alpha: 0.0000e+00 - ce_loss: 1.2783 - embedding_loss: 0.2168 - f1_score: 0.6145 - loss: 1.2797 - precision: 0.8218 - recall: 0.6436 - total loss: 1.2783 - val_accuracy: 0.7126 - val_loss: 1.6130 - learning_rate: 1.0000e-04
# Epoch 13/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.8358 - alpha: 0.0000e+00 - ce_loss: 1.1873 - embedding_loss: 0.2145 - f1_score: 0.6234 - loss: 1.1909 - precision: 0.8264 - recall: 0.6531 - total loss: 1.1873 - val_accuracy: 0.8056 - val_loss: 1.2786 - learning_rate: 1.0000e-04
# Epoch 14/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 346ms/step - accuracy: 0.8460 - alpha: 0.0000e+00 - ce_loss: 1.1196 - embedding_loss: 0.2142 - f1_score: 0.6316 - loss: 1.1218 - precision: 0.8311 - recall: 0.6629 - total loss: 1.1196 - val_accuracy: 0.7650 - val_loss: 1.3225 - learning_rate: 1.0000e-04
# Epoch 15/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 103s 347ms/step - accuracy: 0.8532 - alpha: 0.0000e+00 - ce_loss: 1.0518 - embedding_loss: 0.2123 - f1_score: 0.6392 - loss: 1.0532 - precision: 0.8351 - recall: 0.6718 - total loss: 1.0518 - val_accuracy: 0.8107 - val_loss: 1.1543 - learning_rate: 1.0000e-04
# Epoch 16/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.8615 - alpha: 0.0000e+00 - ce_loss: 0.9820 - embedding_loss: 0.2102 - f1_score: 0.6463 - loss: 0.9843 - precision: 0.8391 - recall: 0.6803 - total loss: 0.9820 - val_accuracy: 0.7870 - val_loss: 1.2346 - learning_rate: 1.0000e-04
# Epoch 17/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.8642 - alpha: 0.0000e+00 - ce_loss: 0.9348 - embedding_loss: 0.2094 - f1_score: 0.6528 - loss: 0.9394 - precision: 0.8426 - recall: 0.6883 - total loss: 0.9348 - val_accuracy: 0.8005 - val_loss: 1.1206 - learning_rate: 1.0000e-04
# Epoch 18/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.8821 - alpha: 0.0000e+00 - ce_loss: 0.8607 - embedding_loss: 0.2067 - f1_score: 0.6590 - loss: 0.8643 - precision: 0.8465 - recall: 0.6962 - total loss: 0.8607 - val_accuracy: 0.8090 - val_loss: 1.0824 - learning_rate: 1.0000e-04
# Epoch 19/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 103s 346ms/step - accuracy: 0.8841 - alpha: 0.0000e+00 - ce_loss: 0.8350 - embedding_loss: 0.2067 - f1_score: 0.6649 - loss: 0.8206 - precision: 0.8503 - recall: 0.7040 - total loss: 0.8350 - val_accuracy: 0.8174 - val_loss: 1.0499 - learning_rate: 1.0000e-04
# Epoch 20/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 103s 347ms/step - accuracy: 0.8957 - alpha: 0.0000e+00 - ce_loss: 0.7650 - embedding_loss: 0.2065 - f1_score: 0.6705 - loss: 0.7681 - precision: 0.8537 - recall: 0.7114 - total loss: 0.7650 - val_accuracy: 0.8233 - val_loss: 1.0443 - learning_rate: 1.0000e-04
# Epoch 21/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 346ms/step - accuracy: 0.9135 - alpha: 0.0000e+00 - ce_loss: 0.7201 - embedding_loss: 0.2061 - f1_score: 0.6758 - loss: 0.7215 - precision: 0.8574 - recall: 0.7190 - total loss: 0.7201 - val_accuracy: 0.8267 - val_loss: 1.0140 - learning_rate: 1.0000e-04
# Epoch 22/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9168 - alpha: 0.0000e+00 - ce_loss: 0.6830 - embedding_loss: 0.2040 - f1_score: 0.6809 - loss: 0.6760 - precision: 0.8610 - recall: 0.7265 - total loss: 0.6830 - val_accuracy: 0.8081 - val_loss: 1.0700 - learning_rate: 1.0000e-04
# Epoch 23/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9303 - alpha: 0.0000e+00 - ce_loss: 0.6367 - embedding_loss: 0.2040 - f1_score: 0.6858 - loss: 0.6325 - precision: 0.8644 - recall: 0.7337 - total loss: 0.6367 - val_accuracy: 0.8140 - val_loss: 0.9820 - learning_rate: 1.0000e-04
# Epoch 24/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9297 - alpha: 0.0000e+00 - ce_loss: 0.6145 - embedding_loss: 0.2044 - f1_score: 0.6905 - loss: 0.6180 - precision: 0.8677 - recall: 0.7405 - total loss: 0.6145 - val_accuracy: 0.8225 - val_loss: 0.9927 - learning_rate: 1.0000e-04
# Epoch 25/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9432 - alpha: 0.0000e+00 - ce_loss: 0.5604 - embedding_loss: 0.2039 - f1_score: 0.6951 - loss: 0.5625 - precision: 0.8711 - recall: 0.7474 - total loss: 0.5604 - val_accuracy: 0.8191 - val_loss: 0.9849 - learning_rate: 1.0000e-04
# Epoch 26/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9440 - alpha: 0.0000e+00 - ce_loss: 0.5547 - embedding_loss: 0.2050 - f1_score: 0.6995 - loss: 0.5467 - precision: 0.8742 - recall: 0.7540 - total loss: 0.5547 - val_accuracy: 0.7997 - val_loss: 1.0565 - learning_rate: 1.0000e-04
# Epoch 27/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9431 - alpha: 0.0000e+00 - ce_loss: 0.5201 - embedding_loss: 0.2035 - f1_score: 0.7037 - loss: 0.5430 - precision: 0.8770 - recall: 0.7601 - total loss: 0.5201 - val_accuracy: 0.8090 - val_loss: 1.0533 - learning_rate: 1.0000e-04
# Epoch 28/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9539 - alpha: 0.0000e+00 - ce_loss: 0.4913 - embedding_loss: 0.2029 - f1_score: 0.7078 - loss: 0.4927 - precision: 0.8799 - recall: 0.7662 - total loss: 0.4913 - val_accuracy: 0.8047 - val_loss: 0.9989 - learning_rate: 1.0000e-04
# Epoch 29/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9604 - alpha: 0.0000e+00 - ce_loss: 0.4701 - embedding_loss: 0.2017 - f1_score: 0.7118 - loss: 0.4650 - precision: 0.8827 - recall: 0.7719 - total loss: 0.4701 - val_accuracy: 0.8073 - val_loss: 1.0643 - learning_rate: 1.0000e-04
# Epoch 30/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9684 - alpha: 0.0000e+00 - ce_loss: 0.4415 - embedding_loss: 0.2027 - f1_score: 0.7157 - loss: 0.4422 - precision: 0.8853 - recall: 0.7775 - total loss: 0.4415 - val_accuracy: 0.7819 - val_loss: 1.1781 - learning_rate: 1.0000e-04
# Epoch 31/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9684 - alpha: 0.0000e+00 - ce_loss: 0.4296 - embedding_loss: 0.2013 - f1_score: 0.7195 - loss: 0.4228 - precision: 0.8878 - recall: 0.7828 - total loss: 0.4296 - val_accuracy: 0.8090 - val_loss: 1.0037 - learning_rate: 1.0000e-04
# Epoch 32/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9757 - alpha: 0.0000e+00 - ce_loss: 0.3961 - embedding_loss: 0.1999 - f1_score: 0.7231 - loss: 0.3990 - precision: 0.8903 - recall: 0.7879 - total loss: 0.3961 - val_accuracy: 0.7836 - val_loss: 1.1566 - learning_rate: 1.0000e-04
# Epoch 33/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.9669 - alpha: 0.0000e+00 - ce_loss: 0.4193 - embedding_loss: 0.1991 - f1_score: 0.7266 - loss: 0.4120 - precision: 0.8925 - recall: 0.7927 - total loss: 0.4193
# Epoch 33: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9669 - alpha: 0.0000e+00 - ce_loss: 0.4193 - embedding_loss: 0.1991 - f1_score: 0.7266 - loss: 0.4120 - precision: 0.8925 - recall: 0.7927 - total loss: 0.4193 - val_accuracy: 0.7929 - val_loss: 1.0912 - learning_rate: 1.0000e-04
# Epoch 34/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9848 - alpha: 0.0000e+00 - ce_loss: 0.3444 - embedding_loss: 0.1992 - f1_score: 0.7301 - loss: 0.3573 - precision: 0.8948 - recall: 0.7973 - total loss: 0.3444 - val_accuracy: 0.8225 - val_loss: 0.9543 - learning_rate: 5.0000e-05
# Epoch 35/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 344ms/step - accuracy: 0.9861 - alpha: 0.0000e+00 - ce_loss: 0.3225 - embedding_loss: 0.1979 - f1_score: 0.7334 - loss: 0.3190 - precision: 0.8972 - recall: 0.8021 - total loss: 0.3225 - val_accuracy: 0.8090 - val_loss: 1.0081 - learning_rate: 5.0000e-05
# Epoch 36/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9869 - alpha: 0.0000e+00 - ce_loss: 0.3067 - embedding_loss: 0.1964 - f1_score: 0.7367 - loss: 0.3104 - precision: 0.8995 - recall: 0.8066 - total loss: 0.3067 - val_accuracy: 0.8107 - val_loss: 0.9716 - learning_rate: 5.0000e-05
# Epoch 37/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9860 - alpha: 0.0000e+00 - ce_loss: 0.2967 - embedding_loss: 0.1949 - f1_score: 0.7398 - loss: 0.3010 - precision: 0.9016 - recall: 0.8109 - total loss: 0.2967 - val_accuracy: 0.8047 - val_loss: 0.9896 - learning_rate: 5.0000e-05
# Epoch 38/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9865 - alpha: 0.0000e+00 - ce_loss: 0.2931 - embedding_loss: 0.1938 - f1_score: 0.7429 - loss: 0.2951 - precision: 0.9037 - recall: 0.8150 - total loss: 0.2931 - val_accuracy: 0.8225 - val_loss: 0.9412 - learning_rate: 5.0000e-05
# Epoch 39/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9859 - alpha: 0.0000e+00 - ce_loss: 0.2973 - embedding_loss: 0.1916 - f1_score: 0.7459 - loss: 0.2928 - precision: 0.9056 - recall: 0.8189 - total loss: 0.2973 - val_accuracy: 0.8242 - val_loss: 0.9633 - learning_rate: 5.0000e-05
# Epoch 40/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9873 - alpha: 0.0000e+00 - ce_loss: 0.2877 - embedding_loss: 0.1908 - f1_score: 0.7489 - loss: 0.2868 - precision: 0.9075 - recall: 0.8226 - total loss: 0.2877 - val_accuracy: 0.8081 - val_loss: 1.0264 - learning_rate: 5.0000e-05
# Epoch 41/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9889 - alpha: 0.0000e+00 - ce_loss: 0.2877 - embedding_loss: 0.1904 - f1_score: 0.7517 - loss: 0.2865 - precision: 0.9092 - recall: 0.8261 - total loss: 0.2877 - val_accuracy: 0.8208 - val_loss: 0.9647 - learning_rate: 5.0000e-05
# Epoch 42/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9917 - alpha: 0.0000e+00 - ce_loss: 0.2727 - embedding_loss: 0.1885 - f1_score: 0.7545 - loss: 0.2669 - precision: 0.9109 - recall: 0.8295 - total loss: 0.2727 - val_accuracy: 0.8107 - val_loss: 0.9701 - learning_rate: 5.0000e-05
# Epoch 43/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 103s 347ms/step - accuracy: 0.9902 - alpha: 0.0000e+00 - ce_loss: 0.2704 - embedding_loss: 0.1889 - f1_score: 0.7572 - loss: 0.2665 - precision: 0.9124 - recall: 0.8327 - total loss: 0.2704 - val_accuracy: 0.8073 - val_loss: 0.9840 - learning_rate: 5.0000e-05
# Epoch 44/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 346ms/step - accuracy: 0.9891 - alpha: 0.0000e+00 - ce_loss: 0.2660 - embedding_loss: 0.1879 - f1_score: 0.7598 - loss: 0.2659 - precision: 0.9139 - recall: 0.8357 - total loss: 0.2660 - val_accuracy: 0.8123 - val_loss: 0.9732 - learning_rate: 5.0000e-05
# Epoch 45/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9896 - alpha: 0.0000e+00 - ce_loss: 0.2579 - embedding_loss: 0.1862 - f1_score: 0.7624 - loss: 0.2581 - precision: 0.9153 - recall: 0.8387 - total loss: 0.2579 - val_accuracy: 0.8157 - val_loss: 0.9763 - learning_rate: 5.0000e-05
# Epoch 46/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 346ms/step - accuracy: 0.9887 - alpha: 0.0000e+00 - ce_loss: 0.2509 - embedding_loss: 0.1863 - f1_score: 0.7649 - loss: 0.2514 - precision: 0.9167 - recall: 0.8415 - total loss: 0.2509 - val_accuracy: 0.8014 - val_loss: 0.9930 - learning_rate: 5.0000e-05
# Epoch 47/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9917 - alpha: 0.0000e+00 - ce_loss: 0.2447 - embedding_loss: 0.1857 - f1_score: 0.7674 - loss: 0.2445 - precision: 0.9180 - recall: 0.8442 - total loss: 0.2447 - val_accuracy: 0.8005 - val_loss: 1.0427 - learning_rate: 5.0000e-05
# Epoch 48/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.9931 - alpha: 0.0000e+00 - ce_loss: 0.2457 - embedding_loss: 0.1845 - f1_score: 0.7698 - loss: 0.2439 - precision: 0.9193 - recall: 0.8468 - total loss: 0.2457
# Epoch 48: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9931 - alpha: 0.0000e+00 - ce_loss: 0.2457 - embedding_loss: 0.1845 - f1_score: 0.7698 - loss: 0.2439 - precision: 0.9193 - recall: 0.8468 - total loss: 0.2457 - val_accuracy: 0.8039 - val_loss: 1.0076 - learning_rate: 5.0000e-05
# Epoch 49/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9932 - alpha: 0.0000e+00 - ce_loss: 0.2204 - embedding_loss: 0.1826 - f1_score: 0.7721 - loss: 0.2242 - precision: 0.9205 - recall: 0.8493 - total loss: 0.2204 - val_accuracy: 0.8166 - val_loss: 0.9818 - learning_rate: 2.5000e-05
# Epoch 50/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9936 - alpha: 0.0000e+00 - ce_loss: 0.2129 - embedding_loss: 0.1817 - f1_score: 0.7744 - loss: 0.2141 - precision: 0.9217 - recall: 0.8518 - total loss: 0.2129 - val_accuracy: 0.8166 - val_loss: 0.9882 - learning_rate: 2.5000e-05
# Epoch 51/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9937 - alpha: 0.0000e+00 - ce_loss: 0.2069 - embedding_loss: 0.1808 - f1_score: 0.7766 - loss: 0.2066 - precision: 0.9229 - recall: 0.8542 - total loss: 0.2069 - val_accuracy: 0.7988 - val_loss: 1.0450 - learning_rate: 2.5000e-05
# Epoch 52/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 344ms/step - accuracy: 0.9932 - alpha: 0.0000e+00 - ce_loss: 0.2072 - embedding_loss: 0.1792 - f1_score: 0.7787 - loss: 0.2067 - precision: 0.9240 - recall: 0.8565 - total loss: 0.2072 - val_accuracy: 0.8191 - val_loss: 0.9709 - learning_rate: 2.5000e-05
# Epoch 53/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9939 - alpha: 0.0000e+00 - ce_loss: 0.2077 - embedding_loss: 0.1790 - f1_score: 0.7809 - loss: 0.2048 - precision: 0.9251 - recall: 0.8587 - total loss: 0.2077 - val_accuracy: 0.8107 - val_loss: 0.9731 - learning_rate: 2.5000e-05
# Epoch 54/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9937 - alpha: 0.0000e+00 - ce_loss: 0.2023 - embedding_loss: 0.1783 - f1_score: 0.7829 - loss: 0.2042 - precision: 0.9261 - recall: 0.8608 - total loss: 0.2023 - val_accuracy: 0.8166 - val_loss: 0.9188 - learning_rate: 2.5000e-05
# Epoch 55/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9954 - alpha: 0.0000e+00 - ce_loss: 0.1982 - embedding_loss: 0.1785 - f1_score: 0.7850 - loss: 0.1980 - precision: 0.9272 - recall: 0.8629 - total loss: 0.1982 - val_accuracy: 0.8123 - val_loss: 0.9877 - learning_rate: 2.5000e-05
# Epoch 56/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9926 - alpha: 0.0000e+00 - ce_loss: 0.1976 - embedding_loss: 0.1761 - f1_score: 0.7869 - loss: 0.1998 - precision: 0.9281 - recall: 0.8648 - total loss: 0.1976 - val_accuracy: 0.8115 - val_loss: 0.9419 - learning_rate: 2.5000e-05
# Epoch 57/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9954 - alpha: 0.0000e+00 - ce_loss: 0.1934 - embedding_loss: 0.1754 - f1_score: 0.7889 - loss: 0.1923 - precision: 0.9291 - recall: 0.8668 - total loss: 0.1934 - val_accuracy: 0.8107 - val_loss: 0.9728 - learning_rate: 2.5000e-05
# Epoch 58/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9952 - alpha: 0.0000e+00 - ce_loss: 0.1892 - embedding_loss: 0.1747 - f1_score: 0.7908 - loss: 0.1912 - precision: 0.9300 - recall: 0.8686 - total loss: 0.1892 - val_accuracy: 0.8149 - val_loss: 0.9687 - learning_rate: 2.5000e-05
# Epoch 59/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9952 - alpha: 0.0000e+00 - ce_loss: 0.1914 - embedding_loss: 0.1742 - f1_score: 0.7926 - loss: 0.1903 - precision: 0.9308 - recall: 0.8704 - total loss: 0.1914 - val_accuracy: 0.8064 - val_loss: 1.0021 - learning_rate: 2.5000e-05
# Epoch 60/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9944 - alpha: 0.0000e+00 - ce_loss: 0.1910 - embedding_loss: 0.1727 - f1_score: 0.7944 - loss: 0.1893 - precision: 0.9317 - recall: 0.8721 - total loss: 0.1910 - val_accuracy: 0.8030 - val_loss: 1.0128 - learning_rate: 2.5000e-05
# Epoch 61/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 344ms/step - accuracy: 0.9947 - alpha: 0.0000e+00 - ce_loss: 0.1868 - embedding_loss: 0.1721 - f1_score: 0.7962 - loss: 0.1902 - precision: 0.9324 - recall: 0.8738 - total loss: 0.1868 - val_accuracy: 0.8098 - val_loss: 0.9633 - learning_rate: 2.5000e-05
# Epoch 62/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9953 - alpha: 0.0000e+00 - ce_loss: 0.1893 - embedding_loss: 0.1720 - f1_score: 0.7979 - loss: 0.1871 - precision: 0.9332 - recall: 0.8754 - total loss: 0.1893 - val_accuracy: 0.8115 - val_loss: 0.9486 - learning_rate: 2.5000e-05
# Epoch 63/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9957 - alpha: 0.0000e+00 - ce_loss: 0.1819 - embedding_loss: 0.1707 - f1_score: 0.7996 - loss: 0.1838 - precision: 0.9340 - recall: 0.8770 - total loss: 0.1819 - val_accuracy: 0.8115 - val_loss: 0.9794 - learning_rate: 2.5000e-05
# Epoch 64/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.9972 - alpha: 0.0000e+00 - ce_loss: 0.1784 - embedding_loss: 0.1711 - f1_score: 0.8013 - loss: 0.1774 - precision: 0.9347 - recall: 0.8785 - total loss: 0.1784
# Epoch 64: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9972 - alpha: 0.0000e+00 - ce_loss: 0.1784 - embedding_loss: 0.1711 - f1_score: 0.8013 - loss: 0.1774 - precision: 0.9347 - recall: 0.8785 - total loss: 0.1784 - val_accuracy: 0.7887 - val_loss: 1.1265 - learning_rate: 2.5000e-05
# Epoch 65/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9957 - alpha: 0.0000e+00 - ce_loss: 0.1734 - embedding_loss: 0.1693 - f1_score: 0.8029 - loss: 0.1775 - precision: 0.9353 - recall: 0.8799 - total loss: 0.1734 - val_accuracy: 0.8166 - val_loss: 0.9623 - learning_rate: 1.2500e-05
# Epoch 66/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9976 - alpha: 0.0000e+00 - ce_loss: 0.1639 - embedding_loss: 0.1694 - f1_score: 0.8045 - loss: 0.1650 - precision: 0.9361 - recall: 0.8814 - total loss: 0.1639 - val_accuracy: 0.8183 - val_loss: 0.9384 - learning_rate: 1.2500e-05
# Epoch 67/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9958 - alpha: 0.0000e+00 - ce_loss: 0.1637 - embedding_loss: 0.1681 - f1_score: 0.8061 - loss: 0.1643 - precision: 0.9367 - recall: 0.8828 - total loss: 0.1637 - val_accuracy: 0.8098 - val_loss: 0.9766 - learning_rate: 1.2500e-05
# Epoch 68/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9974 - alpha: 0.0000e+00 - ce_loss: 0.1631 - embedding_loss: 0.1683 - f1_score: 0.8076 - loss: 0.1630 - precision: 0.9374 - recall: 0.8842 - total loss: 0.1631 - val_accuracy: 0.8166 - val_loss: 0.9437 - learning_rate: 1.2500e-05
# Epoch 69/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9964 - alpha: 0.0000e+00 - ce_loss: 0.1633 - embedding_loss: 0.1664 - f1_score: 0.8091 - loss: 0.1652 - precision: 0.9381 - recall: 0.8855 - total loss: 0.1633 - val_accuracy: 0.8208 - val_loss: 0.9322 - learning_rate: 1.2500e-05
# Epoch 70/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9975 - alpha: 0.0000e+00 - ce_loss: 0.1602 - embedding_loss: 0.1666 - f1_score: 0.8106 - loss: 0.1612 - precision: 0.9387 - recall: 0.8868 - total loss: 0.1602 - val_accuracy: 0.8149 - val_loss: 0.9426 - learning_rate: 1.2500e-05
# Epoch 71/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9963 - alpha: 0.0000e+00 - ce_loss: 0.1626 - embedding_loss: 0.1669 - f1_score: 0.8120 - loss: 0.1612 - precision: 0.9393 - recall: 0.8881 - total loss: 0.1626 - val_accuracy: 0.8157 - val_loss: 0.9470 - learning_rate: 1.2500e-05
# Epoch 72/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9971 - alpha: 0.0000e+00 - ce_loss: 0.1612 - embedding_loss: 0.1661 - f1_score: 0.8135 - loss: 0.1624 - precision: 0.9399 - recall: 0.8893 - total loss: 0.1612 - val_accuracy: 0.8047 - val_loss: 0.9286 - learning_rate: 1.2500e-05
# Epoch 73/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9965 - alpha: 0.0000e+00 - ce_loss: 0.1587 - embedding_loss: 0.1659 - f1_score: 0.8149 - loss: 0.1588 - precision: 0.9405 - recall: 0.8904 - total loss: 0.1587 - val_accuracy: 0.8107 - val_loss: 0.9995 - learning_rate: 1.2500e-05
# Epoch 73: early stopping
# Restoring model weights from the end of the best epoch: 54.
# Test accuracy: 0.8089602589607239, Training accuracy: 0.9997885823249817, Validation accuracy: 0.8165680766105652 for params: {'alpha': 0}
# Testing params: {'alpha': 0.25}
# Epoch 1/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 106s 348ms/step - accuracy: 0.4432 - alpha: 0.2500 - ce_loss: 33.3508 - embedding_loss: 0.2167 - f1_score: 0.3234 - loss: 29.5259 - precision: 0.5519 - recall: 0.2951 - total loss: 25.0672 - val_accuracy: 0.6044 - val_loss: 16.9613 - learning_rate: 1.0000e-04
# Epoch 2/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 103s 347ms/step - accuracy: 0.5814 - alpha: 0.2500 - ce_loss: 15.6421 - embedding_loss: 0.2244 - f1_score: 0.4151 - loss: 14.1953 - precision: 0.6710 - recall: 0.3765 - total loss: 11.7877 - val_accuracy: 0.6805 - val_loss: 7.6473 - learning_rate: 1.0000e-04
# Epoch 3/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 344ms/step - accuracy: 0.6593 - alpha: 0.2500 - ce_loss: 7.2946 - embedding_loss: 0.2184 - f1_score: 0.4533 - loss: 6.4685 - precision: 0.7060 - recall: 0.4301 - total loss: 5.5256 - val_accuracy: 0.7092 - val_loss: 4.0618 - learning_rate: 1.0000e-04
# Epoch 4/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 103s 348ms/step - accuracy: 0.7060 - alpha: 0.2500 - ce_loss: 4.2895 - embedding_loss: 0.2091 - f1_score: 0.4837 - loss: 3.6053 - precision: 0.7364 - recall: 0.4766 - total loss: 3.2694 - val_accuracy: 0.7303 - val_loss: 2.6983 - learning_rate: 1.0000e-04
# Epoch 5/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 344ms/step - accuracy: 0.7403 - alpha: 0.2500 - ce_loss: 3.0959 - embedding_loss: 0.2003 - f1_score: 0.5095 - loss: 2.5158 - precision: 0.7594 - recall: 0.5169 - total loss: 2.3720 - val_accuracy: 0.7498 - val_loss: 2.1420 - learning_rate: 1.0000e-04
# Epoch 6/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 344ms/step - accuracy: 0.7634 - alpha: 0.2500 - ce_loss: 2.5161 - embedding_loss: 0.1926 - f1_score: 0.5314 - loss: 2.0138 - precision: 0.7758 - recall: 0.5463 - total loss: 1.9353 - val_accuracy: 0.7616 - val_loss: 1.7953 - learning_rate: 1.0000e-04
# Epoch 7/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 344ms/step - accuracy: 0.7798 - alpha: 0.2500 - ce_loss: 2.1045 - embedding_loss: 0.1853 - f1_score: 0.5501 - loss: 1.6667 - precision: 0.7876 - recall: 0.5697 - total loss: 1.6247 - val_accuracy: 0.7658 - val_loss: 1.5440 - learning_rate: 1.0000e-04
# Epoch 8/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 343ms/step - accuracy: 0.7875 - alpha: 0.2500 - ce_loss: 1.8561 - embedding_loss: 0.1749 - f1_score: 0.5662 - loss: 1.4652 - precision: 0.7972 - recall: 0.5894 - total loss: 1.4358 - val_accuracy: 0.6458 - val_loss: 1.6721 - learning_rate: 1.0000e-04
# Epoch 9/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 343ms/step - accuracy: 0.7939 - alpha: 0.2500 - ce_loss: 1.6710 - embedding_loss: 0.1656 - f1_score: 0.5801 - loss: 1.3194 - precision: 0.8028 - recall: 0.6045 - total loss: 1.2946 - val_accuracy: 0.7168 - val_loss: 1.3748 - learning_rate: 1.0000e-04
# Epoch 10/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 343ms/step - accuracy: 0.8043 - alpha: 0.2500 - ce_loss: 1.5106 - embedding_loss: 0.1550 - f1_score: 0.5923 - loss: 1.2009 - precision: 0.8091 - recall: 0.6179 - total loss: 1.1717 - val_accuracy: 0.7489 - val_loss: 1.2250 - learning_rate: 1.0000e-04
# Epoch 11/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.8163 - alpha: 0.2500 - ce_loss: 1.3732 - embedding_loss: 0.1465 - f1_score: 0.6032 - loss: 1.0817 - precision: 0.8151 - recall: 0.6308 - total loss: 1.0665 - val_accuracy: 0.7726 - val_loss: 1.1413 - learning_rate: 1.0000e-04
# Epoch 12/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 343ms/step - accuracy: 0.8232 - alpha: 0.2500 - ce_loss: 1.2757 - embedding_loss: 0.1408 - f1_score: 0.6131 - loss: 1.0015 - precision: 0.8202 - recall: 0.6422 - total loss: 0.9920 - val_accuracy: 0.7253 - val_loss: 1.1605 - learning_rate: 1.0000e-04
# Epoch 13/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 344ms/step - accuracy: 0.8376 - alpha: 0.2500 - ce_loss: 1.1747 - embedding_loss: 0.1355 - f1_score: 0.6220 - loss: 0.9264 - precision: 0.8246 - recall: 0.6524 - total loss: 0.9149 - val_accuracy: 0.8123 - val_loss: 0.9563 - learning_rate: 1.0000e-04
# Epoch 14/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 343ms/step - accuracy: 0.8404 - alpha: 0.2500 - ce_loss: 1.1022 - embedding_loss: 0.1290 - f1_score: 0.6303 - loss: 0.8760 - precision: 0.8295 - recall: 0.6627 - total loss: 0.8589 - val_accuracy: 0.8123 - val_loss: 0.9242 - learning_rate: 1.0000e-04
# Epoch 15/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 342ms/step - accuracy: 0.8639 - alpha: 0.2500 - ce_loss: 1.0244 - embedding_loss: 0.1260 - f1_score: 0.6379 - loss: 0.7955 - precision: 0.8343 - recall: 0.6729 - total loss: 0.7998 - val_accuracy: 0.7303 - val_loss: 1.0581 - learning_rate: 1.0000e-04
# Epoch 16/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 343ms/step - accuracy: 0.8655 - alpha: 0.2500 - ce_loss: 0.9695 - embedding_loss: 0.1255 - f1_score: 0.6451 - loss: 0.7708 - precision: 0.8382 - recall: 0.6815 - total loss: 0.7585 - val_accuracy: 0.8149 - val_loss: 0.8516 - learning_rate: 1.0000e-04
# Epoch 17/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.8756 - alpha: 0.2500 - ce_loss: 0.9016 - embedding_loss: 0.1235 - f1_score: 0.6518 - loss: 0.7091 - precision: 0.8427 - recall: 0.6907 - total loss: 0.7070 - val_accuracy: 0.7980 - val_loss: 0.8922 - learning_rate: 1.0000e-04
# Epoch 18/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.8852 - alpha: 0.2500 - ce_loss: 0.8555 - embedding_loss: 0.1230 - f1_score: 0.6581 - loss: 0.6743 - precision: 0.8468 - recall: 0.6993 - total loss: 0.6724 - val_accuracy: 0.7439 - val_loss: 1.0466 - learning_rate: 1.0000e-04
# Epoch 19/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.8915 - alpha: 0.2500 - ce_loss: 0.8059 - embedding_loss: 0.1229 - f1_score: 0.6642 - loss: 0.6364 - precision: 0.8503 - recall: 0.7070 - total loss: 0.6351 - val_accuracy: 0.8090 - val_loss: 0.8216 - learning_rate: 1.0000e-04
# Epoch 20/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9130 - alpha: 0.2500 - ce_loss: 0.7582 - embedding_loss: 0.1216 - f1_score: 0.6699 - loss: 0.5938 - precision: 0.8542 - recall: 0.7152 - total loss: 0.5990 - val_accuracy: 0.8140 - val_loss: 0.8173 - learning_rate: 1.0000e-04
# Epoch 21/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9227 - alpha: 0.2500 - ce_loss: 0.7107 - embedding_loss: 0.1207 - f1_score: 0.6753 - loss: 0.5558 - precision: 0.8581 - recall: 0.7232 - total loss: 0.5632 - val_accuracy: 0.8132 - val_loss: 0.8180 - learning_rate: 1.0000e-04
# Epoch 22/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 342ms/step - accuracy: 0.9227 - alpha: 0.2500 - ce_loss: 0.6770 - embedding_loss: 0.1203 - f1_score: 0.6806 - loss: 0.5405 - precision: 0.8618 - recall: 0.7308 - total loss: 0.5378 - val_accuracy: 0.8199 - val_loss: 0.7936 - learning_rate: 1.0000e-04
# Epoch 23/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9419 - alpha: 0.2500 - ce_loss: 0.6312 - embedding_loss: 0.1204 - f1_score: 0.6856 - loss: 0.4943 - precision: 0.8655 - recall: 0.7384 - total loss: 0.5035 - val_accuracy: 0.8056 - val_loss: 0.8016 - learning_rate: 1.0000e-04
# Epoch 24/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9339 - alpha: 0.2500 - ce_loss: 0.6103 - embedding_loss: 0.1205 - f1_score: 0.6905 - loss: 0.4888 - precision: 0.8688 - recall: 0.7453 - total loss: 0.4878 - val_accuracy: 0.7633 - val_loss: 0.8815 - learning_rate: 1.0000e-04
# Epoch 25/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9467 - alpha: 0.2500 - ce_loss: 0.5783 - embedding_loss: 0.1211 - f1_score: 0.6952 - loss: 0.4575 - precision: 0.8719 - recall: 0.7518 - total loss: 0.4640 - val_accuracy: 0.7861 - val_loss: 0.8459 - learning_rate: 1.0000e-04
# Epoch 26/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9488 - alpha: 0.2500 - ce_loss: 0.5532 - embedding_loss: 0.1229 - f1_score: 0.6997 - loss: 0.4413 - precision: 0.8749 - recall: 0.7582 - total loss: 0.4456 - val_accuracy: 0.8157 - val_loss: 0.7858 - learning_rate: 1.0000e-04
# Epoch 27/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9617 - alpha: 0.2500 - ce_loss: 0.5252 - embedding_loss: 0.1215 - f1_score: 0.7041 - loss: 0.4168 - precision: 0.8780 - recall: 0.7644 - total loss: 0.4243 - val_accuracy: 0.8030 - val_loss: 0.7624 - learning_rate: 1.0000e-04
# Epoch 28/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9587 - alpha: 0.2500 - ce_loss: 0.5049 - embedding_loss: 0.1204 - f1_score: 0.7083 - loss: 0.4079 - precision: 0.8808 - recall: 0.7704 - total loss: 0.4088 - val_accuracy: 0.7870 - val_loss: 0.8022 - learning_rate: 1.0000e-04
# Epoch 29/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9670 - alpha: 0.2500 - ce_loss: 0.4779 - embedding_loss: 0.1212 - f1_score: 0.7123 - loss: 0.3872 - precision: 0.8836 - recall: 0.7761 - total loss: 0.3887 - val_accuracy: 0.7430 - val_loss: 0.9635 - learning_rate: 1.0000e-04
# Epoch 30/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9694 - alpha: 0.2500 - ce_loss: 0.4538 - embedding_loss: 0.1195 - f1_score: 0.7163 - loss: 0.3724 - precision: 0.8862 - recall: 0.7814 - total loss: 0.3703 - val_accuracy: 0.8090 - val_loss: 0.8092 - learning_rate: 1.0000e-04
# Epoch 31/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9625 - alpha: 0.2500 - ce_loss: 0.4525 - embedding_loss: 0.1188 - f1_score: 0.7201 - loss: 0.3731 - precision: 0.8887 - recall: 0.7867 - total loss: 0.3691 - val_accuracy: 0.8090 - val_loss: 0.7571 - learning_rate: 1.0000e-04
# Epoch 32/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 342ms/step - accuracy: 0.9674 - alpha: 0.2500 - ce_loss: 0.4359 - embedding_loss: 0.1175 - f1_score: 0.7238 - loss: 0.3573 - precision: 0.8911 - recall: 0.7916 - total loss: 0.3563 - val_accuracy: 0.8208 - val_loss: 0.7389 - learning_rate: 1.0000e-04
# Epoch 33/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9674 - alpha: 0.2500 - ce_loss: 0.4274 - embedding_loss: 0.1168 - f1_score: 0.7274 - loss: 0.3521 - precision: 0.8934 - recall: 0.7963 - total loss: 0.3498 - val_accuracy: 0.7794 - val_loss: 0.7865 - learning_rate: 1.0000e-04
# Epoch 34/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9723 - alpha: 0.2500 - ce_loss: 0.4013 - embedding_loss: 0.1170 - f1_score: 0.7309 - loss: 0.3367 - precision: 0.8955 - recall: 0.8006 - total loss: 0.3302 - val_accuracy: 0.8191 - val_loss: 0.7521 - learning_rate: 1.0000e-04
# Epoch 35/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9768 - alpha: 0.2500 - ce_loss: 0.3845 - embedding_loss: 0.1149 - f1_score: 0.7342 - loss: 0.3142 - precision: 0.8977 - recall: 0.8050 - total loss: 0.3171 - val_accuracy: 0.8107 - val_loss: 0.7769 - learning_rate: 1.0000e-04
# Epoch 36/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9731 - alpha: 0.2500 - ce_loss: 0.3887 - embedding_loss: 0.1139 - f1_score: 0.7375 - loss: 0.3176 - precision: 0.8997 - recall: 0.8091 - total loss: 0.3200 - val_accuracy: 0.7760 - val_loss: 0.8390 - learning_rate: 1.0000e-04
# Epoch 37/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9733 - alpha: 0.2500 - ce_loss: 0.3681 - embedding_loss: 0.1147 - f1_score: 0.7407 - loss: 0.3100 - precision: 0.9014 - recall: 0.8128 - total loss: 0.3047 - val_accuracy: 0.8199 - val_loss: 0.7583 - learning_rate: 1.0000e-04
# Epoch 38/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9815 - alpha: 0.2500 - ce_loss: 0.3513 - embedding_loss: 0.1139 - f1_score: 0.7438 - loss: 0.2908 - precision: 0.9033 - recall: 0.8167 - total loss: 0.2919 - val_accuracy: 0.8098 - val_loss: 0.6972 - learning_rate: 1.0000e-04
# Epoch 39/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9778 - alpha: 0.2500 - ce_loss: 0.3472 - embedding_loss: 0.1120 - f1_score: 0.7468 - loss: 0.2907 - precision: 0.9051 - recall: 0.8202 - total loss: 0.2884 - val_accuracy: 0.8090 - val_loss: 0.7316 - learning_rate: 1.0000e-04
# Epoch 40/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 340ms/step - accuracy: 0.9792 - alpha: 0.2500 - ce_loss: 0.3317 - embedding_loss: 0.1096 - f1_score: 0.7497 - loss: 0.2766 - precision: 0.9068 - recall: 0.8236 - total loss: 0.2762 - val_accuracy: 0.7836 - val_loss: 0.8255 - learning_rate: 1.0000e-04
# Epoch 41/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 340ms/step - accuracy: 0.9830 - alpha: 0.2500 - ce_loss: 0.3241 - embedding_loss: 0.1071 - f1_score: 0.7526 - loss: 0.2703 - precision: 0.9083 - recall: 0.8269 - total loss: 0.2698 - val_accuracy: 0.8174 - val_loss: 0.6809 - learning_rate: 1.0000e-04
# Epoch 42/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9838 - alpha: 0.2500 - ce_loss: 0.3165 - embedding_loss: 0.1059 - f1_score: 0.7553 - loss: 0.2649 - precision: 0.9099 - recall: 0.8301 - total loss: 0.2638 - val_accuracy: 0.8090 - val_loss: 0.7249 - learning_rate: 1.0000e-04
# Epoch 43/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9848 - alpha: 0.2500 - ce_loss: 0.3085 - embedding_loss: 0.1062 - f1_score: 0.7580 - loss: 0.2542 - precision: 0.9114 - recall: 0.8331 - total loss: 0.2579 - val_accuracy: 0.8115 - val_loss: 0.7354 - learning_rate: 1.0000e-04
# Epoch 44/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 342ms/step - accuracy: 0.9839 - alpha: 0.2500 - ce_loss: 0.2994 - embedding_loss: 0.1052 - f1_score: 0.7606 - loss: 0.2504 - precision: 0.9128 - recall: 0.8360 - total loss: 0.2508 - val_accuracy: 0.7861 - val_loss: 0.8421 - learning_rate: 1.0000e-04
# Epoch 45/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 103s 346ms/step - accuracy: 0.9829 - alpha: 0.2500 - ce_loss: 0.2881 - embedding_loss: 0.1037 - f1_score: 0.7632 - loss: 0.2474 - precision: 0.9141 - recall: 0.8387 - total loss: 0.2420 - val_accuracy: 0.7971 - val_loss: 0.7069 - learning_rate: 1.0000e-04
# Epoch 46/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9834 - alpha: 0.2500 - ce_loss: 0.2931 - embedding_loss: 0.1020 - f1_score: 0.7656 - loss: 0.2433 - precision: 0.9153 - recall: 0.8413 - total loss: 0.2453 - val_accuracy: 0.7887 - val_loss: 0.7847 - learning_rate: 1.0000e-04
# Epoch 47/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9861 - alpha: 0.2500 - ce_loss: 0.2767 - embedding_loss: 0.1020 - f1_score: 0.7681 - loss: 0.2380 - precision: 0.9165 - recall: 0.8438 - total loss: 0.2330 - val_accuracy: 0.7777 - val_loss: 0.8577 - learning_rate: 1.0000e-04
# Epoch 48/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 340ms/step - accuracy: 0.9860 - alpha: 0.2500 - ce_loss: 0.2735 - embedding_loss: 0.0990 - f1_score: 0.7704 - loss: 0.2253 - precision: 0.9176 - recall: 0.8463 - total loss: 0.2299 - val_accuracy: 0.8081 - val_loss: 0.7884 - learning_rate: 1.0000e-04
# Epoch 49/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9884 - alpha: 0.2500 - ce_loss: 0.2551 - embedding_loss: 0.0991 - f1_score: 0.7727 - loss: 0.2211 - precision: 0.9188 - recall: 0.8487 - total loss: 0.2161 - val_accuracy: 0.8107 - val_loss: 0.7255 - learning_rate: 1.0000e-04
# Epoch 50/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9855 - alpha: 0.2500 - ce_loss: 0.2602 - embedding_loss: 0.0969 - f1_score: 0.7749 - loss: 0.2127 - precision: 0.9199 - recall: 0.8511 - total loss: 0.2194 - val_accuracy: 0.8047 - val_loss: 0.7231 - learning_rate: 1.0000e-04
# Epoch 51/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.9816 - alpha: 0.2500 - ce_loss: 0.2622 - embedding_loss: 0.0972 - f1_score: 0.7771 - loss: 0.2258 - precision: 0.9209 - recall: 0.8532 - total loss: 0.2210
# Epoch 51: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9816 - alpha: 0.2500 - ce_loss: 0.2622 - embedding_loss: 0.0972 - f1_score: 0.7771 - loss: 0.2258 - precision: 0.9209 - recall: 0.8532 - total loss: 0.2210 - val_accuracy: 0.8107 - val_loss: 0.7159 - learning_rate: 1.0000e-04
# Epoch 52/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9943 - alpha: 0.2500 - ce_loss: 0.2083 - embedding_loss: 0.0908 - f1_score: 0.7792 - loss: 0.1847 - precision: 0.9220 - recall: 0.8554 - total loss: 0.1789 - val_accuracy: 0.8039 - val_loss: 0.6813 - learning_rate: 5.0000e-05
# Epoch 53/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 342ms/step - accuracy: 0.9942 - alpha: 0.2500 - ce_loss: 0.1965 - embedding_loss: 0.0874 - f1_score: 0.7813 - loss: 0.1687 - precision: 0.9231 - recall: 0.8576 - total loss: 0.1692 - val_accuracy: 0.7937 - val_loss: 0.7394 - learning_rate: 5.0000e-05
# Epoch 54/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 342ms/step - accuracy: 0.9958 - alpha: 0.2500 - ce_loss: 0.1884 - embedding_loss: 0.0835 - f1_score: 0.7834 - loss: 0.1618 - precision: 0.9242 - recall: 0.8597 - total loss: 0.1622 - val_accuracy: 0.8123 - val_loss: 0.6453 - learning_rate: 5.0000e-05
# Epoch 55/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9952 - alpha: 0.2500 - ce_loss: 0.1858 - embedding_loss: 0.0820 - f1_score: 0.7853 - loss: 0.1594 - precision: 0.9252 - recall: 0.8618 - total loss: 0.1598 - val_accuracy: 0.8098 - val_loss: 0.6415 - learning_rate: 5.0000e-05
# Epoch 56/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9930 - alpha: 0.2500 - ce_loss: 0.1854 - embedding_loss: 0.0807 - f1_score: 0.7873 - loss: 0.1616 - precision: 0.9262 - recall: 0.8637 - total loss: 0.1592 - val_accuracy: 0.8047 - val_loss: 0.6943 - learning_rate: 5.0000e-05
# Epoch 57/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9972 - alpha: 0.2500 - ce_loss: 0.1787 - embedding_loss: 0.0799 - f1_score: 0.7892 - loss: 0.1539 - precision: 0.9272 - recall: 0.8657 - total loss: 0.1540 - val_accuracy: 0.8030 - val_loss: 0.6974 - learning_rate: 5.0000e-05
# Epoch 58/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 342ms/step - accuracy: 0.9946 - alpha: 0.2500 - ce_loss: 0.1851 - embedding_loss: 0.0786 - f1_score: 0.7911 - loss: 0.1563 - precision: 0.9281 - recall: 0.8675 - total loss: 0.1585 - val_accuracy: 0.8064 - val_loss: 0.6570 - learning_rate: 5.0000e-05
# Epoch 59/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9936 - alpha: 0.2500 - ce_loss: 0.1773 - embedding_loss: 0.0782 - f1_score: 0.7929 - loss: 0.1554 - precision: 0.9289 - recall: 0.8693 - total loss: 0.1525 - val_accuracy: 0.8166 - val_loss: 0.6466 - learning_rate: 5.0000e-05
# Epoch 60/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 346ms/step - accuracy: 0.9946 - alpha: 0.2500 - ce_loss: 0.1732 - embedding_loss: 0.0763 - f1_score: 0.7947 - loss: 0.1454 - precision: 0.9298 - recall: 0.8710 - total loss: 0.1490 - val_accuracy: 0.7853 - val_loss: 0.7491 - learning_rate: 5.0000e-05
# Epoch 61/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9930 - alpha: 0.2500 - ce_loss: 0.1756 - embedding_loss: 0.0752 - f1_score: 0.7964 - loss: 0.1541 - precision: 0.9305 - recall: 0.8726 - total loss: 0.1505 - val_accuracy: 0.8022 - val_loss: 0.6945 - learning_rate: 5.0000e-05
# Epoch 62/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9953 - alpha: 0.2500 - ce_loss: 0.1710 - embedding_loss: 0.0728 - f1_score: 0.7981 - loss: 0.1423 - precision: 0.9313 - recall: 0.8742 - total loss: 0.1465 - val_accuracy: 0.7921 - val_loss: 0.6851 - learning_rate: 5.0000e-05
# Epoch 63/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9932 - alpha: 0.2500 - ce_loss: 0.1681 - embedding_loss: 0.0731 - f1_score: 0.7998 - loss: 0.1489 - precision: 0.9321 - recall: 0.8757 - total loss: 0.1443 - val_accuracy: 0.8073 - val_loss: 0.6597 - learning_rate: 5.0000e-05
# Epoch 64/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9939 - alpha: 0.2500 - ce_loss: 0.1629 - embedding_loss: 0.0704 - f1_score: 0.8014 - loss: 0.1410 - precision: 0.9328 - recall: 0.8772 - total loss: 0.1398 - val_accuracy: 0.7997 - val_loss: 0.6959 - learning_rate: 5.0000e-05
# Epoch 65/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.9944 - alpha: 0.2500 - ce_loss: 0.1625 - embedding_loss: 0.0700 - f1_score: 0.8030 - loss: 0.1377 - precision: 0.9336 - recall: 0.8787 - total loss: 0.1394
# Epoch 65: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9944 - alpha: 0.2500 - ce_loss: 0.1625 - embedding_loss: 0.0700 - f1_score: 0.8030 - loss: 0.1377 - precision: 0.9336 - recall: 0.8787 - total loss: 0.1394 - val_accuracy: 0.8208 - val_loss: 0.6822 - learning_rate: 5.0000e-05
# Epoch 66/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 342ms/step - accuracy: 0.9966 - alpha: 0.2500 - ce_loss: 0.1482 - embedding_loss: 0.0675 - f1_score: 0.8046 - loss: 0.1318 - precision: 0.9343 - recall: 0.8801 - total loss: 0.1280 - val_accuracy: 0.8090 - val_loss: 0.6447 - learning_rate: 2.5000e-05
# Epoch 67/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 103s 347ms/step - accuracy: 0.9965 - alpha: 0.2500 - ce_loss: 0.1401 - embedding_loss: 0.0648 - f1_score: 0.8061 - loss: 0.1216 - precision: 0.9350 - recall: 0.8816 - total loss: 0.1213 - val_accuracy: 0.7988 - val_loss: 0.6585 - learning_rate: 2.5000e-05
# Epoch 68/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 342ms/step - accuracy: 0.9963 - alpha: 0.2500 - ce_loss: 0.1395 - embedding_loss: 0.0642 - f1_score: 0.8076 - loss: 0.1202 - precision: 0.9357 - recall: 0.8829 - total loss: 0.1207 - val_accuracy: 0.8166 - val_loss: 0.6052 - learning_rate: 2.5000e-05
# Epoch 69/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9981 - alpha: 0.2500 - ce_loss: 0.1358 - embedding_loss: 0.0624 - f1_score: 0.8091 - loss: 0.1179 - precision: 0.9364 - recall: 0.8843 - total loss: 0.1174 - val_accuracy: 0.8081 - val_loss: 0.6762 - learning_rate: 2.5000e-05
# Epoch 70/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 343ms/step - accuracy: 0.9971 - alpha: 0.2500 - ce_loss: 0.1333 - embedding_loss: 0.0612 - f1_score: 0.8106 - loss: 0.1148 - precision: 0.9370 - recall: 0.8856 - total loss: 0.1153 - val_accuracy: 0.8216 - val_loss: 0.6138 - learning_rate: 2.5000e-05
# Epoch 71/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 102s 345ms/step - accuracy: 0.9967 - alpha: 0.2500 - ce_loss: 0.1323 - embedding_loss: 0.0611 - f1_score: 0.8120 - loss: 0.1174 - precision: 0.9376 - recall: 0.8868 - total loss: 0.1145 - val_accuracy: 0.8005 - val_loss: 0.6564 - learning_rate: 2.5000e-05
# Epoch 72/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9958 - alpha: 0.2500 - ce_loss: 0.1358 - embedding_loss: 0.0603 - f1_score: 0.8134 - loss: 0.1162 - precision: 0.9383 - recall: 0.8881 - total loss: 0.1169 - val_accuracy: 0.8098 - val_loss: 0.6388 - learning_rate: 2.5000e-05
# Epoch 73/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9975 - alpha: 0.2500 - ce_loss: 0.1308 - embedding_loss: 0.0603 - f1_score: 0.8148 - loss: 0.1118 - precision: 0.9388 - recall: 0.8893 - total loss: 0.1132 - val_accuracy: 0.8107 - val_loss: 0.6220 - learning_rate: 2.5000e-05
# Epoch 74/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 340ms/step - accuracy: 0.9959 - alpha: 0.2500 - ce_loss: 0.1299 - embedding_loss: 0.0589 - f1_score: 0.8161 - loss: 0.1154 - precision: 0.9394 - recall: 0.8904 - total loss: 0.1122 - val_accuracy: 0.7980 - val_loss: 0.6599 - learning_rate: 2.5000e-05
# Epoch 75/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9980 - alpha: 0.2500 - ce_loss: 0.1262 - embedding_loss: 0.0575 - f1_score: 0.8174 - loss: 0.1091 - precision: 0.9400 - recall: 0.8915 - total loss: 0.1091 - val_accuracy: 0.8073 - val_loss: 0.6318 - learning_rate: 2.5000e-05
# Epoch 76/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9971 - alpha: 0.2500 - ce_loss: 0.1273 - embedding_loss: 0.0569 - f1_score: 0.8187 - loss: 0.1117 - precision: 0.9405 - recall: 0.8926 - total loss: 0.1097 - val_accuracy: 0.8098 - val_loss: 0.6178 - learning_rate: 2.5000e-05
# Epoch 77/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9973 - alpha: 0.2500 - ce_loss: 0.1257 - embedding_loss: 0.0570 - f1_score: 0.8200 - loss: 0.1090 - precision: 0.9411 - recall: 0.8937 - total loss: 0.1085 - val_accuracy: 0.8090 - val_loss: 0.6461 - learning_rate: 2.5000e-05
# Epoch 78/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.9961 - alpha: 0.2500 - ce_loss: 0.1298 - embedding_loss: 0.0566 - f1_score: 0.8213 - loss: 0.1113 - precision: 0.9416 - recall: 0.8947 - total loss: 0.1115
# Epoch 78: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 340ms/step - accuracy: 0.9961 - alpha: 0.2500 - ce_loss: 0.1298 - embedding_loss: 0.0566 - f1_score: 0.8213 - loss: 0.1113 - precision: 0.9416 - recall: 0.8947 - total loss: 0.1115 - val_accuracy: 0.8090 - val_loss: 0.6529 - learning_rate: 2.5000e-05
# Epoch 79/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.9977 - alpha: 0.2500 - ce_loss: 0.1187 - embedding_loss: 0.0553 - f1_score: 0.8225 - loss: 0.1038 - precision: 0.9421 - recall: 0.8958 - total loss: 0.1029 - val_accuracy: 0.8090 - val_loss: 0.6200 - learning_rate: 1.2500e-05
# Epoch 80/100
# ...
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2669 - alpha: 1.0000 - ce_loss: 47.5843 - embedding_loss: 1.5375e-04 - f1_score: 0.0191 - loss: 1.5344e-04 - precision: 0.3552 - recall: 0.0022 - total loss: 1.5375e-04 - val_accuracy: 0.2527 - val_loss: 1.4994e-04 - learning_rate: 2.5000e-05
# Epoch 38/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2681 - alpha: 1.0000 - ce_loss: 47.5897 - embedding_loss: 1.5337e-04 - f1_score: 0.0187 - loss: 1.5320e-04 - precision: 0.3552 - recall: 0.0021 - total loss: 1.5337e-04 - val_accuracy: 0.2527 - val_loss: 1.4997e-04 - learning_rate: 2.5000e-05
# Epoch 39/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 340ms/step - accuracy: 0.2659 - alpha: 1.0000 - ce_loss: 47.5945 - embedding_loss: 1.5280e-04 - f1_score: 0.0183 - loss: 1.5300e-04 - precision: 0.3552 - recall: 0.0021 - total loss: 1.5280e-04 - val_accuracy: 0.2527 - val_loss: 1.5037e-04 - learning_rate: 2.5000e-05
# Epoch 40/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2643 - alpha: 1.0000 - ce_loss: 47.6020 - embedding_loss: 1.5267e-04 - f1_score: 0.0179 - loss: 1.5354e-04 - precision: 0.3552 - recall: 0.0020 - total loss: 1.5267e-04 - val_accuracy: 0.2527 - val_loss: 1.5049e-04 - learning_rate: 2.5000e-05
# Epoch 41/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2664 - alpha: 1.0000 - ce_loss: 47.6092 - embedding_loss: 1.5241e-04 - f1_score: 0.0176 - loss: 1.5286e-04 - precision: 0.3552 - recall: 0.0020 - total loss: 1.5241e-04 - val_accuracy: 0.2527 - val_loss: 1.4981e-04 - learning_rate: 2.5000e-05
# Epoch 42/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2656 - alpha: 1.0000 - ce_loss: 47.6143 - embedding_loss: 1.5257e-04 - f1_score: 0.0172 - loss: 1.5140e-04 - precision: 0.3552 - recall: 0.0019 - total loss: 1.5257e-04 - val_accuracy: 0.2527 - val_loss: 1.4886e-04 - learning_rate: 2.5000e-05
# Epoch 43/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2652 - alpha: 1.0000 - ce_loss: 47.6208 - embedding_loss: 1.5177e-04 - f1_score: 0.0169 - loss: 1.5184e-04 - precision: 0.3552 - recall: 0.0019 - total loss: 1.5177e-04 - val_accuracy: 0.2527 - val_loss: 1.4917e-04 - learning_rate: 2.5000e-05
# Epoch 44/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2665 - alpha: 1.0000 - ce_loss: 47.6290 - embedding_loss: 1.5154e-04 - f1_score: 0.0166 - loss: 1.5190e-04 - precision: 0.3552 - recall: 0.0018 - total loss: 1.5154e-04 - val_accuracy: 0.2527 - val_loss: 1.4754e-04 - learning_rate: 2.5000e-05
# Epoch 45/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2665 - alpha: 1.0000 - ce_loss: 47.6370 - embedding_loss: 1.5128e-04 - f1_score: 0.0163 - loss: 1.5138e-04 - precision: 0.3552 - recall: 0.0018 - total loss: 1.5128e-04 - val_accuracy: 0.2527 - val_loss: 1.4738e-04 - learning_rate: 2.5000e-05
# Epoch 46/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.2739 - alpha: 1.0000 - ce_loss: 47.6430 - embedding_loss: 1.5097e-04 - f1_score: 0.0160 - loss: 1.5134e-04 - precision: 0.3552 - recall: 0.0017 - total loss: 1.5097e-04
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2738 - alpha: 1.0000 - ce_loss: 47.6430 - embedding_loss: 1.5097e-04 - f1_score: 0.0160 - loss: 1.5134e-04 - precision: 0.3552 - recall: 0.0017 - total loss: 1.5097e-04 - val_accuracy: 0.2527 - val_loss: 1.4878e-04 - learning_rate: 2.5000e-05
# Epoch 47/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2652 - alpha: 1.0000 - ce_loss: 47.6445 - embedding_loss: 1.5028e-04 - f1_score: 0.0158 - loss: 1.5039e-04 - precision: 0.3552 - recall: 0.0017 - total loss: 1.5028e-04 - val_accuracy: 0.2527 - val_loss: 1.4783e-04 - learning_rate: 1.2500e-05
# Epoch 48/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2657 - alpha: 1.0000 - ce_loss: 47.6489 - embedding_loss: 1.4986e-04 - f1_score: 0.0155 - loss: 1.5011e-04 - precision: 0.3552 - recall: 0.0017 - total loss: 1.4986e-04 - val_accuracy: 0.2527 - val_loss: 1.4741e-04 - learning_rate: 1.2500e-05
# Epoch 49/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2643 - alpha: 1.0000 - ce_loss: 47.6498 - embedding_loss: 1.4964e-04 - f1_score: 0.0153 - loss: 1.5017e-04 - precision: 0.3552 - recall: 0.0016 - total loss: 1.4964e-04 - val_accuracy: 0.2527 - val_loss: 1.4788e-04 - learning_rate: 1.2500e-05
# Epoch 50/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2639 - alpha: 1.0000 - ce_loss: 47.6517 - embedding_loss: 1.4949e-04 - f1_score: 0.0150 - loss: 1.5009e-04 - precision: 0.3552 - recall: 0.0016 - total loss: 1.4949e-04 - val_accuracy: 0.2527 - val_loss: 1.4717e-04 - learning_rate: 1.2500e-05
# Epoch 51/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2689 - alpha: 1.0000 - ce_loss: 47.6539 - embedding_loss: 1.4940e-04 - f1_score: 0.0148 - loss: 1.4865e-04 - precision: 0.3552 - recall: 0.0016 - total loss: 1.4940e-04 - val_accuracy: 0.2527 - val_loss: 1.4737e-04 - learning_rate: 1.2500e-05
# Epoch 52/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2640 - alpha: 1.0000 - ce_loss: 47.6570 - embedding_loss: 1.4954e-04 - f1_score: 0.0146 - loss: 1.4964e-04 - precision: 0.3552 - recall: 0.0015 - total loss: 1.4954e-04 - val_accuracy: 0.2527 - val_loss: 1.4699e-04 - learning_rate: 1.2500e-05
# Epoch 53/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2682 - alpha: 1.0000 - ce_loss: 47.6557 - embedding_loss: 1.4884e-04 - f1_score: 0.0143 - loss: 1.4867e-04 - precision: 0.3552 - recall: 0.0015 - total loss: 1.4884e-04 - val_accuracy: 0.2527 - val_loss: 1.4816e-04 - learning_rate: 1.2500e-05
# Epoch 54/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 340ms/step - accuracy: 0.2646 - alpha: 1.0000 - ce_loss: 47.6619 - embedding_loss: 1.4950e-04 - f1_score: 0.0141 - loss: 1.4950e-04 - precision: 0.3552 - recall: 0.0015 - total loss: 1.4950e-04 - val_accuracy: 0.2527 - val_loss: 1.4647e-04 - learning_rate: 1.2500e-05
# Epoch 55/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2749 - alpha: 1.0000 - ce_loss: 47.6663 - embedding_loss: 1.4967e-04 - f1_score: 0.0139 - loss: 1.4976e-04 - precision: 0.3552 - recall: 0.0015 - total loss: 1.4967e-04 - val_accuracy: 0.2527 - val_loss: 1.4605e-04 - learning_rate: 1.2500e-05
# Epoch 56/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.2694 - alpha: 1.0000 - ce_loss: 47.6669 - embedding_loss: 1.4912e-04 - f1_score: 0.0137 - loss: 1.4929e-04 - precision: 0.3552 - recall: 0.0014 - total loss: 1.4912e-04
# Epoch 56: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2694 - alpha: 1.0000 - ce_loss: 47.6669 - embedding_loss: 1.4912e-04 - f1_score: 0.0137 - loss: 1.4928e-04 - precision: 0.3552 - recall: 0.0014 - total loss: 1.4912e-04 - val_accuracy: 0.2527 - val_loss: 1.4677e-04 - learning_rate: 1.2500e-05
# Epoch 57/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2706 - alpha: 1.0000 - ce_loss: 47.6694 - embedding_loss: 1.4834e-04 - f1_score: 0.0135 - loss: 1.4825e-04 - precision: 0.3552 - recall: 0.0014 - total loss: 1.4834e-04 - val_accuracy: 0.2527 - val_loss: 1.4660e-04 - learning_rate: 6.2500e-06
# Epoch 58/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2662 - alpha: 1.0000 - ce_loss: 47.6697 - embedding_loss: 1.4826e-04 - f1_score: 0.0133 - loss: 1.4796e-04 - precision: 0.3552 - recall: 0.0014 - total loss: 1.4826e-04 - val_accuracy: 0.2527 - val_loss: 1.4604e-04 - learning_rate: 6.2500e-06
# Epoch 59/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2689 - alpha: 1.0000 - ce_loss: 47.6661 - embedding_loss: 1.4810e-04 - f1_score: 0.0132 - loss: 1.4986e-04 - precision: 0.3552 - recall: 0.0014 - total loss: 1.4810e-04 - val_accuracy: 0.2527 - val_loss: 1.4618e-04 - learning_rate: 6.2500e-06
# Epoch 60/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 342ms/step - accuracy: 0.2669 - alpha: 1.0000 - ce_loss: 47.6692 - embedding_loss: 1.4812e-04 - f1_score: 0.0130 - loss: 1.4799e-04 - precision: 0.3552 - recall: 0.0013 - total loss: 1.4812e-04 - val_accuracy: 0.2527 - val_loss: 1.4640e-04 - learning_rate: 6.2500e-06
# Epoch 61/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2712 - alpha: 1.0000 - ce_loss: 47.6718 - embedding_loss: 1.4868e-04 - f1_score: 0.0128 - loss: 1.4997e-04 - precision: 0.3552 - recall: 0.0013 - total loss: 1.4868e-04 - val_accuracy: 0.2527 - val_loss: 1.4624e-04 - learning_rate: 6.2500e-06
# Epoch 62/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2668 - alpha: 1.0000 - ce_loss: 47.6755 - embedding_loss: 1.4849e-04 - f1_score: 0.0126 - loss: 1.4889e-04 - precision: 0.3552 - recall: 0.0013 - total loss: 1.4849e-04 - val_accuracy: 0.2527 - val_loss: 1.4727e-04 - learning_rate: 6.2500e-06
# Epoch 63/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2642 - alpha: 1.0000 - ce_loss: 47.6748 - embedding_loss: 1.4830e-04 - f1_score: 0.0125 - loss: 1.4828e-04 - precision: 0.3552 - recall: 0.0013 - total loss: 1.4830e-04 - val_accuracy: 0.2527 - val_loss: 1.4537e-04 - learning_rate: 6.2500e-06
# Epoch 64/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2711 - alpha: 1.0000 - ce_loss: 47.6747 - embedding_loss: 1.4793e-04 - f1_score: 0.0123 - loss: 1.4772e-04 - precision: 0.3552 - recall: 0.0013 - total loss: 1.4793e-04 - val_accuracy: 0.2527 - val_loss: 1.4571e-04 - learning_rate: 6.2500e-06
# Epoch 65/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2640 - alpha: 1.0000 - ce_loss: 47.6753 - embedding_loss: 1.4837e-04 - f1_score: 0.0122 - loss: 1.4866e-04 - precision: 0.3552 - recall: 0.0012 - total loss: 1.4837e-04 - val_accuracy: 0.2527 - val_loss: 1.4597e-04 - learning_rate: 6.2500e-06
# Epoch 66/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.2637 - alpha: 1.0000 - ce_loss: 47.6780 - embedding_loss: 1.4838e-04 - f1_score: 0.0120 - loss: 1.4816e-04 - precision: 0.3552 - recall: 0.0012 - total loss: 1.4838e-04
# Epoch 66: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 340ms/step - accuracy: 0.2637 - alpha: 1.0000 - ce_loss: 47.6780 - embedding_loss: 1.4838e-04 - f1_score: 0.0120 - loss: 1.4816e-04 - precision: 0.3552 - recall: 0.0012 - total loss: 1.4838e-04 - val_accuracy: 0.2527 - val_loss: 1.4606e-04 - learning_rate: 6.2500e-06
# Epoch 67/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2708 - alpha: 1.0000 - ce_loss: 47.6771 - embedding_loss: 1.4788e-04 - f1_score: 0.0119 - loss: 1.4764e-04 - precision: 0.3552 - recall: 0.0012 - total loss: 1.4788e-04 - val_accuracy: 0.2527 - val_loss: 1.4539e-04 - learning_rate: 3.1250e-06
# Epoch 68/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2701 - alpha: 1.0000 - ce_loss: 47.6784 - embedding_loss: 1.4751e-04 - f1_score: 0.0117 - loss: 1.4768e-04 - precision: 0.3552 - recall: 0.0012 - total loss: 1.4751e-04 - val_accuracy: 0.2527 - val_loss: 1.4593e-04 - learning_rate: 3.1250e-06
# Epoch 69/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2668 - alpha: 1.0000 - ce_loss: 47.6786 - embedding_loss: 1.4750e-04 - f1_score: 0.0116 - loss: 1.4745e-04 - precision: 0.3552 - recall: 0.0012 - total loss: 1.4750e-04 - val_accuracy: 0.2527 - val_loss: 1.4571e-04 - learning_rate: 3.1250e-06
# Epoch 70/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2705 - alpha: 1.0000 - ce_loss: 47.6776 - embedding_loss: 1.4741e-04 - f1_score: 0.0115 - loss: 1.4749e-04 - precision: 0.3552 - recall: 0.0011 - total loss: 1.4741e-04 - val_accuracy: 0.2527 - val_loss: 1.4590e-04 - learning_rate: 3.1250e-06
# Epoch 71/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2631 - alpha: 1.0000 - ce_loss: 47.6803 - embedding_loss: 1.4776e-04 - f1_score: 0.0113 - loss: 1.4851e-04 - precision: 0.3552 - recall: 0.0011 - total loss: 1.4776e-04 - val_accuracy: 0.2527 - val_loss: 1.4626e-04 - learning_rate: 3.1250e-06
# Epoch 72/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2611 - alpha: 1.0000 - ce_loss: 47.6774 - embedding_loss: 1.4806e-04 - f1_score: 0.0112 - loss: 1.4792e-04 - precision: 0.3552 - recall: 0.0011 - total loss: 1.4806e-04 - val_accuracy: 0.2527 - val_loss: 1.4593e-04 - learning_rate: 3.1250e-06
# Epoch 73/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2605 - alpha: 1.0000 - ce_loss: 47.6847 - embedding_loss: 1.4755e-04 - f1_score: 0.0111 - loss: 1.4865e-04 - precision: 0.3552 - recall: 0.0011 - total loss: 1.4755e-04 - val_accuracy: 0.2527 - val_loss: 1.4624e-04 - learning_rate: 3.1250e-06
# Epoch 74/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2699 - alpha: 1.0000 - ce_loss: 47.6805 - embedding_loss: 1.4824e-04 - f1_score: 0.0110 - loss: 1.4824e-04 - precision: 0.3552 - recall: 0.0011 - total loss: 1.4824e-04 - val_accuracy: 0.2527 - val_loss: 1.4578e-04 - learning_rate: 3.1250e-06
# Epoch 75/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 340ms/step - accuracy: 0.2692 - alpha: 1.0000 - ce_loss: 47.6837 - embedding_loss: 1.4723e-04 - f1_score: 0.0108 - loss: 1.4766e-04 - precision: 0.3552 - recall: 0.0011 - total loss: 1.4723e-04 - val_accuracy: 0.2527 - val_loss: 1.4540e-04 - learning_rate: 3.1250e-06
# Epoch 76/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.2606 - alpha: 1.0000 - ce_loss: 47.6832 - embedding_loss: 1.4763e-04 - f1_score: 0.0107 - loss: 1.4799e-04 - precision: 0.3552 - recall: 0.0011 - total loss: 1.4763e-04
# Epoch 76: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 340ms/step - accuracy: 0.2606 - alpha: 1.0000 - ce_loss: 47.6832 - embedding_loss: 1.4763e-04 - f1_score: 0.0107 - loss: 1.4798e-04 - precision: 0.3552 - recall: 0.0011 - total loss: 1.4763e-04 - val_accuracy: 0.2527 - val_loss: 1.4553e-04 - learning_rate: 3.1250e-06
# Epoch 77/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2675 - alpha: 1.0000 - ce_loss: 47.6833 - embedding_loss: 1.4762e-04 - f1_score: 0.0106 - loss: 1.4804e-04 - precision: 0.3552 - recall: 0.0010 - total loss: 1.4762e-04 - val_accuracy: 0.2527 - val_loss: 1.4577e-04 - learning_rate: 1.5625e-06
# Epoch 78/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 340ms/step - accuracy: 0.2687 - alpha: 1.0000 - ce_loss: 47.6847 - embedding_loss: 1.4788e-04 - f1_score: 0.0105 - loss: 1.4818e-04 - precision: 0.3552 - recall: 0.0010 - total loss: 1.4788e-04 - val_accuracy: 0.2527 - val_loss: 1.4608e-04 - learning_rate: 1.5625e-06
# Epoch 79/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2777 - alpha: 1.0000 - ce_loss: 47.6833 - embedding_loss: 1.4744e-04 - f1_score: 0.0104 - loss: 1.4748e-04 - precision: 0.3552 - recall: 0.0010 - total loss: 1.4744e-04 - val_accuracy: 0.2527 - val_loss: 1.4601e-04 - learning_rate: 1.5625e-06
# Epoch 80/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2609 - alpha: 1.0000 - ce_loss: 47.6838 - embedding_loss: 1.4770e-04 - f1_score: 0.0103 - loss: 1.4825e-04 - precision: 0.3552 - recall: 9.9936e-04 - total loss: 1.4770e-04 - val_accuracy: 0.2527 - val_loss: 1.4556e-04 - learning_rate: 1.5625e-06
# Epoch 81/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2672 - alpha: 1.0000 - ce_loss: 47.6838 - embedding_loss: 1.4759e-04 - f1_score: 0.0102 - loss: 1.4740e-04 - precision: 0.3552 - recall: 9.8694e-04 - total loss: 1.4759e-04 - val_accuracy: 0.2527 - val_loss: 1.4589e-04 - learning_rate: 1.5625e-06
# Epoch 82/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.2648 - alpha: 1.0000 - ce_loss: 47.6828 - embedding_loss: 1.4800e-04 - f1_score: 0.0101 - loss: 1.4809e-04 - precision: 0.3552 - recall: 9.7482e-04 - total loss: 1.4800e-04 - val_accuracy: 0.2527 - val_loss: 1.4637e-04 - learning_rate: 1.5625e-06
# Epoch 82: early stopping
# Restoring model weights from the end of the best epoch: 63.
# Test accuracy: 0.25950971245765686, Training accuracy: 0.27315011620521545, Validation accuracy: 0.2527472674846649 for params: {'alpha': 1}
# Best params: {'alpha': 0.5} with validation accuracy: 0.8233305215835571

# %%
# Plotting
def plot_history(history_dict):
    num_combinations = len(history_dict)
    fig, axs = plt.subplots(num_combinations, 2, figsize=(15, 5 * num_combinations))
    
    if num_combinations == 1:
        axs = np.expand_dims(axs, axis=0)
    
    for i, (params, history) in enumerate(history_dict.items()):
        # param_str = f"alpha: {params[0]}, l1 = {params[1]}, l2 = {params[2]}"
        if only_alpha:
            param_str = f"alpha: {params[0]}"
        else:
            param_str = f"alpha: {params[0]}, l2 = {params[1]}"
        
        # Plot accuracy
        axs[i, 0].plot(history['accuracy'], label='Training Accuracy')
        axs[i, 0].plot(history['val_accuracy'], label='Validation Accuracy')
        axs[i, 0].set_title(f'Accuracy for {param_str}')
        axs[i, 0].set_xlabel('Epochs')
        axs[i, 0].set_ylabel('Accuracy')
        axs[i, 0].legend()
        
        # Plot loss
        axs[i, 1].plot(history['loss'], label='Training Loss')
        axs[i, 1].plot(history['val_loss'], label='Validation Loss')
        axs[i, 1].set_title(f'Loss for {param_str}')
        axs[i, 1].set_xlabel('Epochs')
        axs[i, 1].set_ylabel('Loss')
        axs[i, 1].legend()
    
    plt.tight_layout()
    plt.show()

# Call the plotting function
plot_history(history_dict)

# %%
for k, v in models.items():
    
    best_model = v
    
    # Get predictions from the best model
    predictions = best_model.predict((X_test_spec, X_test_embed_tensor))
    predicted_class_probabilities = predictions[0]  # This gives you the (1183, 8) array
    predicted_labels = np.argmax(predicted_class_probabilities, axis=1)
    ground_truth = np.argmax(y_test, axis=1)  # Converting one-hot encoded ground truth to class labels

    # Reshape predicted_labels and ground_truth to be 1D arrays
    predicted_labels = np.reshape(predicted_labels, (-1,))
    ground_truth = np.reshape(ground_truth, (-1,))

    # Calculate precision, recall, and F1 score
    test_precision = precision_score(ground_truth, predicted_labels, average='macro')
    test_recall = recall_score(ground_truth, predicted_labels, average='macro')
    test_f1_score = f1_score(ground_truth, predicted_labels, average='macro')

    results_dict[(float(str.split(k,'_')[1]),)]["test_precision"] = test_precision
    results_dict[(float(str.split(k,'_')[1]),)]["test_recall"] = test_recall
    results_dict[(float(str.split(k,'_')[1]),)]["test_f1_score"] = test_f1_score
    
    # Define class labels
    class_labels = ['classical', 'country', 'electronic', 'indian',
                    'new age', 'opera', 'pop', 'rock']

    # Convert numerical labels to class labels
    predicted_labels = [class_labels[i] for i in predicted_labels]
    ground_truth = [class_labels[i] for i in ground_truth]

    # Create confusion matrix
    conf_matrix = confusion_matrix(ground_truth, predicted_labels, labels=class_labels)

    # Convert confusion matrix to DataFrame for better visualization
    conf_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

    # Plot confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix_df, annot=True, cmap='Blues', fmt='g', cbar=False)
    plt.xlabel('Predicted Class')
    plt.ylabel('Ground Truth')
    plt.title(f'Confusion Matrix for {k}')
    plt.show()
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step
# /home/mendu/miniconda3/envs/myenv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
pd.DataFrame(results_dict)
# Out:
#                     0.00      0.25      0.50      0.75      1.00
# train_accuracy  0.999789  0.999366  0.998309  0.999789  0.273150
# train_loss      0.188178  0.115078  0.077008  0.032576  0.000143
# val_accuracy    0.816568  0.816568  0.823331  0.809806  0.252747
# val_loss        0.918789  0.605204  0.399045  0.198208  0.000145
# test_accuracy   0.808960  0.814877  0.819104  0.817413  0.259510
# test_loss       0.889062  0.605061  0.394149  0.190495  0.000147
# test_precision  0.730121  0.726071  0.708084  0.724874  0.032439
# test_recall     0.651699  0.631760  0.643286  0.639380  0.125000
# test_f1_score   0.675060  0.655248  0.663519  0.661661  0.051510

# %%
result_dict_path = os.path.join(checkpoint_folder, 'result_dict.pkl')
history_dict_path = os.path.join(checkpoint_folder, 'history_dict.pkl')

with open(result_dict_path, 'wb') as fp:
    pickle.dump(results_dict, fp)
    
with open(history_dict_path, 'wb') as fp:
    pickle.dump(history_dict, fp)

# %%
# Assuming models and other variables are already defined
misclassified_dict = {}

# Iterate over the models and their corresponding parameter values
for model_name, model in models.items():
    # Get model predictions
    y_test_pred = model.predict((X_test_spec, X_test_embed_tensor))
    
    # Check if y_val_pred is a tuple and select the appropriate output
    if isinstance(y_test_pred, tuple):
        y_test_pred = y_test_pred[0]  # Assuming the first element is the logits or probabilities
    
    # Ensure y_val_pred is a 2D array
    if y_test_pred.ndim == 2:
        y_test_pred_labels = np.argmax(y_test_pred, axis=1)
    else:
        raise ValueError(f"Unexpected output shape {y_test_pred.shape} for model {model_name}")

    # Get the true labels
    y_test_true_labels = np.argmax(y_test, axis=1)

    # Find misclassified samples
    misclassified_indices = np.where(y_test_pred_labels != y_test_true_labels)[0]
    wrong_labels = y_test_pred_labels[misclassified_indices]
    correct_labels = y_test_true_labels[misclassified_indices]

    # Create a dataframe
    df_misclassified = pd.DataFrame({
        'Index': misclassified_indices,
        'Wrong Label': wrong_labels,
        'Correct Label': correct_labels
    })

    # Store the dataframe in the dictionary
    misclassified_dict[model_name] = df_misclassified
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step

# %%
model_0 = misclassified_dict['model_0']
model_25= misclassified_dict['model_0.25']
model_5 = misclassified_dict['model_0.5']
model_75 = misclassified_dict['model_0.75']

# %%
# Rename the Wrong Label columns for clarity
model_0 = model_0.rename(columns={'Wrong Label': 'Wrong Label_0'})
model_25 = model_25.rename(columns={'Wrong Label': 'Wrong Label_25'})
model_5 = model_5.rename(columns={'Wrong Label': 'Wrong Label_5'})
model_75 = model_75.rename(columns={'Wrong Label': 'Wrong Label_75'})
# model_1 = model_1.rename(columns={'Wrong Label': 'Wrong Label_1'})

# Merge the dataframes
merged_df = pd.merge(model_0, model_25, on=['Index', 'Correct Label'], how='outer')
merged_df = pd.merge(merged_df, model_5, on=['Index', 'Correct Label'], how='outer')
merged_df = pd.merge(merged_df, model_75, on=['Index', 'Correct Label'], how='outer')
# merged_df = pd.merge(merged_df, model_1, on=['Index', 'Correct Label'], how='outer')

# %%
# Genre mapping
genre_map = {
    0: 'classical',
    1: 'country',
    2: 'electronic',
    3: 'indian',
    4: 'new age',
    5: 'opera',
    6: 'pop',
    7: 'rock'
}

# Replace numeric labels with genre names
columns_to_replace = ['Correct Label', 'Wrong Label_0', 'Wrong Label_25', 'Wrong Label_5', 'Wrong Label_75']
for col in columns_to_replace:
    merged_df[col] = merged_df[col].map(genre_map)

# Display the merged dataframe
merged_df
# Out:
#      Index Wrong Label_0 Correct Label Wrong Label_25 Wrong Label_5  \
# 0        2     classical       country      classical     classical
# 1        3    electronic        indian     electronic    electronic
# 2        9    electronic       new age     electronic    electronic
# 3       10         opera     classical          opera         opera
# 4       12     classical       new age            NaN           NaN
# ..     ...           ...           ...            ...           ...
# 330   1169           pop          rock            NaN           pop
# 331   1173    electronic        indian     electronic    electronic
# 332   1176    electronic          rock     electronic    electronic
# 333   1180    electronic          rock            NaN           NaN
# 334   1182          rock           pop        country       country
#
#     Wrong Label_75
# 0        classical
# 1              NaN
# 2       electronic
# 3            opera
# 4        classical
# ..             ...
# 330            NaN
# 331     electronic
# 332     electronic
# 333            NaN
# 334        country
#
# [335 rows x 6 columns]

# %%
merged_df = merged_df[['Index', 'Correct Label', 'Wrong Label_0', 'Wrong Label_25',
       'Wrong Label_5', 'Wrong Label_75']]

# %%
merged_df = merged_df.dropna(subset=['Wrong Label_0',  'Wrong Label_25', 'Wrong Label_5', 'Wrong Label_75'])

# %%
merged_df
# Out:
#      Index Correct Label Wrong Label_0 Wrong Label_25 Wrong Label_5  \
# 0        2       country     classical      classical     classical
# 2        9       new age    electronic     electronic    electronic
# 3       10     classical         opera          opera         opera
# 9       21         opera     classical      classical     classical
# 10      24           pop          rock           rock          rock
# ..     ...           ...           ...            ...           ...
# 319   1133         opera     classical      classical     classical
# 320   1134        indian     classical      classical         opera
# 331   1173        indian    electronic     electronic    electronic
# 332   1176          rock    electronic     electronic    electronic
# 334   1182           pop          rock        country       country
#
#     Wrong Label_75
# 0        classical
# 2       electronic
# 3            opera
# 9        classical
# 10            rock
# ..             ...
# 319      classical
# 320      classical
# 331     electronic
# 332     electronic
# 334        country
#
# [121 rows x 6 columns]

# %%
# merged_df = merged_df[['Index', 'Correct Label', 'Wrong Label_0',  'Wrong Label_4', 'Wrong Label_5', 'Wrong Label_6']]

# Initialize a new column with zeros
merged_df['Highest Wrong Label'] = 0

# Iterate over each row to count the number of identical wrong labels
for i, row in merged_df.iterrows():
    wrong_labels = row[['Wrong Label_0',  'Wrong Label_25', 'Wrong Label_5', 'Wrong Label_75']]
    # Drop NaN values before checking uniqueness
    unique_labels = wrong_labels.dropna().value_counts().index.tolist()[0] 
    unique_labels_count = wrong_labels.dropna().value_counts().iloc[0]
    merged_df.at[i, 'Highest Wrong Label'] = unique_labels_count

# %%
merged_df['Highest Wrong Label'].value_counts()
# Out:
# Highest Wrong Label
# 4    62
# 3    40
# 2    18
# 1     1
# Name: count, dtype: int64

# %%
error_an_path = os.path.join(checkpoint_folder, 'error_analysis_df.csv')
merged_df.to_csv(error_an_path)

# %%
# sentences = ["This is an example sentence", "Each sentence is converted"]
# embeddings = model.encode(sentences)
# print(embeddings.shape)

# %% [markdown]
# To create the 'df_w_robertaemb' from scratch

# %%
# df = pd.read_csv('/home/mendu/Thesis/data/magnatagatune/saved_df_data/df_w_captions.csv', index_col = [0])

# ### Adding the caption_embedding column
# '''creating a model object with a simple architecture of a pretrained model and a pooling layer after it'''

# ## Step 1: use an existing language model
# word_embedding_model = models.Transformer('distilroberta-base')

# ## Step 2: use a pool function over the token embeddings
# pooling_model = models.Pooling(word_embedding_model.get_word_embedding_dimension())

# ## Join steps 1 and 2 using the modules argument
# model = SentenceTransformer(modules=[word_embedding_model, pooling_model])
# df['caption_embedding'] = df['caption_writing'].apply(lambda x: expit(model.encode(x)))

# # df
# # df['caption_embedding'][2]
# len(df['caption_embedding'][2])
# df
# df.to_csv('/home/mendu/Thesis/data/magnatagatune/saved_df_data/df_w_robertaemb.csv')
# df.to_pickle("/home/mendu/Thesis/data/magnatagatune/saved_df_data/df_w_robertaemb.pkl")
