# %%
# Importing necessary libraries
# TODO:clean this
import pandas as pd
import numpy as np
import os
import pickle 
pd.options.mode.chained_assignment = None 
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import ParameterGrid
import cv2
import keras
from tensorflow import keras
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, Activation
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from tensorflow.keras.losses import categorical_crossentropy
from collections import OrderedDict
import pyarrow.parquet as pa
# from cnnmodel import ModelSubClassing
# Out:
# 2024-07-31 06:05:47.790579: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-31 06:05:47.832338: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-31 06:05:48.494727: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
#df for 64 embeddings
df = pd.read_pickle('/home/mendu/Thesis/data/magnatagatune/saved_df_data/df_w_embeddings.pkl')
df
# Out:
#                                                   mp3_path        tags  \
# clip_id
# 2        american_bach_soloists-j_s__bach_solo_cantatas...       opera
# 6        american_bach_soloists-j_s__bach_solo_cantatas...       opera
# 10       american_bach_soloists-j_s__bach_solo_cantatas...       opera
# 11       american_bach_soloists-j_s__bach_solo_cantatas...       opera
# 14                lvx_nova-lvx_nova-01-contimune-30-59.mp3  electronic
# ...                                                    ...         ...
# 58896    jacob_heringman-blame_not_my_lute-56-la_bressa...   classical
# 58897    jacob_heringman-blame_not_my_lute-56-la_bressa...   classical
# 58898    jacob_heringman-blame_not_my_lute-56-la_bressa...   classical
# 58907    jacob_heringman-blame_not_my_lute-57-lost_is_m...   classical
# 58915    jacob_heringman-blame_not_my_lute-58-a_toy_for...   classical
#
#                                            caption_writing  \
# clip_id
# 2        Experience the majestic beauty of classical mu...
# 6        Experience the rich sound of classical eleganc...
# 10       This powerful classic opera piece showcases th...
# 11       This atmospheric and introspective song blends...
# 14       This upbeat dance track features a pulsing tec...
# ...                                                    ...
# 58896    This classical guitar solo piece features intr...
# 58897    This beautiful classical piece features a haun...
# 58898    This classical piece features beautiful melodi...
# 58907    This beautiful classical piece features a gent...
# 58915    This beautiful classical guitar melody is slow...
#
#                                          caption_embedding
# clip_id
# 2        [0.0018344965, 1.0, 1.0, 2.655105e-06, 1.50058...
# 6        [0.00030539755, 1.0, 1.0, 7.7272097e-07, 1.570...
# 10       [0.0017760618, 1.0, 1.0, 5.9899867e-06, 4.3203...
# 11       [0.00037677313, 1.0, 1.0, 3.5533972e-07, 2.639...
# 14       [0.011517418, 0.9999858, 0.99753535, 0.0061413...
# ...                                                    ...
# 58896    [0.009028655, 1.0, 1.0, 5.342795e-06, 2.080080...
# 58897    [0.00088836084, 1.0, 1.0, 1.0079755e-06, 5.713...
# 58898    [0.0050765076, 1.0, 1.0, 9.212903e-06, 2.80899...
# 58907    [0.0013480721, 1.0, 1.0, 1.892443e-06, 1.53413...
# 58915    [0.00462206, 1.0, 0.9999999, 1.4287562e-05, 9....
#
# [11826 rows x 4 columns]

# %% [markdown]
# ## Training the model

# %%
data = np.load('/home/mendu/Thesis/data/magnatagatune/saved_df_data/data_array.npy')

# %%
# Caption Embeddings
embeddings = df['caption_embedding']

# %%
#normalize data
data = data.astype('float32')/255.0

data.shape
# Out:
# (11826, 128, 1255)

# %%
# Reshape data to include the channel dimension
data = data.reshape((-1, 128, 1255, 1))

# Split data into training and validation sets
X_train_spec, X_val_spec, X_train_embed, X_val_embed, y_train, y_val = train_test_split(data, embeddings, pd.get_dummies(df['tags']), test_size=0.1, random_state=42)

# %%
# Now, convert this array of arrays into a proper 2D NumPy array
X_train_embed_array = np.stack(X_train_embed, axis=0)

# Check the new shape to ensure it's (450, 64)
print("Shape after conversion:", X_train_embed_array.shape)

# Convert the 2D NumPy array to a TensorFlow tensor
X_train_embed_tensor = tf.convert_to_tensor(X_train_embed_array, dtype=tf.float32)

# Check the shape of the resulting tensor
print("Tensor shape:", X_train_embed_tensor.shape)
# Out:
# Shape after conversion: (10643, 64)
# Tensor shape: (10643, 64)
# 2024-07-31 06:05:53.527076: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
# Convert the 1D array of arrays into a proper 2D NumPy array
X_val_embed_array = np.stack(X_val_embed, axis=0)

# Check the new shape to ensure it's in the correct format
print("Shape after conversion:", X_val_embed_array.shape)

# Convert the 2D NumPy array to a TensorFlow tensor
X_val_embed_tensor = tf.convert_to_tensor(X_val_embed_array, dtype=tf.float32)

# Check the shape of the resulting tensor
print("Tensor shape:", X_val_embed_tensor.shape)
# Out:
# Shape after conversion: (1183, 64)
# Tensor shape: (1183, 64)

# %%
# Convert training data to tensors
X_train_spec = tf.convert_to_tensor(X_train_spec, dtype=tf.float32)
y_train = tf.convert_to_tensor(y_train, dtype=tf.float32)

# Convert validation data to tensors
X_val_spec = tf.convert_to_tensor(X_val_spec, dtype=tf.float32)
y_val = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
# Initialize ImageDataGenerator with necessary augmentations
datagen = ImageDataGenerator(
    width_shift_range=0.2,
    height_shift_range=0.2
)

datagen.fit(X_train_spec)

# %%
# Define num_classes based on the number of unique genres
num_classes = y_train.shape[1]
num_classes
# Out:
# 8

# %%
X_train_spec.shape
# Out:
# TensorShape([10643, 128, 1255, 1])

# %%
embeddings = embeddings.reset_index(drop = True)

# %%
# removing 50% of training data
# Get the number of samples
num_samples = X_train_spec.shape[0]

# Generate a random permutation of indices from 0 to num_samples - 1
random_indices = np.random.permutation(num_samples)

# Select the first 50% of the indices
selected_indices = random_indices[:num_samples // 2]

# Subset the data and embeddings using the selected indices
reduced_data = tf.gather(X_train_spec, selected_indices)
reduced_embeddings = tf.gather(X_train_embed_tensor, selected_indices)
reduced_y_train = tf.gather(y_train, selected_indices)

# Check the shapes of the reduced data
print(reduced_data.shape) 
print(reduced_embeddings.shape)
# Out:
# (5321, 128, 1255, 1)
# (5321, 64)

# %%
y_train.shape
# Out:
# TensorShape([10643, 8])

# %%
class ModelSubClassing(keras.Model):
    def __init__(self, num_classes, l1_reg=0.01, l2_reg=0.001, alpha = 0.5):
        super().__init__()
        
        # Define L1 and L2 regularizer
        self.l1_l2_regularizer = regularizers.l1_l2(l1=l1_reg, l2=l2_reg)
        # self.l2_regularizer = regularizers.l2(l2_reg)
        
        # Define alpha the loss regulator
        self.alpha = alpha
        
        # number of classes
        self.num_classes = num_classes
        
        # Initialize layers as None
        self.conv1 = None
        self.max1 = None
        self.bn1 = None
        self.conv2 = None
        self.bn2 = None
        self.max2 = None
        self.drop1 = None
        self.conv3 = None
        self.bn3 = None
        self.max3 = None
        self.drop2 = None
        self.flatten = None
        self.dense128 = None
        self.dense128_activation = None
        self.dense128_do = None
        self.dense64 = None
        self.dense64_activation = None
        self.dense_out = None
        
        self.loss_tracker = keras.metrics.Mean(name="loss")
        self.accuracy = keras.metrics.CategoricalAccuracy(name="accuracy")

    def build(self, input_shape):
        # Create layers
        self.conv1 = Conv2D(32, 8, activation="relu", kernel_regularizer=self.l1_l2_regularizer)
        self.max1  = MaxPooling2D(3)
        self.bn1   = BatchNormalization(momentum=0.9)

        self.conv2 = Conv2D(64, 8, activation="relu", kernel_regularizer=self.l1_l2_regularizer)
        self.bn2   = BatchNormalization(momentum=0.9)
        self.max2  = MaxPooling2D(3)
        self.drop1 = Dropout(0.3)

        self.conv3 = Conv2D(128, 8, activation="relu", kernel_regularizer=self.l1_l2_regularizer)
        self.bn3   = BatchNormalization(momentum=0.9)
        self.max3  = MaxPooling2D(3)
        self.drop2 = Dropout(0.3)

        self.flatten = Flatten()
        self.dense128 = Dense(128)
        self.dense128_activation = Activation('relu')
        self.dense128_do = Dropout(0.3)
        self.dense64 = Dense(64)
        self.dense64_act_sig = Activation('sigmoid')
        self.dense64_act_relu = Activation('relu')
        self.dense_out = Dense(self.num_classes, activation="softmax")
        
        super().build(input_shape)

    def call(self, inputs, training=None):
        # Unpack the inputs
        mel_spectrogram = inputs[0]

        # Forward pass: block 1
        x = self.conv1(mel_spectrogram)
        x = self.max1(x)
        x = self.bn1(x, training=training)

        # Forward pass: block 2
        x = self.conv2(x)
        x = self.bn2(x, training=training)
        x = self.max2(x)
        x = self.drop1(x, training=training)

        # Forward pass: block 3
        x = self.conv3(x)
        x = self.bn3(x, training=training)
        x = self.max3(x)
        x = self.drop2(x, training=training)

        # Flatten and dense layers
        x = self.flatten(x)
        x_dense128 = self.dense128(x)
        x_dense128_act = self.dense128_activation(x_dense128)
        x_dense128_act = self.dense128_do(x_dense128_act, training=training)
        
        # dense layer 64
        x_dense64 = self.dense64(x_dense128_act)
        x_dense64_act_sig = self.dense64_act_sig(x_dense64)
        x_dense64_act_relu = self.dense64_act_relu(x_dense64)
        y_hat = self.dense_out(x_dense64_act_relu)
        
        return y_hat, x_dense64_act_sig


    def train_step(self, data):
        # Unpack the data
        (mel_spectrogram, caption_embedding), y = data

        with tf.GradientTape() as tape: 
        #here we get the gradients of the trainable weights with this loss
            y_pred, x_dense64 = self((mel_spectrogram, caption_embedding), training=True)  # Forward pass
            # Compute the standard loss value
            loss = self.compiled_loss(y, y_pred)
            custom_loss = self.custom_loss(caption_embedding, x_dense64)
            total_loss = (1 - self.alpha) * loss + self.alpha * custom_loss

        # Compute gradients
        gradients = tape.gradient(total_loss, self.trainable_variables)

        # Update weights
        self.optimizer.apply_gradients(zip(gradients, self.trainable_variables))

        # Update the loss metric and any additional metrics
        self.loss_tracker.update_state(total_loss)
        self.accuracy.update_state(y, y_pred)

        return {
            "loss": self.loss_tracker.result(),
            "accuracy": self.accuracy.result(),
            "crossentropy_loss": loss,
            "embedding_loss": custom_loss,
            "total_loss": total_loss
        }

        
    def test_step(self, data):
        # Unpack the data
        (mel_spectrogram, caption_embedding), y = data

        
        y_pred, x_dense64 = self((mel_spectrogram, caption_embedding), training=False)  # Forward pass
        # Compute the standard loss value
        loss = self.compiled_loss(y, y_pred)
        custom_loss = self.custom_loss(caption_embedding, x_dense64)
        total_loss = (1 - self.alpha) * loss + self.alpha * custom_loss

        # Update the loss metric and any additional metrics
        self.loss_tracker.update_state(total_loss)
        self.accuracy.update_state(y, y_pred)

        return {
            "loss": self.loss_tracker.result(),
            "accuracy": self.accuracy.result(),
            "crossentropy_loss": loss,
            "embedding_loss": custom_loss,
            "total_loss": total_loss
        }
        
    # Add a custom loss method in the model
    def custom_loss(self, caption_embedding, x_dense64):
        return tf.reduce_mean(tf.square(caption_embedding - x_dense64))

    #new
    @property
    def metrics(self):
        # List all metrics to be reset after each epoch
        return [self.loss_tracker, self.accuracy]
    
# Creating the class object
model = ModelSubClassing(num_classes, l2_reg= 0.01)

# Compile the model
adam_opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=adam_opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
rlronp = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=10, verbose=1)
early_stopper = EarlyStopping(monitor='val_loss', patience=19, verbose=1, restore_best_weights=True)

history = model.fit(
    (reduced_data, reduced_embeddings),
    reduced_y_train,
    epochs=100,
    batch_size=32,
    validation_data=((X_val_spec, X_val_embed_tensor), y_val),
    callbacks = [early_stopper, rlronp]
)
# Out:
# Epoch 1/100
# /home/mendu/miniconda3/envs/myenv/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py:612: UserWarning: `model.compiled_loss()` is deprecated. Instead, use `model.compute_loss(x, y, y_pred, sample_weight)`.
#   warnings.warn(
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 71s 408ms/step - accuracy: 0.3734 - crossentropy_loss: 62.9224 - embedding_loss: 0.2714 - loss: 36.7932 - total_loss: 31.5969 - val_accuracy: 0.5875 - val_loss: 21.4847 - learning_rate: 1.0000e-04
# Epoch 2/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 402ms/step - accuracy: 0.5895 - crossentropy_loss: 28.7909 - embedding_loss: 0.2447 - loss: 17.7125 - total_loss: 14.5178 - val_accuracy: 0.6796 - val_loss: 9.0951 - learning_rate: 1.0000e-04
# Epoch 3/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 402ms/step - accuracy: 0.6255 - crossentropy_loss: 13.1035 - embedding_loss: 0.2292 - loss: 7.7819 - total_loss: 6.6663 - val_accuracy: 0.5985 - val_loss: 4.9588 - learning_rate: 1.0000e-04
# Epoch 4/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 402ms/step - accuracy: 0.6831 - crossentropy_loss: 7.8437 - embedding_loss: 0.2174 - loss: 4.4013 - total_loss: 4.0306 - val_accuracy: 0.7202 - val_loss: 3.3166 - learning_rate: 1.0000e-04
# Epoch 5/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 68s 406ms/step - accuracy: 0.6954 - crossentropy_loss: 5.7340 - embedding_loss: 0.2071 - loss: 3.1696 - total_loss: 2.9706 - val_accuracy: 0.7025 - val_loss: 2.5739 - learning_rate: 1.0000e-04
# Epoch 6/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 68s 407ms/step - accuracy: 0.7034 - crossentropy_loss: 4.5872 - embedding_loss: 0.1935 - loss: 2.4954 - total_loss: 2.3904 - val_accuracy: 0.7025 - val_loss: 2.1722 - learning_rate: 1.0000e-04
# Epoch 7/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 403ms/step - accuracy: 0.7171 - crossentropy_loss: 3.6921 - embedding_loss: 0.1857 - loss: 2.0250 - total_loss: 1.9389 - val_accuracy: 0.6712 - val_loss: 1.8188 - learning_rate: 1.0000e-04
# Epoch 8/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 402ms/step - accuracy: 0.7205 - crossentropy_loss: 3.1593 - embedding_loss: 0.1756 - loss: 1.7260 - total_loss: 1.6675 - val_accuracy: 0.7202 - val_loss: 1.6251 - learning_rate: 1.0000e-04
# Epoch 9/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 402ms/step - accuracy: 0.7454 - crossentropy_loss: 2.7868 - embedding_loss: 0.1667 - loss: 1.5188 - total_loss: 1.4767 - val_accuracy: 0.5706 - val_loss: 1.5527 - learning_rate: 1.0000e-04
# Epoch 10/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.7415 - crossentropy_loss: 2.5274 - embedding_loss: 0.1599 - loss: 1.3773 - total_loss: 1.3437 - val_accuracy: 0.7895 - val_loss: 1.2115 - learning_rate: 1.0000e-04
# Epoch 11/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 401ms/step - accuracy: 0.7429 - crossentropy_loss: 2.2931 - embedding_loss: 0.1525 - loss: 1.2555 - total_loss: 1.2228 - val_accuracy: 0.7650 - val_loss: 1.1114 - learning_rate: 1.0000e-04
# Epoch 12/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 401ms/step - accuracy: 0.7595 - crossentropy_loss: 2.1229 - embedding_loss: 0.1451 - loss: 1.1447 - total_loss: 1.1340 - val_accuracy: 0.7320 - val_loss: 1.1327 - learning_rate: 1.0000e-04
# Epoch 13/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.7657 - crossentropy_loss: 1.9742 - embedding_loss: 0.1362 - loss: 1.0802 - total_loss: 1.0552 - val_accuracy: 0.7261 - val_loss: 1.0862 - learning_rate: 1.0000e-04
# Epoch 14/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 401ms/step - accuracy: 0.7543 - crossentropy_loss: 1.8811 - embedding_loss: 0.1314 - loss: 1.0419 - total_loss: 1.0062 - val_accuracy: 0.6213 - val_loss: 1.1629 - learning_rate: 1.0000e-04
# Epoch 15/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.7705 - crossentropy_loss: 1.7815 - embedding_loss: 0.1251 - loss: 0.9462 - total_loss: 0.9533 - val_accuracy: 0.6585 - val_loss: 1.1341 - learning_rate: 1.0000e-04
# Epoch 16/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 401ms/step - accuracy: 0.7863 - crossentropy_loss: 1.7032 - embedding_loss: 0.1203 - loss: 0.9090 - total_loss: 0.9118 - val_accuracy: 0.7430 - val_loss: 0.9228 - learning_rate: 1.0000e-04
# Epoch 17/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 401ms/step - accuracy: 0.7899 - crossentropy_loss: 1.6616 - embedding_loss: 0.1155 - loss: 0.8819 - total_loss: 0.8885 - val_accuracy: 0.7295 - val_loss: 0.9511 - learning_rate: 1.0000e-04
# Epoch 18/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 401ms/step - accuracy: 0.7871 - crossentropy_loss: 1.6421 - embedding_loss: 0.1105 - loss: 0.8730 - total_loss: 0.8763 - val_accuracy: 0.7371 - val_loss: 0.9267 - learning_rate: 1.0000e-04
# Epoch 19/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.7927 - crossentropy_loss: 1.5941 - embedding_loss: 0.1061 - loss: 0.8440 - total_loss: 0.8501 - val_accuracy: 0.7785 - val_loss: 0.8494 - learning_rate: 1.0000e-04
# Epoch 20/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 401ms/step - accuracy: 0.7865 - crossentropy_loss: 1.5781 - embedding_loss: 0.1042 - loss: 0.8393 - total_loss: 0.8411 - val_accuracy: 0.6610 - val_loss: 0.9986 - learning_rate: 1.0000e-04
# Epoch 21/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.8142 - crossentropy_loss: 1.5057 - embedding_loss: 0.0998 - loss: 0.7969 - total_loss: 0.8028 - val_accuracy: 0.6788 - val_loss: 0.9551 - learning_rate: 1.0000e-04
# Epoch 22/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.8077 - crossentropy_loss: 1.4795 - embedding_loss: 0.0963 - loss: 0.7839 - total_loss: 0.7879 - val_accuracy: 0.8107 - val_loss: 0.7834 - learning_rate: 1.0000e-04
# Epoch 23/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.8091 - crossentropy_loss: 1.4754 - embedding_loss: 0.0939 - loss: 0.7717 - total_loss: 0.7846 - val_accuracy: 0.6145 - val_loss: 1.0792 - learning_rate: 1.0000e-04
# Epoch 24/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 399ms/step - accuracy: 0.8065 - crossentropy_loss: 1.4752 - embedding_loss: 0.0905 - loss: 0.7878 - total_loss: 0.7829 - val_accuracy: 0.7785 - val_loss: 0.7917 - learning_rate: 1.0000e-04
# Epoch 25/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.8111 - crossentropy_loss: 1.4318 - embedding_loss: 0.0876 - loss: 0.7573 - total_loss: 0.7597 - val_accuracy: 0.7549 - val_loss: 0.8245 - learning_rate: 1.0000e-04
# Epoch 26/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.8177 - crossentropy_loss: 1.4585 - embedding_loss: 0.0849 - loss: 0.7688 - total_loss: 0.7717 - val_accuracy: 0.7354 - val_loss: 0.8747 - learning_rate: 1.0000e-04
# Epoch 27/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.8254 - crossentropy_loss: 1.3878 - embedding_loss: 0.0808 - loss: 0.7434 - total_loss: 0.7343 - val_accuracy: 0.6374 - val_loss: 0.9653 - learning_rate: 1.0000e-04
# Epoch 28/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.8197 - crossentropy_loss: 1.4160 - embedding_loss: 0.0793 - loss: 0.7427 - total_loss: 0.7476 - val_accuracy: 0.8014 - val_loss: 0.7459 - learning_rate: 1.0000e-04
# Epoch 29/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 399ms/step - accuracy: 0.8305 - crossentropy_loss: 1.3680 - embedding_loss: 0.0780 - loss: 0.7138 - total_loss: 0.7230 - val_accuracy: 0.8107 - val_loss: 0.7208 - learning_rate: 1.0000e-04
# Epoch 30/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 399ms/step - accuracy: 0.8303 - crossentropy_loss: 1.3387 - embedding_loss: 0.0772 - loss: 0.6965 - total_loss: 0.7080 - val_accuracy: 0.7498 - val_loss: 0.8028 - learning_rate: 1.0000e-04
# Epoch 31/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.8343 - crossentropy_loss: 1.3282 - embedding_loss: 0.0763 - loss: 0.6951 - total_loss: 0.7022 - val_accuracy: 0.7937 - val_loss: 0.7492 - learning_rate: 1.0000e-04
# Epoch 32/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 401ms/step - accuracy: 0.8224 - crossentropy_loss: 1.3225 - embedding_loss: 0.0738 - loss: 0.7127 - total_loss: 0.6982 - val_accuracy: 0.7929 - val_loss: 0.7288 - learning_rate: 1.0000e-04
# Epoch 33/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.8339 - crossentropy_loss: 1.2920 - embedding_loss: 0.0732 - loss: 0.6866 - total_loss: 0.6826 - val_accuracy: 0.7794 - val_loss: 0.7386 - learning_rate: 1.0000e-04
# Epoch 34/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 401ms/step - accuracy: 0.8478 - crossentropy_loss: 1.2365 - embedding_loss: 0.0716 - loss: 0.6547 - total_loss: 0.6541 - val_accuracy: 0.7447 - val_loss: 0.8464 - learning_rate: 1.0000e-04
# Epoch 35/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.8438 - crossentropy_loss: 1.2568 - embedding_loss: 0.0699 - loss: 0.6611 - total_loss: 0.6634 - val_accuracy: 0.8014 - val_loss: 0.7196 - learning_rate: 1.0000e-04
# Epoch 36/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.8304 - crossentropy_loss: 1.2711 - embedding_loss: 0.0706 - loss: 0.6708 - total_loss: 0.6708 - val_accuracy: 0.8183 - val_loss: 0.6853 - learning_rate: 1.0000e-04
# Epoch 37/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.8595 - crossentropy_loss: 1.2197 - embedding_loss: 0.0683 - loss: 0.6187 - total_loss: 0.6440 - val_accuracy: 0.5883 - val_loss: 1.4033 - learning_rate: 1.0000e-04
# Epoch 38/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 399ms/step - accuracy: 0.8553 - crossentropy_loss: 1.2239 - embedding_loss: 0.0686 - loss: 0.6393 - total_loss: 0.6463 - val_accuracy: 0.7726 - val_loss: 0.7472 - learning_rate: 1.0000e-04
# Epoch 39/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 401ms/step - accuracy: 0.8547 - crossentropy_loss: 1.2202 - embedding_loss: 0.0676 - loss: 0.6422 - total_loss: 0.6439 - val_accuracy: 0.7971 - val_loss: 0.7531 - learning_rate: 1.0000e-04
# Epoch 40/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.8553 - crossentropy_loss: 1.2199 - embedding_loss: 0.0662 - loss: 0.6494 - total_loss: 0.6431 - val_accuracy: 0.7320 - val_loss: 0.8044 - learning_rate: 1.0000e-04
# Epoch 41/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 399ms/step - accuracy: 0.8485 - crossentropy_loss: 1.1891 - embedding_loss: 0.0662 - loss: 0.6321 - total_loss: 0.6276 - val_accuracy: 0.7540 - val_loss: 0.7625 - learning_rate: 1.0000e-04
# Epoch 42/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.8694 - crossentropy_loss: 1.1696 - embedding_loss: 0.0653 - loss: 0.6105 - total_loss: 0.6174 - val_accuracy: 0.8183 - val_loss: 0.7110 - learning_rate: 1.0000e-04
# Epoch 43/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 399ms/step - accuracy: 0.8607 - crossentropy_loss: 1.1752 - embedding_loss: 0.0650 - loss: 0.6342 - total_loss: 0.6201 - val_accuracy: 0.6720 - val_loss: 0.9586 - learning_rate: 1.0000e-04
# Epoch 44/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.8686 - crossentropy_loss: 1.1387 - embedding_loss: 0.0644 - loss: 0.5922 - total_loss: 0.6015 - val_accuracy: 0.6441 - val_loss: 1.0701 - learning_rate: 1.0000e-04
# Epoch 45/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.8727 - crossentropy_loss: 1.1364 - embedding_loss: 0.0644 - loss: 0.5993 - total_loss: 0.6004 - val_accuracy: 0.7557 - val_loss: 0.7842 - learning_rate: 1.0000e-04
# Epoch 46/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.8757 - crossentropy_loss: 1.1325 - embedding_loss: 0.0635 - loss: 0.6087 - total_loss: 0.5980
# Epoch 46: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 401ms/step - accuracy: 0.8757 - crossentropy_loss: 1.1325 - embedding_loss: 0.0635 - loss: 0.6087 - total_loss: 0.5980 - val_accuracy: 0.7295 - val_loss: 0.8089 - learning_rate: 1.0000e-04
# Epoch 47/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 401ms/step - accuracy: 0.8994 - crossentropy_loss: 0.9134 - embedding_loss: 0.0629 - loss: 0.5153 - total_loss: 0.4882 - val_accuracy: 0.8039 - val_loss: 0.6255 - learning_rate: 5.0000e-05
# Epoch 48/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.9095 - crossentropy_loss: 0.8212 - embedding_loss: 0.0617 - loss: 0.4420 - total_loss: 0.4415 - val_accuracy: 0.7760 - val_loss: 0.6557 - learning_rate: 5.0000e-05
# Epoch 49/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.9119 - crossentropy_loss: 0.8133 - embedding_loss: 0.0617 - loss: 0.4380 - total_loss: 0.4375 - val_accuracy: 0.8047 - val_loss: 0.6009 - learning_rate: 5.0000e-05
# Epoch 50/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.9110 - crossentropy_loss: 0.8196 - embedding_loss: 0.0608 - loss: 0.4340 - total_loss: 0.4402 - val_accuracy: 0.8166 - val_loss: 0.5753 - learning_rate: 5.0000e-05
# Epoch 51/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 401ms/step - accuracy: 0.9116 - crossentropy_loss: 0.8157 - embedding_loss: 0.0606 - loss: 0.4273 - total_loss: 0.4381 - val_accuracy: 0.8183 - val_loss: 0.5908 - learning_rate: 5.0000e-05
# Epoch 52/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 401ms/step - accuracy: 0.9064 - crossentropy_loss: 0.8164 - embedding_loss: 0.0608 - loss: 0.4333 - total_loss: 0.4386 - val_accuracy: 0.8064 - val_loss: 0.5888 - learning_rate: 5.0000e-05
# Epoch 53/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 399ms/step - accuracy: 0.9157 - crossentropy_loss: 0.8022 - embedding_loss: 0.0609 - loss: 0.4266 - total_loss: 0.4315 - val_accuracy: 0.8259 - val_loss: 0.5739 - learning_rate: 5.0000e-05
# Epoch 54/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.9049 - crossentropy_loss: 0.7938 - embedding_loss: 0.0605 - loss: 0.4346 - total_loss: 0.4272 - val_accuracy: 0.8157 - val_loss: 0.5799 - learning_rate: 5.0000e-05
# Epoch 55/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 399ms/step - accuracy: 0.9198 - crossentropy_loss: 0.7896 - embedding_loss: 0.0602 - loss: 0.4273 - total_loss: 0.4249 - val_accuracy: 0.7971 - val_loss: 0.6098 - learning_rate: 5.0000e-05
# Epoch 56/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.9132 - crossentropy_loss: 0.7679 - embedding_loss: 0.0603 - loss: 0.4104 - total_loss: 0.4141 - val_accuracy: 0.8216 - val_loss: 0.5726 - learning_rate: 5.0000e-05
# Epoch 57/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 401ms/step - accuracy: 0.9244 - crossentropy_loss: 0.7469 - embedding_loss: 0.0604 - loss: 0.3954 - total_loss: 0.4036 - val_accuracy: 0.8073 - val_loss: 0.5965 - learning_rate: 5.0000e-05
# Epoch 58/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.9129 - crossentropy_loss: 0.7924 - embedding_loss: 0.0598 - loss: 0.4320 - total_loss: 0.4261 - val_accuracy: 0.7777 - val_loss: 0.6370 - learning_rate: 5.0000e-05
# Epoch 59/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.9137 - crossentropy_loss: 0.7654 - embedding_loss: 0.0601 - loss: 0.4177 - total_loss: 0.4127 - val_accuracy: 0.8183 - val_loss: 0.5737 - learning_rate: 5.0000e-05
# Epoch 60/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.9313 - crossentropy_loss: 0.7349 - embedding_loss: 0.0595 - loss: 0.3971 - total_loss: 0.3972 - val_accuracy: 0.7980 - val_loss: 0.5947 - learning_rate: 5.0000e-05
# Epoch 61/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 399ms/step - accuracy: 0.9352 - crossentropy_loss: 0.7228 - embedding_loss: 0.0599 - loss: 0.3820 - total_loss: 0.3913 - val_accuracy: 0.8149 - val_loss: 0.5945 - learning_rate: 5.0000e-05
# Epoch 62/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.9245 - crossentropy_loss: 0.7351 - embedding_loss: 0.0589 - loss: 0.3947 - total_loss: 0.3970 - val_accuracy: 0.8039 - val_loss: 0.5984 - learning_rate: 5.0000e-05
# Epoch 63/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.9323 - crossentropy_loss: 0.7210 - embedding_loss: 0.0588 - loss: 0.3842 - total_loss: 0.3899 - val_accuracy: 0.7971 - val_loss: 0.6345 - learning_rate: 5.0000e-05
# Epoch 64/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.9241 - crossentropy_loss: 0.7439 - embedding_loss: 0.0590 - loss: 0.3988 - total_loss: 0.4014 - val_accuracy: 0.8166 - val_loss: 0.5872 - learning_rate: 5.0000e-05
# Epoch 65/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.9326 - crossentropy_loss: 0.7096 - embedding_loss: 0.0592 - loss: 0.3882 - total_loss: 0.3844 - val_accuracy: 0.7988 - val_loss: 0.6059 - learning_rate: 5.0000e-05
# Epoch 66/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.9386 - crossentropy_loss: 0.7080 - embedding_loss: 0.0587 - loss: 0.3717 - total_loss: 0.3833
# Epoch 66: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.9386 - crossentropy_loss: 0.7080 - embedding_loss: 0.0587 - loss: 0.3718 - total_loss: 0.3833 - val_accuracy: 0.8056 - val_loss: 0.6027 - learning_rate: 5.0000e-05
# Epoch 67/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 399ms/step - accuracy: 0.9428 - crossentropy_loss: 0.6069 - embedding_loss: 0.0585 - loss: 0.3427 - total_loss: 0.3327 - val_accuracy: 0.8259 - val_loss: 0.5247 - learning_rate: 2.5000e-05
# Epoch 68/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.9412 - crossentropy_loss: 0.5690 - embedding_loss: 0.0583 - loss: 0.3188 - total_loss: 0.3136 - val_accuracy: 0.8157 - val_loss: 0.5144 - learning_rate: 2.5000e-05
# Epoch 69/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 399ms/step - accuracy: 0.9521 - crossentropy_loss: 0.5442 - embedding_loss: 0.0581 - loss: 0.2956 - total_loss: 0.3011 - val_accuracy: 0.8208 - val_loss: 0.5140 - learning_rate: 2.5000e-05
# Epoch 70/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.9417 - crossentropy_loss: 0.5464 - embedding_loss: 0.0581 - loss: 0.3046 - total_loss: 0.3022 - val_accuracy: 0.8115 - val_loss: 0.5213 - learning_rate: 2.5000e-05
# Epoch 71/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 399ms/step - accuracy: 0.9447 - crossentropy_loss: 0.5278 - embedding_loss: 0.0581 - loss: 0.2983 - total_loss: 0.2930 - val_accuracy: 0.8073 - val_loss: 0.5288 - learning_rate: 2.5000e-05
# Epoch 72/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 399ms/step - accuracy: 0.9411 - crossentropy_loss: 0.5403 - embedding_loss: 0.0580 - loss: 0.2996 - total_loss: 0.2992 - val_accuracy: 0.8292 - val_loss: 0.5121 - learning_rate: 2.5000e-05
# Epoch 73/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 399ms/step - accuracy: 0.9424 - crossentropy_loss: 0.5430 - embedding_loss: 0.0577 - loss: 0.3080 - total_loss: 0.3003 - val_accuracy: 0.8081 - val_loss: 0.5309 - learning_rate: 2.5000e-05
# Epoch 74/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.9467 - crossentropy_loss: 0.5359 - embedding_loss: 0.0577 - loss: 0.2946 - total_loss: 0.2968 - val_accuracy: 0.8056 - val_loss: 0.5518 - learning_rate: 2.5000e-05
# Epoch 75/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 399ms/step - accuracy: 0.9525 - crossentropy_loss: 0.5289 - embedding_loss: 0.0576 - loss: 0.2884 - total_loss: 0.2933 - val_accuracy: 0.8115 - val_loss: 0.5365 - learning_rate: 2.5000e-05
# Epoch 76/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 399ms/step - accuracy: 0.9454 - crossentropy_loss: 0.5225 - embedding_loss: 0.0574 - loss: 0.2905 - total_loss: 0.2899 - val_accuracy: 0.8242 - val_loss: 0.4942 - learning_rate: 2.5000e-05
# Epoch 77/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.9550 - crossentropy_loss: 0.5093 - embedding_loss: 0.0573 - loss: 0.2827 - total_loss: 0.2833 - val_accuracy: 0.8073 - val_loss: 0.5175 - learning_rate: 2.5000e-05
# Epoch 78/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.9538 - crossentropy_loss: 0.5185 - embedding_loss: 0.0575 - loss: 0.2862 - total_loss: 0.2880 - val_accuracy: 0.8242 - val_loss: 0.4941 - learning_rate: 2.5000e-05
# Epoch 79/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 399ms/step - accuracy: 0.9511 - crossentropy_loss: 0.5119 - embedding_loss: 0.0573 - loss: 0.2844 - total_loss: 0.2846 - val_accuracy: 0.8250 - val_loss: 0.4951 - learning_rate: 2.5000e-05
# Epoch 80/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 399ms/step - accuracy: 0.9473 - crossentropy_loss: 0.5231 - embedding_loss: 0.0573 - loss: 0.2859 - total_loss: 0.2902 - val_accuracy: 0.8276 - val_loss: 0.4988 - learning_rate: 2.5000e-05
# Epoch 81/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 399ms/step - accuracy: 0.9600 - crossentropy_loss: 0.5025 - embedding_loss: 0.0575 - loss: 0.2786 - total_loss: 0.2800 - val_accuracy: 0.7760 - val_loss: 0.5801 - learning_rate: 2.5000e-05
# Epoch 82/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.9461 - crossentropy_loss: 0.5205 - embedding_loss: 0.0573 - loss: 0.2974 - total_loss: 0.2889 - val_accuracy: 0.8284 - val_loss: 0.4997 - learning_rate: 2.5000e-05
# Epoch 83/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.9532 - crossentropy_loss: 0.5027 - embedding_loss: 0.0574 - loss: 0.2729 - total_loss: 0.2800 - val_accuracy: 0.8174 - val_loss: 0.5199 - learning_rate: 2.5000e-05
# Epoch 84/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.9561 - crossentropy_loss: 0.4975 - embedding_loss: 0.0572 - loss: 0.2803 - total_loss: 0.2774 - val_accuracy: 0.8183 - val_loss: 0.5147 - learning_rate: 2.5000e-05
# Epoch 85/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 399ms/step - accuracy: 0.9544 - crossentropy_loss: 0.5149 - embedding_loss: 0.0571 - loss: 0.2726 - total_loss: 0.2860 - val_accuracy: 0.8123 - val_loss: 0.5134 - learning_rate: 2.5000e-05
# Epoch 86/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 399ms/step - accuracy: 0.9521 - crossentropy_loss: 0.5115 - embedding_loss: 0.0572 - loss: 0.2878 - total_loss: 0.2843 - val_accuracy: 0.8123 - val_loss: 0.5122 - learning_rate: 2.5000e-05
# Epoch 87/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 399ms/step - accuracy: 0.9620 - crossentropy_loss: 0.4830 - embedding_loss: 0.0568 - loss: 0.2691 - total_loss: 0.2699 - val_accuracy: 0.8267 - val_loss: 0.5047 - learning_rate: 2.5000e-05
# Epoch 88/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.9504 - crossentropy_loss: 0.5033 - embedding_loss: 0.0568 - loss: 0.2819 - total_loss: 0.2800
# Epoch 88: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 399ms/step - accuracy: 0.9504 - crossentropy_loss: 0.5033 - embedding_loss: 0.0568 - loss: 0.2819 - total_loss: 0.2800 - val_accuracy: 0.8216 - val_loss: 0.5157 - learning_rate: 2.5000e-05
# Epoch 89/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.9642 - crossentropy_loss: 0.4494 - embedding_loss: 0.0567 - loss: 0.2538 - total_loss: 0.2531 - val_accuracy: 0.8225 - val_loss: 0.4828 - learning_rate: 1.2500e-05
# Epoch 90/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 399ms/step - accuracy: 0.9655 - crossentropy_loss: 0.4195 - embedding_loss: 0.0570 - loss: 0.2381 - total_loss: 0.2382 - val_accuracy: 0.8183 - val_loss: 0.4865 - learning_rate: 1.2500e-05
# Epoch 91/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 399ms/step - accuracy: 0.9680 - crossentropy_loss: 0.4163 - embedding_loss: 0.0568 - loss: 0.2340 - total_loss: 0.2366 - val_accuracy: 0.8242 - val_loss: 0.4773 - learning_rate: 1.2500e-05
# Epoch 92/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 399ms/step - accuracy: 0.9648 - crossentropy_loss: 0.4111 - embedding_loss: 0.0566 - loss: 0.2326 - total_loss: 0.2338 - val_accuracy: 0.8183 - val_loss: 0.4752 - learning_rate: 1.2500e-05
# Epoch 93/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 398ms/step - accuracy: 0.9579 - crossentropy_loss: 0.4154 - embedding_loss: 0.0566 - loss: 0.2383 - total_loss: 0.2360 - val_accuracy: 0.8132 - val_loss: 0.4715 - learning_rate: 1.2500e-05
# Epoch 94/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 399ms/step - accuracy: 0.9643 - crossentropy_loss: 0.4134 - embedding_loss: 0.0566 - loss: 0.2331 - total_loss: 0.2350 - val_accuracy: 0.8157 - val_loss: 0.4773 - learning_rate: 1.2500e-05
# Epoch 95/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 399ms/step - accuracy: 0.9628 - crossentropy_loss: 0.4140 - embedding_loss: 0.0561 - loss: 0.2306 - total_loss: 0.2350 - val_accuracy: 0.8174 - val_loss: 0.4825 - learning_rate: 1.2500e-05
# Epoch 96/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.9638 - crossentropy_loss: 0.4122 - embedding_loss: 0.0562 - loss: 0.2319 - total_loss: 0.2342 - val_accuracy: 0.8149 - val_loss: 0.4762 - learning_rate: 1.2500e-05
# Epoch 97/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 399ms/step - accuracy: 0.9602 - crossentropy_loss: 0.4202 - embedding_loss: 0.0565 - loss: 0.2375 - total_loss: 0.2384 - val_accuracy: 0.8107 - val_loss: 0.4934 - learning_rate: 1.2500e-05
# Epoch 98/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.9610 - crossentropy_loss: 0.4097 - embedding_loss: 0.0564 - loss: 0.2362 - total_loss: 0.2330 - val_accuracy: 0.8191 - val_loss: 0.4837 - learning_rate: 1.2500e-05
# Epoch 99/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 400ms/step - accuracy: 0.9635 - crossentropy_loss: 0.4125 - embedding_loss: 0.0563 - loss: 0.2339 - total_loss: 0.2344 - val_accuracy: 0.8174 - val_loss: 0.4977 - learning_rate: 1.2500e-05
# Epoch 100/100
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 67s 398ms/step - accuracy: 0.9650 - crossentropy_loss: 0.4112 - embedding_loss: 0.0563 - loss: 0.2316 - total_loss: 0.2338 - val_accuracy: 0.8267 - val_loss: 0.4737 - learning_rate: 1.2500e-05
# Restoring model weights from the end of the best epoch: 93.

# %%
# Plot a graph for training and validation loss
plt.figure(figsize=(10, 5)) # Optionally specify the figure size
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot a graph for training and validation accuracy
plt.figure(figsize=(10, 5)) # Optionally specify the figure size
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Get predictions
predictions = model.predict((X_val_spec, X_val_embed_tensor))
predicted_labels = np.argmax(predictions[0], axis=1)  # Converting probabilities to class labels
ground_truth = np.argmax(y_val, axis=1)  # Converting one-hot encoded ground truth to class labels

# Reshape predicted_labels and ground_truth to be 1D arrays
predicted_labels = np.reshape(predicted_labels, (-1,))
ground_truth = np.reshape(ground_truth, (-1,))

# Define class labels
class_labels = ['classical', 'country', 'electronic', 'indian',
                'new age', 'opera', 'pop', 'rock']

predicted_labels = [class_labels[i] for i in predicted_labels]
ground_truth = [class_labels[i] for i in ground_truth]

# Create a table with prediction and ground truth
comparison_table = pd.DataFrame({'Predicted': predicted_labels, 'Ground Truth': ground_truth})
# Get unique class labels
unique_labels = sorted(comparison_table['Ground Truth'].unique())

# Create confusion matrix
conf_matrix = confusion_matrix(comparison_table['Ground Truth'], comparison_table['Predicted'], labels=unique_labels)

# Convert confusion matrix to DataFrame for better visualization
conf_matrix_df = pd.DataFrame(conf_matrix, index=unique_labels, columns=unique_labels)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_df, annot=True, cmap='Blues', fmt='g', cbar=False)
plt.xlabel('Predicted Class')
plt.ylabel('Ground Truth')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step

# %%
# evaluate manually
train_loss, train_accuracy = model.evaluate((X_train_spec, X_train_embed_tensor), y_train, verbose=0)
val_loss, val_accuracy = model.evaluate((X_val_spec, X_val_embed_tensor), y_val, verbose=0)
print(f"Training accuracy: {train_accuracy}, Validation accuracy: {val_accuracy}")
print(f"Training loss: {train_loss}, Validation loss: {val_loss}")
# Out:
# Training accuracy: 0.9061354994773865, Validation accuracy: 0.8131868243217468
# Training loss: 0.33940255641937256, Validation loss: 0.4715101420879364

# %%
# saving the histories in a pickle file
# with open('/home/mendu/Thesis/data/magnatagatune/saved_history_dictionaries/history_dict_re9.pkl', 'wb') as f:
#     pickle.dump(history.history, f)
