# %%
import pandas as pd
pd.set_option('max_colwidth', None)

# %%
df = pd.read_csv('/home/mendu/Thesis/data/magnatagatune/tag_annotations.csv', sep = '\t',index_col=[0])

# %%
df =df[['mp3_path']]

# %%
df
# Out:
#                                                                               mp3_path
# clip_id
# 2          f/american_bach_soloists-j_s__bach_solo_cantatas-01-bwv54__i_aria-30-59.mp3
# 6        f/american_bach_soloists-j_s__bach_solo_cantatas-01-bwv54__i_aria-146-175.mp3
# 10       f/american_bach_soloists-j_s__bach_solo_cantatas-01-bwv54__i_aria-262-291.mp3
# 11       f/american_bach_soloists-j_s__bach_solo_cantatas-01-bwv54__i_aria-291-320.mp3
# 12       f/american_bach_soloists-j_s__bach_solo_cantatas-01-bwv54__i_aria-320-349.mp3
# ...                                                                                ...
# 58899                  8/jacob_heringman-blame_not_my_lute-56-la_bressanina-88-117.mp3
# 58906               8/jacob_heringman-blame_not_my_lute-57-lost_is_my_lyberty-0-29.mp3
# 58907              8/jacob_heringman-blame_not_my_lute-57-lost_is_my_lyberty-30-59.mp3
# 58908              8/jacob_heringman-blame_not_my_lute-57-lost_is_my_lyberty-59-88.mp3
# 58915          8/jacob_heringman-blame_not_my_lute-58-a_toy_for_monica_bishop-0-29.mp3
#
# [25863 rows x 1 columns]

# %%
df['mp3_path'][6]
# Out:
# 'f/american_bach_soloists-j_s__bach_solo_cantatas-01-bwv54__i_aria-146-175.mp3'

# %%
df_tags = df.drop('mp3_path', axis='columns')

# %%
df_tags.sum(axis = 0).sort_values(ascending=False)[:10]
# Out:
# guitar        4852
# classical     4272
# slow          3547
# techno        2954
# strings       2729
# drums         2598
# electronic    2519
# rock          2371
# fast          2306
# piano         2056
# dtype: int64

# %%
err_128 = pd.read_csv('/home/mendu/Thesis/data/saved_models/grid_search_alpha_128/error_analysis_df.csv', index_col = [0])

# %%
err_128
# Out:
#      Index Correct Label Wrong Label_0 Wrong Label_25 Wrong Label_5  \
# 0        2       country     classical      classical     classical
# 2        9       new age    electronic     electronic    electronic
# 5       15       new age    electronic     electronic    electronic
# 6       17           pop          rock           rock        indian
# 7       21         opera     classical      classical     classical
# ..     ...           ...           ...            ...           ...
# 308   1134        indian     classical      classical     classical
# 311   1142          rock    electronic     electronic        indian
# 313   1145        indian    electronic        country          rock
# 317   1173        indian    electronic     electronic    electronic
# 318   1176          rock    electronic     electronic    electronic
#
#     Wrong Label_75  Highest Wrong Label
# 0        classical                    4
# 2       electronic                    4
# 5       electronic                    4
# 6             rock                    3
# 7        classical                    4
# ..             ...                  ...
# 308      classical                    4
# 311     electronic                    3
# 313           rock                    2
# 317     electronic                    4
# 318     electronic                    4
#
# [113 rows x 7 columns]

# %%
err_128[err_128['Highest Wrong Label'] == 4].head(10)
# Out:
#     Index Correct Label Wrong Label_0 Wrong Label_25 Wrong Label_5  \
# 0       2       country     classical      classical     classical
# 2       9       new age    electronic     electronic    electronic
# 5      15       new age    electronic     electronic    electronic
# 7      21         opera     classical      classical     classical
# 8      24           pop          rock           rock          rock
# 14     47     classical    electronic     electronic    electronic
# 16     52          rock    electronic     electronic    electronic
# 24     90           pop          rock           rock          rock
# 29    112           pop    electronic     electronic    electronic
# 32    127           pop          rock           rock          rock
#
#    Wrong Label_75  Highest Wrong Label
# 0       classical                    4
# 2      electronic                    4
# 5      electronic                    4
# 7       classical                    4
# 8            rock                    4
# 14     electronic                    4
# 16     electronic                    4
# 24           rock                    4
# 29     electronic                    4
# 32           rock                    4

# %%
df.loc[[2]]
# Out:
#                                                                             mp3_path
# clip_id
# 2        f/american_bach_soloists-j_s__bach_solo_cantatas-01-bwv54__i_aria-30-59.mp3

# %%
path
# Out:
# clip_id
# 2    f/american_bach_soloists-j_s__bach_solo_cantat...
# Name: mp3_path, dtype: object
